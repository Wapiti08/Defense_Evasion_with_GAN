# %% [markdown]
# ## N-gram on registry strings

# %% [markdown]
# ### 1. Used to save the registry_features_list for both normal and ransom

# %%
import pickle
import itertools
import sys


ransome_features = './feature_ransom.txt'
normal_features = './feature_normal.txt'

# %%
def features_fields(features_txt):
    features_list = []
    stop =sum(1 for line in open(features_txt, 'r'))
    # feature = open("features_normal.txt","r",encoding="utf-8")
    with open(features_txt,"r") as fr:
        feature = fr.readlines()    
        for ind in itertools.islice(feature , stop):
            fields = ind.split(':', 1)
            features_list.append(fields[1])
        return features_list

# %%
normal_features_list = features_fields('../dataset/features_normal.txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# e:\open_source_projects\Analysis_Ransome_with_GAN\processing\N-Gram.ipynb Cell 5' in <module>
# ----> <a href='vscode-notebook-cell:/e%3A/open_source_projects/Analysis_Ransome_with_GAN/processing/N-Gram.ipynb#ch0000004?line=0'>1</a> normal_features_list = features_fields('../dataset/features_normal.txt')
#
# e:\open_source_projects\Analysis_Ransome_with_GAN\processing\N-Gram.ipynb Cell 4' in features_fields(features_txt)
#       <a href='vscode-notebook-cell:/e%3A/open_source_projects/Analysis_Ransome_with_GAN/processing/N-Gram.ipynb#ch0000003?line=0'>1</a> def features_fields(features_txt):
#       <a href='vscode-notebook-cell:/e%3A/open_source_projects/Analysis_Ransome_with_GAN/processing/N-Gram.ipynb#ch0000003?line=1'>2</a>     features_list = []
# ----> <a href='vscode-notebook-cell:/e%3A/open_source_projects/Analysis_Ransome_with_GAN/processing/N-Gram.ipynb#ch0000003?line=2'>3</a>     stop =sum(1 for line in open(features_txt, 'r'))
#       <a href='vscode-notebook-cell:/e%3A/open_source_projects/Analysis_Ransome_with_GAN/processing/N-Gram.ipynb#ch0000003?line=3'>4</a>     # feature = open("features_normal.txt","r",encoding="utf-8")
#       <a href='vscode-notebook-cell:/e%3A/open_source_projects/Analysis_Ransome_with_GAN/processing/N-Gram.ipynb#ch0000003?line=4'>5</a>     with open(features_txt,"r") as fr:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../dataset/features_normal.txt'

# %%
ransom_features_list = features_fields('../dataset/features_ransom.txt')

# %%
# extract the regkey parts from both features_list
for feature in normal_features_list:
    if feature[:7] != 'regkey':
        normal_features_list.remove(feature)
for feature in ransom_features_list:
    if feature[:7] != 'regkey':
        ransom_features_list.remove(feature)

# %%
# save the registry features with titles
with open('../dataset/registry_features/nor_registry_features.pkl','wb') as nw:
    pickle.dump(normal_features_list, nw)
with open('../dataset/registry_features/ran_registry_features.pkl','wb') as rw:
    pickle.dump(ransom_features_list, rw)

# %% [markdown]
# ### 2. Used to analyse the saved features results

# %%
from nltk import ngrams
from nltk import FreqDist
import pandas as pd

def ngram_fre_analysis(n, features_list):
    ngrams_list = []
    for feature in features_list:
        grams = ngrams(feature.split("\\"),n)
        for gram in grams:
            ngrams_list.append(gram)
    
    ngrams_freqdist = FreqDist(ngrams_list)
    return ngrams_freqdist

# %%
# read the normal_features_list
with open('../dataset/registry_features/nor_registry_features.pkl','rb') as wr:
    normal_features_list = pickle.load(wr)

# read the ransom_featuers_list
with open('../dataset/registry_features/ran_registry_features.pkl','rb') as wr:
    ransom_features_list = pickle.load(wr)

# %%
# get the fre of three ngrams for two sets of features
thr_ngrams_freqdist_nor = ngram_fre_analysis(3, normal_features_list)
thr_ngrams_freqdist_ran = ngram_fre_analysis(3, ransom_features_list)

# %%
dict(thr_ngrams_freqdist_nor)
# Out:
# {('regkey_opened_HKEY_LOCAL_MACHINE', 'SOFTWARE', 'Wow6432Node'): 143,
#  ('SOFTWARE', 'Wow6432Node', 'Microsoft'): 1237,
#  ('Wow6432Node', 'Microsoft', 'Windows'): 1173,
#  ('Microsoft', 'Windows', 'CurrentVersion'): 1368,
#  ('Windows', 'CurrentVersion', 'explorer'): 1163,
#  ('CurrentVersion', 'explorer', 'FolderDescriptions'): 1151,
#  ('explorer',
#   'FolderDescriptions',
#   '{724EF170-A42D-4FEF-9F26-B60E846FBA4F}'): 8,
#  ('FolderDescriptions',
#   '{724EF170-A42D-4FEF-9F26-B60E846FBA4F}',
#   'PropertyBag\n'): 1,
#  ('Wow6432Node', 'Microsoft', 'Cryptography'): 47,
#  ('Microsoft', 'Cryptography', 'OID'): 42,
#  ('Cryptography', 'OID', 'EncodingType 0'): 35,
#  ('OID', 'EncodingType 0', 'CryptSIPDllVerifyIndirectData'): 7,
#  ('EncodingType 0',
#   'CryptSIPDllVerifyIndirectData',
#   '{DE351A42-8E59-11D0-8C47-00C04FC295EE}\n'): 1,
#  ('regkey_opened_HKEY_LOCAL_MACHINE', 'Software', 'Microsoft'): 40,
#  ('Software', 'Microsoft', 'Cryptography'): 8,
#  ('Microsoft', 'Cryptography', 'Providers'): 11,
#  ('Cryptography', 'Providers', 'Trust'): 11,
#  ('Providers', 'Trust', 'Signature'): 1,
#  ('Trust', 'Signature', '{00AAC56B-CD44-11D0-8CC2-00C04FC295EE}\n'): 1,
#  ('regkey_opened_HKEY_LOCAL_MACHINE', 'SOFTWARE', 'Microsoft'): 24,
#  ('SOFTWARE', 'Microsoft', 'Windows'): 14,
#  ('Windows', 'CurrentVersion', 'ShellCompatibility'): 7,
#  ('CurrentVersion', 'ShellCompatibility', 'Applications'): 3,
#  ('ShellCompatibility', 'Applications', 'AcroRd32.exe\n'): 1,
#  ('regkey_opened_HKEY_LOCAL_MACHINE', 'Software', 'Clients'): 1,
#  ('Software', 'Clients', 'Media'): 1,
#  ('Clients', 'Media', 'Windows Media Player'): 3,
#  ('Media', 'Windows Media Player', 'Capabilities\n'): 1,
#  ('regkey_opened_HKEY_LOCAL_MACHINE', 'SOFTWARE', 'Classes'): 61,
#  ('SOFTWARE', 'Classes', 'Applications'): 88,
#  ('Classes', 'Applications', 'photoviewer.dll'): 5,
#  ('Applications', 'photoviewer.dll', 'shell'): 5,
#  ('photoviewer.dll', 'shell', 'open\n'): 1,
#  ('regkey_opened_HKEY_CURRENT_USER', 'Software', 'Microsoft'): 40,
#  ('Software', 'Microsoft', 'Windows'): 183,
#  ('Windows', 'CurrentVersion', 'Explorer'): 148,
#  ('CurrentVersion', 'Explorer', 'SessionInfo'): 3,
#  ('Explorer', 'SessionInfo', '1\n'): 1,
#  ('Explorer', 'SessionInfo', '1'): 2,
#  ('SessionInfo', '1', 'KnownFolders\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{7D1D3A04-DEBB-4115-95CF-2F29DA2920DA}\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'Applications', 'wab.exe\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{9E3995AB-1F9C-4F13-B827-48B24B6C7174}'): 12,
#  ('FolderDescriptions',
#   '{9E3995AB-1F9C-4F13-B827-48B24B6C7174}',
#   'PropertyBag\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'Drive', 'shellex'): 2,
#  ('Drive', 'shellex', 'FolderExtensions\n'): 1,
#  ('Windows', 'CurrentVersion', 'Uninstall'): 12,
#  ('CurrentVersion',
#   'Uninstall',
#   '{AC76BA86-7AD7-1033-7B44-AB0000000001}\n'): 1,
#  ('Windows', 'CurrentVersion', 'Policies'): 19,
#  ('CurrentVersion', 'Policies', 'NonEnum\n'): 1,
#  ('OID', 'EncodingType 0', 'CryptSIPDllGetSignedDataMsg'): 4,
#  ('EncodingType 0',
#   'CryptSIPDllGetSignedDataMsg',
#   '{C689AAB8-8E78-11D0-8C47-00C04FC295EE}\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{54EED2E0-E7CA-4FDB-9148-0F4247291CFA}'): 13,
#  ('FolderDescriptions',
#   '{54EED2E0-E7CA-4FDB-9148-0F4247291CFA}',
#   'PropertyBag\n'): 1,
#  ('Windows', 'CurrentVersion', 'Shell Extensions'): 4,
#  ('CurrentVersion', 'Shell Extensions', 'Cached\n'): 1,
#  ('regkey_opened_HKEY_CURRENT_USER', 'bin_auto_file', 'BrowseInPlace\n'): 1,
#  ('SOFTWARE', 'Classes', 'Unknown'): 9,
#  ('Classes', 'Unknown', 'BrowseInPlace\n'): 1,
#  ('OID', 'EncodingType 0', 'CryptDllEncodeObjectEx\n'): 1,
#  ('SOFTWARE', 'Classes', 'SystemFileAssociations'): 11,
#  ('Classes', 'SystemFileAssociations', 'system'): 4,
#  ('SystemFileAssociations', 'system', 'BrowseInPlace\n'): 2,
#  ('CurrentVersion', 'Explorer', 'FileExts'): 16,
#  ('Explorer', 'FileExts', '.exe'): 2,
#  ('FileExts', '.exe', '(Default)\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{625B53C3-AB48-4EC1-BA1F-A1EF4146FC19}\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'xmind-zen', 'shell\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'Applications', 'helpctr.exe\n'): 1,
#  ('EncodingType 0',
#   'CryptSIPDllGetSignedDataMsg',
#   '{C689AABA-8E78-11D0-8C47-00C04FC295EE}\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'Applications', 'wusa.exe\n'): 1,
#  ('OID', 'EncodingType 0', 'CryptDllFindOIDInfo'): 2,
#  ('EncodingType 0', 'CryptDllFindOIDInfo', '1.3.6.1.4.1.311.64.1.1!7\n'): 1,
#  ('Microsoft', 'Cryptography', 'Wintrust'): 1,
#  ('Cryptography', 'Wintrust', 'Config\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'Applications', 'mnyimprt.exe\n'): 1,
#  ('Windows', 'CurrentVersion', 'PropertySystem'): 2,
#  ('CurrentVersion', 'PropertySystem', 'PropertyHandlers'): 2,
#  ('PropertySystem', 'PropertyHandlers', '.exe\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'Applications', 'cryptext.dll\n'): 1,
#  ('regkey_opened_HKEY_LOCAL_MACHINE', 'SOFTWARE', 'Clients'): 4,
#  ('SOFTWARE', 'Clients', 'Media'): 3,
#  ('Clients', 'Media', 'Windows Media Center'): 1,
#  ('Media', 'Windows Media Center', 'Capabilities'): 1,
#  ('Windows Media Center', 'Capabilities', 'FileAssociations\n'): 1,
#  ('regkey_opened_HKEY_CURRENT_USER', 'Software', 'Policies'): 3,
#  ('Software', 'Policies', 'Microsoft'): 10,
#  ('Policies', 'Microsoft', 'Internet Explorer'): 2,
#  ('Microsoft', 'Internet Explorer', 'Main'): 6,
#  ('Internet Explorer', 'Main', 'FeatureControl\n'): 4,
#  ('Windows', 'CurrentVersion', 'App Paths'): 7,
#  ('CurrentVersion', 'App Paths', 'rundll32.exe\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{A305CE99-F527-492B-8B1A-7E76FA98D6E4}'): 11,
#  ('FolderDescriptions',
#   '{A305CE99-F527-492B-8B1A-7E76FA98D6E4}',
#   'PropertyBag\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{CAC52C1A-B53D-4EDC-92D7-6B2E8AC19434}'): 12,
#  ('FolderDescriptions',
#   '{CAC52C1A-B53D-4EDC-92D7-6B2E8AC19434}',
#   'PropertyBag\n'): 1,
#  ('SOFTWARE', 'Microsoft', 'CTF'): 5,
#  ('Microsoft', 'CTF', 'Compatibility'): 4,
#  ('CTF', 'Compatibility', 'ThunderStart.exe\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{B250C668-F57D-4EE1-A63C-290EE7D1AA1F}\n'): 1,
#  ('CurrentVersion', 'Explorer', 'CLSID'): 5,
#  ('Explorer', 'CLSID', '{59031A47-3F72-44A7-89C5-5595FE6B30EE}'): 1,
#  ('CLSID', '{59031A47-3F72-44A7-89C5-5595FE6B30EE}', 'ShellFolder\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'Applications', 'fpidcwiz.exe\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{52A4F021-7B75-48A9-9F6B-4B87A210BC8F}'): 9,
#  ('FolderDescriptions',
#   '{52A4F021-7B75-48A9-9F6B-4B87A210BC8F}',
#   'PropertyBag\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{7B0DB17D-9CD2-4A93-9733-46CC89022E7C}\n'): 1,
#  ('CurrentVersion', 'Explorer', 'AutoComplete\n'): 2,
#  ('SOFTWARE', 'Classes', 'Directory'): 4,
#  ('Classes', 'Directory', 'BrowseInPlace\n'): 1,
#  ('regkey_opened_HKEY_CURRENT_USER', 'manifest_auto_file', 'Progid\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'Applications', 'MSInfo32.exe\n'): 1,
#  ('regkey_opened_HKEY_CURRENT_USER',
#   'Interface',
#   '{000214E3-0000-0000-C000-000000000046}\n'): 1,
#  ('Explorer', 'FileExts', '.manifest'): 6,
#  ('FileExts', '.manifest', 'OpenWithProgids\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'Applications', 'depends.exe\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{10C07CD0-EF91-4567-B850-448B77CB37F9}\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{2C36C0AA-5812-4B87-BFD0-4CD0DFB19B39}\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'Applications', 'faxcover.exe\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'Applications', 'wordpad.exe\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{F3CE0F7C-4901-4ACC-8648-D5D44B04EF8F}'): 12,
#  ('FolderDescriptions',
#   '{F3CE0F7C-4901-4ACC-8648-D5D44B04EF8F}',
#   'PropertyBag\n'): 1,
#  ('Cryptography', 'OID', 'EncodingType 1'): 14,
#  ('OID', 'EncodingType 1', 'SchemeDllRetrieveEncodedObjectW\n'): 1,
#  ('OID', 'EncodingType 1', 'ContextDllCreateObjectContext\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{DFDF76A2-C82A-4D63-906A-5644AC457385}'): 10,
#  ('FolderDescriptions',
#   '{DFDF76A2-C82A-4D63-906A-5644AC457385}',
#   'PropertyBag\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT',
#   'SystemFileAssociations',
#   '.manifest\n'): 1,
#  ('Software', 'Microsoft', 'windows'): 3,
#  ('Microsoft', 'windows', 'CurrentVersion'): 3,
#  ('windows', 'CurrentVersion', 'Internet Settings'): 3,
#  ('CurrentVersion', 'Internet Settings', 'Connections\n'): 2,
#  ('explorer',
#   'FolderDescriptions',
#   '{4BD8D571-6D19-48D3-BE97-422220080E43}'): 11,
#  ('FolderDescriptions',
#   '{4BD8D571-6D19-48D3-BE97-422220080E43}',
#   'PropertyBag\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{2A00375E-224C-49DE-B8D1-440DF7EF3DDC}\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{4BFEFB45-347D-4006-A5BE-AC0CB0567192}\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{ED4824AF-DCE4-45A8-81E2-FC7965083634}'): 11,
#  ('FolderDescriptions',
#   '{ED4824AF-DCE4-45A8-81E2-FC7965083634}',
#   'PropertyBag\n'): 1,
#  ('Explorer', 'FileExts', '.lnk\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', '.manifest', 'OpenWithProgids\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{0139D44E-6AFE-49F2-8690-3DAFCAE6FFB8}'): 8,
#  ('FolderDescriptions',
#   '{0139D44E-6AFE-49F2-8690-3DAFCAE6FFB8}',
#   'PropertyBag\n'): 1,
#  ('SOFTWARE', 'Microsoft', 'OLEAUT\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{DE92C1C7-837F-4F69-A3BB-86E631204A23}'): 10,
#  ('FolderDescriptions',
#   '{DE92C1C7-837F-4F69-A3BB-86E631204A23}',
#   'PropertyBag\n'): 1,
#  ('OID', 'EncodingType 0', 'CryptDllImportPublicKeyInfoEx2\n'): 1,
#  ('OID', 'EncodingType 0', 'CryptSIPDllPutSignedDataMsg'): 5,
#  ('EncodingType 0',
#   'CryptSIPDllPutSignedDataMsg',
#   '{DE351A42-8E59-11D0-8C47-00C04FC295EE}\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'xmind', 'shell'): 1,
#  ('xmind', 'shell', 'Open\n'): 1,
#  ('CTF', 'Compatibility', 'installer.exe\n'): 1,
#  ('Policies', 'Microsoft', 'SystemCertificates'): 3,
#  ('Microsoft', 'SystemCertificates', 'TrustedPublisher'): 1,
#  ('SystemCertificates', 'TrustedPublisher', 'Safer\n'): 1,
#  ('SOFTWARE', 'Microsoft', 'OLE\n'): 1,
#  ('Microsoft', 'Windows', 'Shell'): 10,
#  ('Windows', 'Shell', 'Associations'): 1,
#  ('Shell', 'Associations', 'UrlAssociations'): 1,
#  ('Associations', 'UrlAssociations', 'Directory\n'): 1,
#  ('Windows', 'CurrentVersion', 'GameUX'): 18,
#  ('CurrentVersion', 'GameUX', 'Games'): 18,
#  ('GameUX', 'Games', '{6C815596-821F-40B3-8A84-643B73A8EB16}\n'): 1,
#  ('SOFTWARE', 'Clients', 'StartMenuInternet'): 1,
#  ('Clients', 'StartMenuInternet', 'Google Chrome'): 1,
#  ('StartMenuInternet', 'Google Chrome', 'Capabilities'): 1,
#  ('Google Chrome', 'Capabilities', 'FileAssociations\n'): 1,
#  ('Classes', 'Directory', '(Default)\n'): 1,
#  ('regkey_opened_HKEY_CURRENT_USER', 'manifest_auto_file', 'CurVer\n'): 1,
#  ('FileExts', '.manifest', 'UserChoice\n'): 1,
#  ('EncodingType 0',
#   'CryptSIPDllPutSignedDataMsg',
#   '{C689AAB8-8E78-11D0-8C47-00C04FC295EE}\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'Applications', 'OSA.EXE\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT',
#   'CLSID',
#   '{ED228FDF-9EA8-4870-83B1-96B02CFE0D52}'): 1,
#  ('CLSID', '{ED228FDF-9EA8-4870-83B1-96B02CFE0D52}', 'InProcServer32\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{69D2CF90-FC33-4FB7-9A0C-EBB0F0FCB43C}'): 10,
#  ('FolderDescriptions',
#   '{69D2CF90-FC33-4FB7-9A0C-EBB0F0FCB43C}',
#   'PropertyBag\n'): 1,
#  ('FileExts', '.manifest', 'OpenWithList\n'): 1,
#  ('Classes', 'Applications', 'ehshell.exe'): 4,
#  ('Applications', 'ehshell.exe', 'shell\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{BCBD3057-CA5C-4622-B42D-BC56DB0AE516}'): 13,
#  ('FolderDescriptions',
#   '{BCBD3057-CA5C-4622-B42D-BC56DB0AE516}',
#   'PropertyBag\n'): 1,
#  ('SOFTWARE', 'Classes', 'Wow6432Node'): 70,
#  ('Classes', 'Wow6432Node', 'CLSID'): 63,
#  ('Wow6432Node', 'CLSID', '{C90250F3-4D7D-4991-9B69-A5C5BC1C2AE6}'): 4,
#  ('CLSID', '{C90250F3-4D7D-4991-9B69-A5C5BC1C2AE6}', 'Progid\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT',
#   'CLSID',
#   '{FAE3D380-FEA4-4623-8C75-C6B61110B681}'): 1,
#  ('CLSID', '{FAE3D380-FEA4-4623-8C75-C6B61110B681}', 'Instance'): 1,
#  ('{FAE3D380-FEA4-4623-8C75-C6B61110B681}', 'Instance', 'Disabled\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{43668BF8-C14E-49B2-97C9-747784D784B7}\n'): 1,
#  ('regkey_opened_HKEY_LOCAL_MACHINE', 'Software', 'Policies'): 7,
#  ('Policies', 'Microsoft', 'System'): 1,
#  ('Microsoft', 'System', 'DNSClient\n'): 1,
#  ('OID', 'EncodingType 1', 'CertDllVerifyCertificateChainPolicy\n'): 1,
#  ('regkey_opened_HKEY_CURRENT_USER', 'bin_auto_file', 'Clsid\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'xmind-zen', 'shell'): 2,
#  ('xmind-zen', 'shell', 'Open'): 3,
#  ('shell', 'Open', 'command\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{C1BAE2D0-10DF-4334-BEDD-7AA20B227A9D}\n'): 1,
#  ('Windows', 'CurrentVersion', 'Internet Settings'): 9,
#  ('CurrentVersion', 'Internet Settings', 'WinHttp'): 2,
#  ('Internet Settings', 'WinHttp', 'Tracing\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{8983036C-27C0-404B-8F08-102D10DCFD74}\n'): 1,
#  ('EncodingType 0',
#   'CryptSIPDllPutSignedDataMsg',
#   '{1629F04E-2799-4DB5-8FE5-ACE10F17EBAB}\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT',
#   'CLSID',
#   '{03C036F1-A186-11D0-824A-00AA005B4383}'): 1,
#  ('CLSID', '{03C036F1-A186-11D0-824A-00AA005B4383}', 'InProcServer32\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{DFDF76A2-C82A-4D63-906A-5644AC457385}\n'): 1,
#  ('CurrentVersion', 'Explorer', 'KindMap\n'): 1,
#  ('SOFTWARE', 'Classes', 'exefile'): 6,
#  ('Classes', 'exefile', 'ShellEx'): 1,
#  ('exefile', 'ShellEx', 'IconHandler\n'): 1,
#  ('SOFTWARE', 'Classes', 'AllFilesystemObjects'): 8,
#  ('Classes', 'AllFilesystemObjects', 'ShellEx'): 2,
#  ('AllFilesystemObjects',
#   'ShellEx',
#   '{2F711B17-773C-41D4-93FA-7F23EDCECB66}\n'): 1,
#  ('CurrentVersion', 'Internet Settings', 'WinHttp\n'): 1,
#  ('photoviewer.dll', 'shell', 'open'): 3,
#  ('shell', 'open', 'command\n'): 4,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'Applications', 'ehshell.exe\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{E555AB60-153B-4D17-9F04-A5FE99FC15EC}\n'): 1,
#  ('regkey_opened_HKEY_CURRENT_USER',
#   'CLSID',
#   '{A4A1A128-768F-41E0-BF75-E4FDDD701CBA}\n'): 1,
#  ('Classes', 'exefile', 'CurVer\n'): 1,
#  ('regkey_opened_HKEY_CURRENT_USER',
#   'Interface',
#   '{000214E2-0000-0000-C000-000000000046}\n'): 1,
#  ('Classes', 'Wow6432Node', 'Interface'): 7,
#  ('Wow6432Node', 'Interface', '{00000114-0000-0000-C000-000000000046}'): 2,
#  ('Interface',
#   '{00000114-0000-0000-C000-000000000046}',
#   'ProxyStubClsid32\n'): 1,
#  ('Classes', 'exefile', '(Default)\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'Applications', 'HYPERTRM.EXE\n'): 1,
#  ('Software', 'Microsoft', 'Windows NT'): 4,
#  ('Microsoft', 'Windows NT', 'CurrentVersion'): 5,
#  ('Windows NT', 'CurrentVersion', 'ProfileList'): 1,
#  ('CurrentVersion',
#   'ProfileList',
#   'S-1-5-21-1608274813-2371932595-3444937299-1001\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{3EB685DB-65F9-4CF6-A03A-E3EF65729F3D}\n'): 1,
#  ('EncodingType 0',
#   'CryptSIPDllPutSignedDataMsg',
#   '{603BCC1F-4B59-4E08-B724-D2C6297EF351}\n'): 1,
#  ('ShellCompatibility', 'Applications', 'installer.exe\n'): 1,
#  ('GameUX', 'Games', '{FC96B68C-09EF-4251-A598-19E4BE1B76A9}\n'): 1,
#  ('EncodingType 0',
#   'CryptSIPDllVerifyIndirectData',
#   '{C689AABA-8E78-11D0-8C47-00C04FC295EE}\n'): 1,
#  ('Classes', 'Applications', 'AcroRD32.exe'): 10,
#  ('Applications', 'AcroRD32.exe', 'shell'): 8,
#  ('AcroRD32.exe', 'shell', 'Read\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{F7F1ED05-9F6D-47A2-AAAE-29D317C6F066}'): 12,
#  ('FolderDescriptions',
#   '{F7F1ED05-9F6D-47A2-AAAE-29D317C6F066}',
#   'PropertyBag\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{F1B32785-6FBA-4FCF-9D55-7B8E7F157091}'): 10,
#  ('FolderDescriptions',
#   '{F1B32785-6FBA-4FCF-9D55-7B8E7F157091}',
#   'PropertyBag\n'): 1,
#  ('Wow6432Node', 'CLSID', '{A4A1A128-768F-41E0-BF75-E4FDDD701CBA}'): 5,
#  ('CLSID', '{A4A1A128-768F-41E0-BF75-E4FDDD701CBA}', 'TreatAs\n'): 1,
#  ('Classes', 'Applications', 'mspaint.exe'): 6,
#  ('Applications', 'mspaint.exe', '(Default)\n'): 1,
#  ('Classes', 'Applications', 'wmplayer.exe'): 4,
#  ('Applications', 'wmplayer.exe', 'shell'): 3,
#  ('wmplayer.exe', 'shell', 'play'): 2,
#  ('shell', 'play', 'command\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{C4900540-2379-4C75-844B-64E6FAF8716B}'): 9,
#  ('FolderDescriptions',
#   '{C4900540-2379-4C75-844B-64E6FAF8716B}',
#   'PropertyBag\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{C870044B-F49E-4126-A9C3-B52A1FF411E8}'): 14,
#  ('FolderDescriptions',
#   '{C870044B-F49E-4126-A9C3-B52A1FF411E8}',
#   'PropertyBag\n'): 1,
#  ('Classes', 'SystemFileAssociations', '.exe'): 6,
#  ('SystemFileAssociations', '.exe', 'Clsid\n'): 1,
#  ('OID', 'EncodingType 0', 'UrlDllGetObjectUrl\n'): 1,
#  ('Software', 'Microsoft', 'Internet Explorer'): 6,
#  ('explorer',
#   'FolderDescriptions',
#   '{7C5A40EF-A0FB-4BFC-874A-C0F2E0B9FA8E}\n'): 1,
#  ('Explorer', 'CLSID', '{20D04FE0-3AEA-1069-A2D8-08002B30309D}'): 1,
#  ('CLSID', '{20D04FE0-3AEA-1069-A2D8-08002B30309D}', 'ShellFolder\n'): 1,
#  ('SOFTWARE', 'Classes', 'lnkfile'): 7,
#  ('Classes', 'lnkfile', '(Default)\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{3D644C9B-1FB8-4F30-9B45-F670235F79C0}\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{98EC0E18-2098-4D44-8644-66979315A281}'): 15,
#  ('FolderDescriptions',
#   '{98EC0E18-2098-4D44-8644-66979315A281}',
#   'PropertyBag\n'): 1,
#  ('OID', 'EncodingType 1', 'CryptSIPDllVerifyIndirectData\n'): 1,
#  ('CTF', 'Compatibility', 'audacity-win-2.3.3.tmp\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT',
#   'CLSID',
#   '{DD313E04-FEFF-11D1-8ECD-0000F87A470C}'): 1,
#  ('CLSID', '{DD313E04-FEFF-11D1-8ECD-0000F87A470C}', 'InProcServer32\n'): 1,
#  ('regkey_opened_HKEY_CURRENT_USER', 'Software', 'Google'): 1,
#  ('Software', 'Google', 'Update'): 1,
#  ('Google', 'Update', 'Clients'): 2,
#  ('Update', 'Clients', '{430FD4D0-B729-4F61-AA34-91526481799D}\n'): 2,
#  ('regkey_opened_HKEY_LOCAL_MACHINE', 'System', 'CurrentControlSet'): 5,
#  ('System', 'CurrentControlSet', 'Control'): 2,
#  ('CurrentControlSet', 'Control', 'LsaExtensionConfig'): 1,
#  ('Control', 'LsaExtensionConfig', 'SspiCli\n'): 1,
#  ('Software', 'Microsoft', 'CTF'): 1,
#  ('Microsoft', 'CTF', 'TIP'): 1,
#  ('CTF', 'TIP', '{0000897b-83df-4b96-be07-0fb58b01c4a4}'): 1,
#  ('TIP', '{0000897b-83df-4b96-be07-0fb58b01c4a4}', 'LanguageProfile'): 1,
#  ('{0000897b-83df-4b96-be07-0fb58b01c4a4}',
#   'LanguageProfile',
#   '0x00000000'): 1,
#  ('LanguageProfile',
#   '0x00000000',
#   '{0001bea3-ed56-483d-a2e2-aeae25577436}\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{A990AE9F-A03B-4E80-94BC-9912D7504104}'): 9,
#  ('FolderDescriptions',
#   '{A990AE9F-A03B-4E80-94BC-9912D7504104}',
#   'PropertyBag\n'): 1,
#  ('EncodingType 0',
#   'CryptSIPDllGetSignedDataMsg',
#   '{DE351A43-8E59-11D0-8C47-00C04FC295EE}\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'Applications', 'zipfldr.dll\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'SystemFileAssociations', 'system\n'): 1,
#  ('CurrentVersion', 'ShellCompatibility', 'ProgIDs'): 1,
#  ('ShellCompatibility', 'ProgIDs', 'manifest_auto_file\n'): 1,
#  ('regkey_opened_HKEY_CURRENT_USER',
#   'manifest_auto_file',
#   'BrowseInPlace\n'): 1,
#  ('Media', 'Windows Media Player', 'Capabilities'): 2,
#  ('Windows Media Player', 'Capabilities', 'FileAssociations\n'): 1,
#  ('OID', 'EncodingType 0', 'CryptDllFindOIDInfo\n'): 1,
#  ('Wow6432Node', 'Interface', '{E7A1AF80-4D96-11CF-960C-0080C7F4EE85}'): 2,
#  ('Interface',
#   '{E7A1AF80-4D96-11CF-960C-0080C7F4EE85}',
#   'ProxyStubClsid32\n'): 1,
#  ('CurrentVersion', 'Explorer', 'RemoveAccess\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{352481E8-33BE-4251-BA85-6007CAEDCF9D}\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'Applications', 'ORGCHART.EXE\n'): 1,
#  ('Internet Explorer', 'Main', 'FeatureControl'): 2,
#  ('Main', 'FeatureControl', 'FEATURE_MIME_SNIFFING\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{625B53C3-AB48-4EC1-BA1F-A1EF4146FC19}'): 9,
#  ('FolderDescriptions',
#   '{625B53C3-AB48-4EC1-BA1F-A1EF4146FC19}',
#   'PropertyBag\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'xmind', 'DefaultIcon\n'): 1,
#  ('CurrentVersion', 'Policies', 'Explorer\n'): 2,
#  ('explorer',
#   'FolderDescriptions',
#   '{FDD39AD0-238F-46AF-ADB4-6C85480369C7}\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'Applications', 'CMMGR32.EXE\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{B88F4DAA-E7BD-49A9-B74D-02885A5DC765}\n'): 1,
#  ('xmind-zen', 'shell', 'Open\n'): 1,
#  ('CurrentVersion', 'explorer', 'FileAssociation\n'): 1,
#  ('CurrentVersion', 'Uninstall', 'Everything\n'): 1,
#  ('Cryptography', 'OID', 'EncodingType 1\n'): 1,
#  ('Classes', 'Unknown', '(Default)\n'): 1,
#  ('CurrentVersion', 'Internet Settings', 'Wpad\n'): 1,
#  ('regkey_opened_HKEY_LOCAL_MACHINE', 'SOFTWARE', 'Policies'): 1,
#  ('SOFTWARE', 'Policies', 'Adobe'): 8,
#  ('Policies', 'Adobe', 'Acrobat Reader'): 8,
#  ('Adobe', 'Acrobat Reader', '11.0'): 11,
#  ('Acrobat Reader', '11.0', 'FeatureLockdown\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{0762D272-C50A-4BB0-A382-697DCD729B80}\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{289A9A43-BE44-4057-A41B-587A76D7E7F9}'): 10,
#  ('FolderDescriptions',
#   '{289A9A43-BE44-4057-A41B-587A76D7E7F9}',
#   'PropertyBag\n'): 1,
#  ('EncodingType 0',
#   'CryptSIPDllPutSignedDataMsg',
#   '{9BA61D3F-E73A-11D0-8CD2-00C04FC295EE}\n'): 1,
#  ('System', 'CurrentControlSet', 'Services'): 3,
#  ('CurrentControlSet', 'Services', 'LDAP\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{4D9F7874-4E0C-4904-967B-40B0D20C3E4B}\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', '.lnk', 'OpenWithProgids\n'): 1,
#  ('CurrentVersion', 'Explorer', 'MountPoints2'): 6,
#  ('Explorer', 'MountPoints2', 'CPC'): 6,
#  ('MountPoints2', 'CPC', 'Volume'): 5,
#  ('CPC', 'Volume', '{3ffe1cff-3eb4-11ea-9e4c-806e6f6e6963}'): 1,
#  ('Volume', '{3ffe1cff-3eb4-11ea-9e4c-806e6f6e6963}', '\n'): 1,
#  ('CurrentVersion', 'ShellCompatibility', 'Objects'): 3,
#  ('ShellCompatibility',
#   'Objects',
#   '{ED228FDF-9EA8-4870-83B1-96B02CFE0D52}\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{B97D20BB-F46A-4C97-BA10-5E3608430854}'): 14,
#  ('FolderDescriptions',
#   '{B97D20BB-F46A-4C97-BA10-5E3608430854}',
#   'PropertyBag\n'): 1,
#  ('ShellCompatibility', 'Applications', 'helper.exe\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'Applications', 'shscrap.dll\n'): 1,
#  ('Explorer', 'CLSID', '{1F3427C8-5C10-4210-AA03-2EE45287D668}'): 2,
#  ('CLSID', '{1F3427C8-5C10-4210-AA03-2EE45287D668}', 'ShellFolder\n'): 3,
#  ('EncodingType 0',
#   'CryptSIPDllVerifyIndirectData',
#   '{1629F04E-2799-4DB5-8FE5-ACE10F17EBAB}\n'): 1,
#  ('SOFTWARE', 'Microsoft', 'Windows NT'): 2,
#  ('Windows NT', 'CurrentVersion', 'LanguagePack'): 1,
#  ('CurrentVersion', 'LanguagePack', 'SurrogateFallback\n'): 1,
#  ('Explorer', 'CLSID', '{DFFACDC5-679F-4156-8947-C5C76BC0B67F}'): 1,
#  ('CLSID', '{DFFACDC5-679F-4156-8947-C5C76BC0B67F}', 'ShellFolder\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', '.manifest', 'OpenWithList\n'): 1,
#  ('Classes', 'Applications', 'notepad.exe'): 3,
#  ('Applications', 'notepad.exe', 'shell\n'): 1,
#  ('regkey_opened_HKEY_LOCAL_MACHINE', 'SYSTEM', 'ControlSet001'): 2,
#  ('SYSTEM', 'ControlSet001', 'SERVICES'): 14,
#  ('ControlSet001', 'SERVICES', 'WinSock2'): 2,
#  ('SERVICES', 'WinSock2', 'Parameters'): 2,
#  ('WinSock2', 'Parameters', 'Protocol_Catalog9'): 2,
#  ('Parameters', 'Protocol_Catalog9', '00000005\n'): 1,
#  ('Providers', 'Trust', 'Initialization'): 2,
#  ('Trust', 'Initialization', '{00AAC56B-CD44-11D0-8CC2-00C04FC295EE}\n'): 1,
#  ('Classes', 'Applications', 'isoburn.exe'): 3,
#  ('Applications', 'isoburn.exe', '(Default)\n'): 1,
#  ('OID', 'EncodingType 0', 'TimeValidDllGetObject\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{B88F4DAA-E7BD-49A9-B74D-02885A5DC765}'): 14,
#  ('FolderDescriptions',
#   '{B88F4DAA-E7BD-49A9-B74D-02885A5DC765}',
#   'PropertyBag\n'): 1,
#  ('OID', 'EncodingType 0', 'CertDllVerifyCertificateChainPolicy\n'): 1,
#  ('EncodingType 0',
#   'CryptSIPDllVerifyIndirectData',
#   '{000C10F1-0000-0000-C000-000000000046}\n'): 1,
#  ('CurrentVersion', 'Explorer', 'Advanced\n'): 2,
#  ('Main', 'FeatureControl', 'FEATURE_FEEDS\n'): 1,
#  ('CurrentVersion', 'Explorer', 'User Shell Folders\n'): 2,
#  ('Classes', 'Applications', 'NTVDM.exe'): 2,
#  ('Applications', 'NTVDM.exe', 'shell\n'): 1,
#  ('AcroRD32.exe', 'shell', 'Read'): 5,
#  ('shell', 'Read', 'DropTarget\n'): 1,
#  ('regkey_opened_HKEY_LOCAL_MACHINE', 'SYSTEM', 'CurrentControlSet'): 4,
#  ('SYSTEM', 'CurrentControlSet', 'Services'): 4,
#  ('CurrentControlSet', 'Services', 'crypt32\n'): 1,
#  ('CurrentControlSet', 'Services', 'Winsock'): 2,
#  ('Services', 'Winsock', 'Parameters\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'Applications', 'cmd.exe\n'): 1,
#  ('regkey_opened_HKEY_LOCAL_MACHINE', 'Software', 'Adobe'): 2,
#  ('Software', 'Adobe', 'Adobe Acrobat'): 1,
#  ('Adobe', 'Adobe Acrobat', '11.0'): 1,
#  ('Adobe Acrobat', '11.0', 'Security\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{724EF170-A42D-4FEF-9F26-B60E846FBA4F}\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'Applications', 'awdvstub.exe\n'): 1,
#  ('GameUX', 'Games', '{AF698A5B-24D6-4F78-AE95-204B09EDC7B6}\n'): 1,
#  ('EncodingType 0',
#   'CryptSIPDllVerifyIndirectData',
#   '{06C9E010-38CE-11D4-A2A3-00104BD35090}\n'): 1,
#  ('regkey_opened_HKEY_CURRENT_USER', 'Software', 'Adobe'): 4,
#  ('Software', 'Adobe', 'CommonFiles'): 2,
#  ('Adobe', 'CommonFiles', 'Usage'): 2,
#  ('CommonFiles', 'Usage', 'Reader 11_Acrobat11_Reader_11.0.10\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'Applications', 'iexplore.exe\n'): 1,
#  ('CLSID', '{A4A1A128-768F-41E0-BF75-E4FDDD701CBA}', 'Progid\n'): 1,
#  ('MountPoints2', 'CPC', 'Volume\n'): 1,
#  ('Classes', 'Applications', 'iexplore.exe'): 6,
#  ('Applications', 'iexplore.exe', 'shell'): 3,
#  ('iexplore.exe', 'shell', 'open'): 2,
#  ('Microsoft', 'SystemCertificates', 'ChainEngine'): 1,
#  ('SystemCertificates', 'ChainEngine', 'Config\n'): 1,
#  ('SOFTWARE', 'Classes', 'Folder'): 4,
#  ('Classes', 'Folder', 'Clsid\n'): 1,
#  ('CurrentVersion', 'explorer', 'ShellIconOverlayIdentifiers'): 2,
#  ('explorer', 'ShellIconOverlayIdentifiers', 'SharingPrivate\n'): 1,
#  ('OID', 'EncodingType 1', 'CryptDllEncodeObjectEx'): 4,
#  ('EncodingType 1',
#   'CryptDllEncodeObjectEx',
#   '1.2.840.113549.1.9.16.2.11\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'Applications', 'cag.exe\n'): 1,
#  ('CurrentVersion', 'App Paths', 'AcroRd32.exe\n'): 2,
#  ('explorer',
#   'FolderDescriptions',
#   '{48DAF80B-E6CF-4F4E-B800-0E69D84EE384}'): 14,
#  ('FolderDescriptions',
#   '{48DAF80B-E6CF-4F4E-B800-0E69D84EE384}',
#   'PropertyBag\n'): 1,
#  ('Applications', 'iexplore.exe', 'shell\n'): 1,
#  ('ShellCompatibility',
#   'Objects',
#   '{1F3427C8-5C10-4210-AA03-2EE45287D668}\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{3214FAB5-9757-4298-BB61-92A9DEAA44FF}'): 9,
#  ('FolderDescriptions',
#   '{3214FAB5-9757-4298-BB61-92A9DEAA44FF}',
#   'PropertyBag\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{F38BF404-1D43-42F2-9305-67DE0B28FC23}'): 7,
#  ('FolderDescriptions',
#   '{F38BF404-1D43-42F2-9305-67DE0B28FC23}',
#   'PropertyBag\n'): 1,
#  ('Microsoft', 'Internet Explorer', 'Security\n'): 1,
#  ('CurrentVersion', 'Explorer', 'UsersFiles'): 2,
#  ('Explorer', 'UsersFiles', 'NameSpace'): 1,
#  ('UsersFiles', 'NameSpace', 'DelegateFolders\n'): 2,
#  ('Classes', 'AllFilesystemObjects', 'DocObject\n'): 1,
#  ('Applications', 'iexplore.exe', '(Default)\n'): 1,
#  ('regkey_opened_HKEY_CURRENT_USER', 'Software', 'Borland'): 1,
#  ('Software', 'Borland', 'Locales\n'): 1,
#  ('CLSID', '{A4A1A128-768F-41E0-BF75-E4FDDD701CBA}', 'InprocHandler\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{5CE4A5E9-E4EB-479D-B89F-130C02886155}\n'): 1,
#  ('Applications', 'mspaint.exe', 'shell'): 4,
#  ('mspaint.exe', 'shell', 'edit'): 3,
#  ('shell', 'edit', 'command\n'): 1,
#  ('regkey_opened_HKEY_LOCAL_MACHINE', 'Software', 'Classes'): 1,
#  ('Software', 'Classes', 'XMind Workbook'): 1,
#  ('Classes', 'XMind Workbook', 'DefaultIcon\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{F1B32785-6FBA-4FCF-9D55-7B8E7F157091}\n'): 1,
#  ('CommonFiles', 'Usage', 'Reader 11\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{D20BEEC4-5CA8-4905-AE3B-BF251EA09B53}\n'): 1,
#  ('Policies', 'Microsoft', 'Windows NT'): 1,
#  ('Microsoft', 'Windows NT', 'Rpc\n'): 1,
#  ('SystemFileAssociations', '.exe', 'ShellEx'): 1,
#  ('.exe', 'ShellEx', 'IconHandler\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{18989B1D-99B5-455B-841C-AB7C74E4DDFC}'): 15,
#  ('FolderDescriptions',
#   '{18989B1D-99B5-455B-841C-AB7C74E4DDFC}',
#   'PropertyBag\n'): 1,
#  ('Microsoft', 'CTF', 'KnownClasses\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'Applications', 'regedit.exe\n'): 1,
#  ('CTF', 'Compatibility', 'SandboxieInstall64.exe\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{48DAF80B-E6CF-4F4E-B800-0E69D84EE384}\n'): 1,
#  ('Software', 'Adobe', 'Adobe Synchronizer'): 1,
#  ('Adobe', 'Adobe Synchronizer', '11.0\n'): 1,
#  ('Providers', 'Trust', 'Cleanup'): 2,
#  ('Trust', 'Cleanup', '{00AAC56B-CD44-11D0-8CC2-00C04FC295EE}\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT',
#   'CLSID',
#   '{1F3427C8-5C10-4210-AA03-2EE45287D668}'): 2,
#  ('CLSID', '{1F3427C8-5C10-4210-AA03-2EE45287D668}', 'InProcServer32\n'): 1,
#  ('EncodingType 0',
#   'CryptSIPDllVerifyIndirectData',
#   '{603BCC1F-4B59-4E08-B724-D2C6297EF351}\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', '.exe', 'OpenWithProgids\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{18989B1D-99B5-455B-841C-AB7C74E4DDFC}\n'): 1,
#  ('Classes', 'Unknown', 'shell'): 3,
#  ('Unknown', 'shell', 'openas\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'Applications', 'oledb32.dll\n'): 1,
#  ('Explorer', 'FileExts', '.manifest\n'): 1,
#  ('Explorer', 'FileExts', '.bin\n'): 1,
#  ('Classes', 'Applications', 'wordpad.exe'): 2,
#  ('Applications', 'wordpad.exe', '(Default)\n'): 1,
#  ('Explorer', 'FileExts', '.bin'): 3,
#  ('FileExts', '.bin', 'UserChoice\n'): 1,
#  ('GameUX', 'Games', '{5FA410C1-1DD5-4238-833E-4DF9974FBC9C}\n'): 1,
#  ('Unknown', 'shell', 'openas'): 2,
#  ('shell', 'openas', 'command\n'): 1,
#  ('regkey_opened_HKEY_CURRENT_USER', 'Software', 'classes\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'Applications', 'wmplayer.exe\n'): 1,
#  ('Classes', 'Folder', 'DocObject\n'): 1,
#  ('Windows', 'CurrentVersion', 'Internet Settings\n'): 2,
#  ('ControlSet001', 'SERVICES', 'Winsock'): 3,
#  ('SERVICES', 'Winsock', 'Setup Migration'): 2,
#  ('Winsock', 'Setup Migration', 'Providers'): 2,
#  ('Setup Migration', 'Providers', 'Tcpip\n'): 1,
#  ('regkey_opened_HKEY_LOCAL_MACHINE',
#   'Software',
#   'fbd30ee5-8150-549e-9aed-fd9d444364fb\n'): 1,
#  ('Classes', 'AllFilesystemObjects', 'BrowseInPlace\n'): 2,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'Applications', 'sdclt.exe\n'): 1,
#  ('OID', 'EncodingType 1', 'CryptDllConvertPublicKeyInfo\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{FD228CB7-AE11-4AE3-864C-16F3910AB8FE}\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{BCBD3057-CA5C-4622-B42D-BC56DB0AE516}\n'): 1,
#  ('regkey_opened_HKEY_LOCAL_MACHINE',
#   'SOFTWARE',
#   'RegisteredApplications\n'): 1,
#  ('CurrentVersion', 'App Paths', 'installer.exe\n'): 1,
#  ('Classes', 'Folder', 'ShellEx'): 1,
#  ('Folder', 'ShellEx', 'PropertyHandler\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{BCB5256F-79F6-4CEE-B725-DC34E402FD46}'): 7,
#  ('FolderDescriptions',
#   '{BCB5256F-79F6-4CEE-B725-DC34E402FD46}',
#   'PropertyBag\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{7B396E54-9EC5-4300-BE0A-2482EBAE1A26}\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{C4900540-2379-4C75-844B-64E6FAF8716B}\n'): 1,
#  ('regkey_opened_HKEY_LOCAL_MACHINE', 'Software', 'Macromedia'): 2,
#  ('Software', 'Macromedia', 'FlashPlayerPlugin\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'Applications', 'themes.exe\n'): 1,
#  ('EncodingType 0',
#   'CryptSIPDllGetSignedDataMsg',
#   '{06C9E010-38CE-11D4-A2A3-00104BD35090}\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{A305CE99-F527-492B-8B1A-7E76FA98D6E4}\n'): 1,
#  ('GameUX', 'Games', '{1FE520E6-95FE-48A6-9956-D7FBC347A472}\n'): 1,
#  ('Applications', 'mspaint.exe', 'shell\n'): 1,
#  ('SOFTWARE', 'Classes', '.bin'): 6,
#  ('Classes', '.bin', 'BrowseInPlace\n'): 1,
#  ('CurrentVersion', 'Uninstall', 'Audacity_is1\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT',
#   'ExplorerCLSIDFlags',
#   '{66742402-F9B9-11D1-A202-0000F81FEDEE}\n'): 1,
#  ('Wow6432Node', 'Interface', '{6D5140C1-7436-11CE-8034-00AA006009FA}'): 1,
#  ('Interface',
#   '{6D5140C1-7436-11CE-8034-00AA006009FA}',
#   'ProxyStubClsid32\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{859EAD94-2E85-48AD-A71A-0969CB56A6CD}'): 10,
#  ('FolderDescriptions',
#   '{859EAD94-2E85-48AD-A71A-0969CB56A6CD}',
#   'PropertyBag\n'): 1,
#  ('GameUX', 'Games', '{AFA7FF39-1DDF-4F70-A2D5-23FCFFF02E5F}\n'): 1,
#  ('regkey_opened_HKEY_CURRENT_USER', 'bin_auto_file', 'DocObject\n'): 1,
#  ('SOFTWARE', 'Classes', 'TypeLib'): 5,
#  ('Classes', 'TypeLib', '{00020430-0000-0000-C000-000000000046}\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'Applications', 'grpconv.exe\n'): 1,
#  ('Explorer', 'FileExts', '.lnk'): 1,
#  ('FileExts', '.lnk', '(Default)\n'): 1,
#  ('OID', 'EncodingType 0', 'CryptSIPDllVerifyIndirectData\n'): 1,
#  ('regkey_opened_HKEY_CURRENT_USER', 'manifest_auto_file', 'Clsid\n'): 1,
#  ('Software', 'Macromedia', 'FlashPlayerPepper\n'): 1,
#  ('Services', 'Winsock', 'Setup Migration'): 1,
#  ('Winsock', 'Setup Migration', 'Providers\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT',
#   'CLSID',
#   '{ED228FDF-9EA8-4870-83B1-96B02CFE0D52}\n'): 1,
#  ('CurrentVersion', 'Policies', 'Associations\n'): 1,
#  ('Classes', 'lnkfile', 'ShellEx'): 1,
#  ('lnkfile', 'ShellEx', 'IconHandler\n'): 1,
#  ('Classes', 'exefile', 'BrowseInPlace\n'): 1,
#  ('regkey_opened_HKEY_LOCAL_MACHINE', 'System', 'Setup\n'): 1,
#  ('CurrentControlSet', 'Services', 'Tcpip6'): 1,
#  ('Services', 'Tcpip6', 'Parameters'): 1,
#  ('Tcpip6', 'Parameters', 'Winsock\n'): 1,
#  ('OID', 'EncodingType 1', 'CryptSIPDllGetSignedDataMsg\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{0762D272-C50A-4BB0-A382-697DCD729B80}'): 10,
#  ('FolderDescriptions',
#   '{0762D272-C50A-4BB0-A382-697DCD729B80}',
#   'PropertyBag\n'): 1,
#  ('Microsoft', 'Cryptography', 'TVO\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT',
#   'CLSID',
#   '{08244EE6-92F0-47F2-9FC9-929BAA2E7235}'): 1,
#  ('CLSID', '{08244EE6-92F0-47F2-9FC9-929BAA2E7235}', 'InProcServer32\n'): 1,
#  ('SOFTWARE', 'Clients', 'Contacts'): 2,
#  ('Clients', 'Contacts', 'Address Book'): 2,
#  ('Contacts', 'Address Book', 'Capabilities'): 2,
#  ('Address Book', 'Capabilities', 'FileAssociations\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'Applications', 'hh.exe\n'): 1,
#  ('Microsoft', 'SystemCertificates', 'Root'): 1,
#  ('SystemCertificates', 'Root', 'ProtectedRoots\n'): 1,
#  ('Classes', 'lnkfile', 'BrowseInPlace\n'): 1,
#  ('EncodingType 0',
#   'CryptSIPDllVerifyIndirectData',
#   '{1A610570-38CE-11D4-A2A3-00104BD35090}\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{054FAE61-4DD8-4787-80B6-090220C4B700}'): 11,
#  ('FolderDescriptions',
#   '{054FAE61-4DD8-4787-80B6-090220C4B700}',
#   'PropertyBag\n'): 1,
#  ('Wow6432Node', 'Microsoft', 'Windows Photo Viewer'): 1,
#  ('Microsoft', 'Windows Photo Viewer', 'Capabilities'): 1,
#  ('Windows Photo Viewer', 'Capabilities', 'FileAssociations\n'): 1,
#  ('regkey_opened_HKEY_CURRENT_USER', 'Software', 'Policies\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'Applications', 'MMC.exe\n'): 1,
#  ('Classes', 'Applications', 'WINWORD.EXE'): 3,
#  ('Applications', 'WINWORD.EXE', 'shell\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{2C36C0AA-5812-4B87-BFD0-4CD0DFB19B39}'): 7,
#  ('FolderDescriptions',
#   '{2C36C0AA-5812-4B87-BFD0-4CD0DFB19B39}',
#   'PropertyBag\n'): 1,
#  ('OID', 'EncodingType 1', 'CryptDllEncodeObjectEx\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{CAC52C1A-B53D-4EDC-92D7-6B2E8AC19434}\n'): 1,
#  ('EncodingType 1',
#   'CryptDllEncodeObjectEx',
#   '1.2.840.113549.1.9.16.2.12\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{5CE4A5E9-E4EB-479D-B89F-130C02886155}'): 9,
#  ('FolderDescriptions',
#   '{5CE4A5E9-E4EB-479D-B89F-130C02886155}',
#   'PropertyBag\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{C4AA340D-F20F-4863-AFEF-F87EF2E6BA25}'): 14,
#  ('FolderDescriptions',
#   '{C4AA340D-F20F-4863-AFEF-F87EF2E6BA25}',
#   'PropertyBag\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'SystemFileAssociations', '.lnk\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{69D2CF90-FC33-4FB7-9A0C-EBB0F0FCB43C}\n'): 1,
#  ('regkey_opened_HKEY_CURRENT_USER',
#   'Interface',
#   '{E7A1AF80-4D96-11CF-960C-0080C7F4EE85}\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{D20BEEC4-5CA8-4905-AE3B-BF251EA09B53}'): 8,
#  ('FolderDescriptions',
#   '{D20BEEC4-5CA8-4905-AE3B-BF251EA09B53}',
#   'PropertyBag\n'): 1,
#  ('OID', 'EncodingType 1', 'UrlDllGetObjectUrl\n'): 1,
#  ('Explorer', 'UsersFiles', 'NameSpace\n'): 1,
#  ('GameUX', 'Games', '{91CA4D38-EA2B-4F3C-94DE-36C1386182FC}\n'): 1,
#  ('EncodingType 1',
#   'CryptDllEncodeObjectEx',
#   '1.2.840.113549.1.9.16.2.3\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{5CD7AEE2-2219-4A67-B85D-6C9CE15660CB}\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{62AB5D82-FDC1-4DC3-A9DD-070D1D495D97}\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'Applications', 'isoburn.exe\n'): 1,
#  ('OID', 'EncodingType 0', 'CryptSIPDllPutSignedDataMsg\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{43668BF8-C14E-49B2-97C9-747784D784B7}'): 9,
#  ('FolderDescriptions',
#   '{43668BF8-C14E-49B2-97C9-747784D784B7}',
#   'PropertyBag\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT',
#   'CLSID',
#   '{D9144DCD-E998-4ECA-AB6A-DCD83CCBA16D}'): 1,
#  ('CLSID', '{D9144DCD-E998-4ECA-AB6A-DCD83CCBA16D}', 'InProcServer32\n'): 1,
#  ('CurrentVersion',
#   'Uninstall',
#   '{fbd30ee5-8150-549e-9aed-fd9d444364fb}\n'): 2,
#  ('SOFTWARE', 'Classes', '.manifest'): 7,
#  ('Classes', '.manifest', 'ShellEx'): 1,
#  ('.manifest', 'ShellEx', 'IconHandler\n'): 1,
#  ('Software', 'Microsoft', 'DirectUI\n'): 1,
#  ('Applications', 'ehshell.exe', 'shell'): 2,
#  ('ehshell.exe', 'shell', 'open'): 2,
#  ('Classes', 'Applications', 'python.exe'): 4,
#  ('Applications', 'python.exe', 'shell\n'): 1,
#  ('regkey_opened_HKEY_LOCAL_MACHINE', 'Software', 'Policies\n'): 1,
#  ('SystemFileAssociations', '.exe', 'BrowseInPlace\n'): 1,
#  ('regkey_opened_HKEY_LOCAL_MACHINE', 'Software', 'MozillaPlugins'): 1,
#  ('Software', 'MozillaPlugins', '@adobe.com/FlashPlayer\n'): 1,
#  ('Classes', 'TypeLib', '{50A7E9B0-70EF-11D1-B75A-00A0C90564FE}'): 2,
#  ('TypeLib', '{50A7E9B0-70EF-11D1-B75A-00A0C90564FE}', '1.0\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{FDD39AD0-238F-46AF-ADB4-6C85480369C7}'): 12,
#  ('FolderDescriptions',
#   '{FDD39AD0-238F-46AF-ADB4-6C85480369C7}',
#   'PropertyBag\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'xmind-zen', 'DefaultIcon\n'): 1,
#  ('Classes', '.manifest', 'BrowseInPlace\n'): 1,
#  ('CurrentVersion', 'Explorer', 'Taskband\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{2112AB0A-C86A-4FFE-A368-0DE96E47012E}\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{C5ABBF53-E17F-4121-8900-86626FC2C973}'): 13,
#  ('FolderDescriptions',
#   '{C5ABBF53-E17F-4121-8900-86626FC2C973}',
#   'PropertyBag\n'): 1,
#  ('EncodingType 1',
#   'CryptDllEncodeObjectEx',
#   '1.2.840.113549.1.9.16.2.1\n'): 1,
#  ('Wow6432Node', 'Microsoft', 'IsoBurn'): 1,
#  ('Microsoft', 'IsoBurn', 'Capabilities'): 1,
#  ('IsoBurn', 'Capabilities', 'FileAssociations\n'): 1,
#  ('OID', 'EncodingType 0', 'CertDllCreateCertificateChainEngine'): 9,
#  ('EncodingType 0', 'CertDllCreateCertificateChainEngine', 'Config\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{7C5A40EF-A0FB-4BFC-874A-C0F2E0B9FA8E}'): 10,
#  ('FolderDescriptions',
#   '{7C5A40EF-A0FB-4BFC-874A-C0F2E0B9FA8E}',
#   'PropertyBag\n'): 1,
#  ('GameUX', 'Games', '{00D8862B-6453-4957-A821-3D98D74C76BE}\n'): 1,
#  ('CurrentControlSet', 'Services', 'SbieDrv\n'): 1,
#  ('Software', 'Adobe', 'Acrobat Reader'): 2,
#  ('Acrobat Reader', '11.0', 'AVGeneral\n'): 1,
#  ('CPC', 'Volume', '{3ffe1cfc-3eb4-11ea-9e4c-806e6f6e6963}'): 2,
#  ('Volume', '{3ffe1cfc-3eb4-11ea-9e4c-806e6f6e6963}', '\n'): 1,
#  ('iexplore.exe', 'shell', 'open\n'): 1,
#  ('Wow6432Node', 'Microsoft', 'Internet Explorer'): 7,
#  ('Microsoft', 'Internet Explorer', 'MAIN'): 4,
#  ('Internet Explorer', 'MAIN', 'FeatureControl'): 4,
#  ('MAIN', 'FeatureControl', 'Feature_Enable_Compat_Logging\n'): 1,
#  ('SessionInfo', '1', 'UsersFiles'): 1,
#  ('1', 'UsersFiles', 'NameSpace'): 1,
#  ('Providers', 'Trust', 'FinalPolicy'): 1,
#  ('Trust', 'FinalPolicy', '{00AAC56B-CD44-11D0-8CC2-00C04FC295EE}\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'Applications', 'wmpdmc.exe\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'Applications', 'WB32.EXE\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{DE61D971-5EBC-4F02-A3A9-6C82895E5C04}\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'Applications', 'finder.exe\n'): 1,
#  ('Windows NT', 'CurrentVersion', 'PeerDist'): 1,
#  ('CurrentVersion', 'PeerDist', 'Service\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{3EB685DB-65F9-4CF6-A03A-E3EF65729F3D}'): 15,
#  ('FolderDescriptions',
#   '{3EB685DB-65F9-4CF6-A03A-E3EF65729F3D}',
#   'PropertyBag\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{AE50C081-EBD2-438A-8655-8A092E34987A}\n'): 1,
#  ('Microsoft', 'Windows NT', 'CurrentVersion\n'): 2,
#  ('Classes', 'TypeLib', '{00020430-0000-0000-C000-000000000046}'): 2,
#  ('TypeLib', '{00020430-0000-0000-C000-000000000046}', '2.0'): 2,
#  ('{00020430-0000-0000-C000-000000000046}', '2.0', '0\n'): 1,
#  ('Acrobat Reader', '11.0', 'Installer\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{DEBF2536-E1A8-4C59-B6A2-414586476AEA}'): 12,
#  ('FolderDescriptions',
#   '{DEBF2536-E1A8-4C59-B6A2-414586476AEA}',
#   'PropertyBag\n'): 1,
#  ('regkey_opened_HKEY_CURRENT_USER',
#   'Interface',
#   '{6D5140C1-7436-11CE-8034-00AA006009FA}\n'): 1,
#  ('Software', 'Microsoft', 'OLE'): 1,
#  ('Microsoft', 'OLE', 'Tracing\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'SystemFileAssociations', 'system'): 1,
#  ('SystemFileAssociations', 'system', 'OpenWithList\n'): 1,
#  ('Classes', 'Applications', 'AcroRd32.exe\n'): 1,
#  ('AcroRD32.exe', 'shell', 'open\n'): 1,
#  ('Software', 'Microsoft', 'Tracing'): 1,
#  ('Microsoft', 'Tracing', 'RASMANCS\n'): 1,
#  ('Policies', 'Microsoft', 'Windows'): 11,
#  ('Microsoft', 'Windows', 'Explorer\n'): 1,
#  ('OID', 'EncodingType 1', 'CryptDllImportPublicKeyInfoEx2\n'): 1,
#  ('FileExts', '.manifest', '(Default)\n'): 1,
#  ('Microsoft', 'Windows', 'System\n'): 1,
#  ('SOFTWARE', 'Microsoft', 'Internet Explorer'): 1,
#  ('Microsoft', 'Internet Explorer', 'Capabilities\n'): 1,
#  ('Drive', 'shellex', 'FolderExtensions'): 2,
#  ('shellex',
#   'FolderExtensions',
#   '{fbeb8a05-beee-4442-804e-409d6c4515e9}\n'): 1,
#  ('CurrentControlSet', 'Control', 'LSA'): 1,
#  ('Control', 'LSA', 'AccessProviders\n'): 1,
#  ('regkey_opened_HKEY_CURRENT_USER', 'manifest_auto_file', '(Default)\n'): 1,
#  ('CurrentControlSet', 'Services', 'LanmanWorkstation'): 1,
#  ('Services', 'LanmanWorkstation', 'Parameters\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{A63293E8-664E-48DB-A079-DF759E0509F7}\n'): 1,
#  ('FileExts', '.exe', 'UserChoice\n'): 1,
#  ('regkey_opened_HKEY_CURRENT_USER', 'Local Settings', 'Software'): 1,
#  ('Local Settings', 'Software', 'Microsoft'): 9,
#  ('Windows', 'Shell', 'MuiCache'): 9,
#  ('Shell', 'MuiCache', '(Default)\n'): 1,
#  ('CurrentVersion', 'Explorer', 'StartPage\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{905E63B6-C1BF-494E-B29C-65B732D3D21A}'): 11,
#  ('FolderDescriptions',
#   '{905E63B6-C1BF-494E-B29C-65B732D3D21A}',
#   'PropertyBag\n'): 1,
#  ('Windows', 'CurrentVersion', 'WinTrust'): 1,
#  ('CurrentVersion', 'WinTrust', 'Trust Providers'): 1,
#  ('WinTrust', 'Trust Providers', 'Software Publishing\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{DE61D971-5EBC-4F02-A3A9-6C82895E5C04}'): 10,
#  ('FolderDescriptions',
#   '{DE61D971-5EBC-4F02-A3A9-6C82895E5C04}',
#   'PropertyBag\n'): 1,
#  ('Windows', 'CurrentVersion', 'Explorer\n'): 1,
#  ('Classes', '.manifest', 'Clsid\n'): 1,
#  ('ShellCompatibility',
#   'Objects',
#   '{D9144DCD-E998-4ECA-AB6A-DCD83CCBA16D}\n'): 1,
#  ('Explorer', 'FileExts', '.exe\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'Applications', 'shell32.dll\n'): 1,
#  ('Classes', 'lnkfile', 'CurVer\n'): 1,
#  ('OID', 'EncodingType 1', 'TimeValidDllGetObject\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{BFB9D5E0-C6A9-404C-B2B2-AE6DB6AF4968}\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'ES', 'shell'): 1,
#  ('ES', 'shell', 'open'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{1777F761-68AD-4D8A-87BD-30B759FA33DD}\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{BFB9D5E0-C6A9-404C-B2B2-AE6DB6AF4968}'): 11,
#  ('FolderDescriptions',
#   '{BFB9D5E0-C6A9-404C-B2B2-AE6DB6AF4968}',
#   'PropertyBag\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT',
#   'CLSID',
#   '{DFFACDC5-679F-4156-8947-C5C76BC0B67F}'): 1,
#  ('CLSID', '{DFFACDC5-679F-4156-8947-C5C76BC0B67F}', 'InProcServer32\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{0139D44E-6AFE-49F2-8690-3DAFCAE6FFB8}\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{1777F761-68AD-4D8A-87BD-30B759FA33DD}'): 11,
#  ('FolderDescriptions',
#   '{1777F761-68AD-4D8A-87BD-30B759FA33DD}',
#   'PropertyBag\n'): 1,
#  ('regkey_opened_HKEY_CURRENT_USER', 'bin_auto_file', '(Default)\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'Applications', 'snapview.exe\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'Applications', 'ISIGNUP.EXE\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{190337D1-B8CA-4121-A639-6D472D16972A}\n'): 1,
#  ('regkey_opened_HKEY_CLASSES_ROOT', 'Applications', 'graflink.exe\n'): 1,
#  ('Software', 'Microsoft', 'Windows Search'): 1,
#  ('Microsoft', 'Windows Search', 'Capabilities\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{82A5EA35-D9CD-47C5-9629-E15D2F714E6E}'): 15,
#  ('FolderDescriptions',
#   '{82A5EA35-D9CD-47C5-9629-E15D2F714E6E}',
#   'PropertyBag\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{D65231B0-B2F1-4857-A4CE-A8E7C6EA7D27}'): 13,
#  ('FolderDescriptions',
#   '{D65231B0-B2F1-4857-A4CE-A8E7C6EA7D27}',
#   'PropertyBag\n'): 1,
#  ('Microsoft', 'Internet Explorer', 'Capabilities'): 2,
#  ('Internet Explorer', 'Capabilities', 'FileAssociations\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{C5ABBF53-E17F-4121-8900-86626FC2C973}\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{A75D362E-50FC-4FB7-AC2C-A8BEAA314493}'): 12,
#  ('FolderDescriptions',
#   '{A75D362E-50FC-4FB7-AC2C-A8BEAA314493}',
#   'PropertyBag\n'): 1,
#  ('Windows', 'CurrentVersion', 'Applets'): 2,
#  ('CurrentVersion', 'Applets', 'Paint'): 1,
#  ('Applets', 'Paint', 'Capabilities'): 1,
#  ('Paint', 'Capabilities', 'FileAssociations\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{9E3995AB-1F9C-4F13-B827-48B24B6C7174}\n'): 1,
#  ('regkey_opened_HKEY_LOCAL_MACHINE', 'SOFTWARE', 'MICROSOFT'): 1,
#  ('SOFTWARE', 'MICROSOFT', 'WINDOWS NT'): 24,
#  ('MICROSOFT', 'WINDOWS NT', 'CURRENTVERSION'): 24,
#  ('WINDOWS NT', 'CURRENTVERSION', 'LanguagePack'): 2,
#  ('CURRENTVERSION', 'LanguagePack', 'SurrogateFallback'): 2,
#  ('LanguagePack', 'SurrogateFallback', 'MS Sans Serif\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{B4BFCC3A-DB2C-424C-B029-7FE99A87C641}'): 10,
#  ('FolderDescriptions',
#   '{B4BFCC3A-DB2C-424C-B029-7FE99A87C641}',
#   'PropertyBag\n'): 1,
#  ('CurrentVersion',
#   'Uninstall',
#   '{E2CAA395-66B3-4772-85E3-6134DBAB244E}\n'): 1,
#  ('AllFilesystemObjects', 'ShellEx', 'PropertyHandler\n'): 1,
#  ('regkey_read_HKEY_LOCAL_MACHINE', 'SOFTWARE', 'Wow6432Node'): 1091,
#  ('FolderDescriptions',
#   '{CAC52C1A-B53D-4EDC-92D7-6B2E8AC19434}',
#   'ParentFolder\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{EE32E446-31CA-4ABA-814F-A5EBD2FD6D5E}'): 14,
#  ('FolderDescriptions',
#   '{EE32E446-31CA-4ABA-814F-A5EBD2FD6D5E}',
#   'Roamable\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{A63293E8-664E-48DB-A079-DF759E0509F7}'): 9,
#  ('FolderDescriptions',
#   '{A63293E8-664E-48DB-A079-DF759E0509F7}',
#   'PublishExpandedPath\n'): 1,
#  ('regkey_read_HKEY_LOCAL_MACHINE', 'SOFTWARE', 'Classes'): 182,
#  ('Wow6432Node', 'CLSID', '{1F3427C8-5C10-4210-AA03-2EE45287D668}'): 6,
#  ('CLSID', '{1F3427C8-5C10-4210-AA03-2EE45287D668}', 'ShellFolder'): 5,
#  ('{1F3427C8-5C10-4210-AA03-2EE45287D668}',
#   'ShellFolder',
#   'HideOnDesktopPerUser\n'): 1,
#  ('FolderDescriptions',
#   '{B4BFCC3A-DB2C-424C-B029-7FE99A87C641}',
#   'ParsingName\n'): 1,
#  ('regkey_read_HKEY_LOCAL_MACHINE', 'SOFTWARE', 'MICROSOFT'): 65,
#  ('WINDOWS NT', 'CURRENTVERSION', 'FontSubstitutes'): 19,
#  ('CURRENTVERSION', 'FontSubstitutes', 'Tahoma Armenian\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{8983036C-27C0-404B-8F08-102D10DCFD74}'): 11,
#  ('FolderDescriptions',
#   '{8983036C-27C0-404B-8F08-102D10DCFD74}',
#   'Attributes\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{4C5C32FF-BB9D-43B0-B5B4-2D72E54EAAA4}'): 14,
#  ('FolderDescriptions',
# ...
#  ('Applications', 'ISIGNUP.EXE', 'NoOpenWith\n'): 1,
#  ('FolderDescriptions',
#   '{2400183A-6185-49FB-A2D8-4A392A602BA3}',
#   'Description\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{D0384E7D-BAC3-4797-8F14-CBA229B392B5}'): 11,
#  ('FolderDescriptions',
#   '{D0384E7D-BAC3-4797-8F14-CBA229B392B5}',
#   'Description\n'): 1,
#  ('FolderDescriptions',
#   '{DE61D971-5EBC-4F02-A3A9-6C82895E5C04}',
#   'InfoTip\n'): 1,
#  ('FolderDescriptions',
#   '{905E63B6-C1BF-494E-B29C-65B732D3D21A}',
#   'RelativePath\n'): 1,
#  ('FolderDescriptions', '{C4AA340D-F20F-4863-AFEF-F87EF2E6BA25}', 'Name\n'): 1,
#  ('{CEBFF5CD-ACE2-4F4F-9178-9926F41749EA}',
#   'Count',
#   '{7P5N40RS-N0SO-4OSP-874N-P0S2R0O9SN8R}'): 3,
#  ('Count', '{7P5N40RS-N0SO-4OSP-874N-P0S2R0O9SN8R}', '360'): 2,
#  ('{7P5N40RS-N0SO-4OSP-874N-P0S2R0O9SN8R}', '360', '360mvc'): 2,
#  ('360', '360mvc', '360mvc.rkr\n'): 1,
#  ('CurrentVersion', 'Explorer', 'Advanced'): 12,
#  ('Explorer', 'Advanced', 'ShowSuperHidden\n'): 1,
#  ('Nls', 'CustomLocale', 'pt\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{8AD10C31-2ADB-4296-A8F7-E4701232C972}'): 8,
#  ('FolderDescriptions',
#   '{8AD10C31-2ADB-4296-A8F7-E4701232C972}',
#   'Roamable\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{FD228CB7-AE11-4AE3-864C-16F3910AB8FE}'): 12,
#  ('FolderDescriptions',
#   '{FD228CB7-AE11-4AE3-864C-16F3910AB8FE}',
#   'ParsingName\n'): 1,
#  ('FolderDescriptions',
#   '{DEBF2536-E1A8-4C59-B6A2-414586476AEA}',
#   'Security\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{A520A1A4-1780-4FF6-BD18-167343C5AF16}'): 8,
#  ('FolderDescriptions', '{A520A1A4-1780-4FF6-BD18-167343C5AF16}', 'Name\n'): 1,
#  ('Nls', 'ExtendedLocale', 'zh-Hans\n'): 1,
#  ('FolderDescriptions',
#   '{C4AA340D-F20F-4863-AFEF-F87EF2E6BA25}',
#   'StreamResourceType\n'): 1,
#  ('FolderDescriptions',
#   '{859EAD94-2E85-48AD-A71A-0969CB56A6CD}',
#   'Security\n'): 1,
#  ('Nls', 'ExtendedLocale', 'gl\n'): 1,
#  ('Wow6432Node', 'CLSID', '{59031A47-3F72-44A7-89C5-5595FE6B30EE}'): 11,
#  ('CLSID', '{59031A47-3F72-44A7-89C5-5595FE6B30EE}', 'ShellFolder'): 11,
#  ('{59031A47-3F72-44A7-89C5-5595FE6B30EE}',
#   'ShellFolder',
#   'WantsFORPARSING\n'): 1,
#  ('FolderDescriptions',
#   '{3EB685DB-65F9-4CF6-A03A-E3EF65729F3D}',
#   'ParentFolder\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{A302545D-DEFF-464B-ABE8-61C8648D939B}'): 15,
#  ('FolderDescriptions',
#   '{A302545D-DEFF-464B-ABE8-61C8648D939B}',
#   'InfoTip\n'): 1,
#  ('FolderDescriptions',
#   '{F7F1ED05-9F6D-47A2-AAAE-29D317C6F066}',
#   'Stream\n'): 1,
#  ('FolderDescriptions',
#   '{D0384E7D-BAC3-4797-8F14-CBA229B392B5}',
#   'InitFolderHandler\n'): 1,
#  ('FolderDescriptions',
#   '{B97D20BB-F46A-4C97-BA10-5E3608430854}',
#   'ParentFolder\n'): 1,
#  ('FolderDescriptions',
#   '{A4115719-D62E-491D-AA7C-E74B8BE3B067}',
#   'StreamResource\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{76FC4E2D-D6AD-4519-A663-37BD56068185}'): 10,
#  ('FolderDescriptions',
#   '{76FC4E2D-D6AD-4519-A663-37BD56068185}',
#   'ParsingName\n'): 1,
#  ('Nls', 'ExtendedLocale', 'fo-FO\n'): 1,
#  ('FolderDescriptions',
#   '{FDD39AD0-238F-46AF-ADB4-6C85480369C7}',
#   'Category\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{B7534046-3ECB-4C18-BE4E-64CD4CB7D6AC}'): 13,
#  ('FolderDescriptions', '{B7534046-3ECB-4C18-BE4E-64CD4CB7D6AC}', 'Icon\n'): 1,
#  ('Count', '{1NP14R77-02R7-4R5Q-O744-2RO1NR5198O7}', 'vfpfvpcy.rkr\n'): 1,
#  ('Nls', 'ExtendedLocale', 'fi-FI\n'): 1,
#  ('Nls', 'ExtendedLocale', 'hsb\n'): 1,
#  ('FolderDescriptions',
#   '{DFDF76A2-C82A-4D63-906A-5644AC457385}',
#   'StreamResource\n'): 1,
#  ('FolderDescriptions',
#   '{FDD39AD0-238F-46AF-ADB4-6C85480369C7}',
#   'RelativePath\n'): 1,
#  ('FolderDescriptions',
#   '{A75D362E-50FC-4FB7-AC2C-A8BEAA314493}',
#   'PreCreate\n'): 1,
#  ('FolderDescriptions',
#   '{C870044B-F49E-4126-A9C3-B52A1FF411E8}',
#   'Stream\n'): 1,
#  ('FolderDescriptions',
#   '{0139D44E-6AFE-49F2-8690-3DAFCAE6FFB8}',
#   'LocalRedirectOnly\n'): 1,
#  ('Nls', 'CustomLocale', 'prs\n'): 1,
#  ('Nls', 'CustomLocale', 'id\n'): 1,
#  ('FolderDescriptions', '{F3CE0F7C-4901-4ACC-8648-D5D44B04EF8F}', 'Icon\n'): 1,
#  ('SOFTWARE', 'MICROSOFT', 'Windows'): 34,
#  ('MICROSOFT', 'Windows', 'CurrentVersion'): 34,
#  ('CurrentVersion', 'App Paths', 'AcroRd32.exe'): 3,
#  ('App Paths', 'AcroRd32.exe', 'UseShortName\n'): 1,
#  ('FolderDescriptions',
#   '{E555AB60-153B-4D17-9F04-A5FE99FC15EC}',
#   'Roamable\n'): 1,
#  ('ControlSet001', 'Control', 'LsaExtensionConfig'): 1,
#  ('Control', 'LsaExtensionConfig', 'SspiCli'): 1,
#  ('LsaExtensionConfig', 'SspiCli', 'CheckSignatureDll\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{A77F5D77-2E2B-44C3-A6A2-ABA601054A51}'): 9,
#  ('FolderDescriptions',
#   '{A77F5D77-2E2B-44C3-A6A2-ABA601054A51}',
#   'StreamResourceType\n'): 1,
#  ('FolderDescriptions',
#   '{3214FAB5-9757-4298-BB61-92A9DEAA44FF}',
#   'FolderTypeID\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{491E922F-5643-4AF4-A7EB-4E7A138D8174}'): 9,
#  ('FolderDescriptions',
#   '{491E922F-5643-4AF4-A7EB-4E7A138D8174}',
#   'Security\n'): 1,
#  ('FolderDescriptions',
#   '{C870044B-F49E-4126-A9C3-B52A1FF411E8}',
#   'InitFolderHandler\n'): 1,
#  ('{CEBFF5CD-ACE2-4F4F-9178-9926F41749EA}', 'Count', 'P:'): 4,
#  ('Count', 'P:', 'Clguba27'): 1,
#  ('P:', 'Clguba27', 'clgubaj.rkr\n'): 1,
#  ('FolderDescriptions',
#   '{A75D362E-50FC-4FB7-AC2C-A8BEAA314493}',
#   'RelativePath\n'): 1,
#  ('Nls', 'ExtendedLocale', 'moh\n'): 1,
#  ('Explorer', 'Advanced', 'Start_MinMFU\n'): 1,
#  ('ControlSet001', 'Control', 'Lsa'): 6,
#  ('Control', 'Lsa', 'SspiCache'): 4,
#  ('Lsa', 'SspiCache', 'credssp.dll'): 4,
#  ('SspiCache', 'credssp.dll', 'Type\n'): 1,
#  ('FolderDescriptions',
#   '{52A4F021-7B75-48A9-9F6B-4B87A210BC8F}',
#   'RelativePath\n'): 1,
#  ('{F4E57C4B-2036-45F0-A9AB-443BCFE33D9F}',
#   'Count',
#   '::{RQ228SQS-9RN8-4870-83O1-96O02PSR0Q52}'): 4,
#  ('Count',
#   '::{RQ228SQS-9RN8-4870-83O1-96O02PSR0Q52}',
#   '{5SN410P1-1QQ5-4238-833R-4QS9974SOP9P}\n'): 1,
#  ('MAIN', 'FeatureControl', 'FEATURE_MIME_SNIFFING'): 1,
#  ('FeatureControl', 'FEATURE_MIME_SNIFFING', 'wscript.exe\n'): 1,
#  ('SspiCache', 'credssp.dll', 'Capabilities\n'): 1,
#  ('regkey_read_HKEY_CURRENT_USER', 'Local Settings', 'MuiCache'): 34,
#  ('Local Settings', 'MuiCache', '4'): 35,
#  ('MuiCache', '4', '52C64B7E'): 35,
#  ('4', '52C64B7E', '@C:'): 33,
#  ('52C64B7E', '@C:', 'Windows'): 30,
#  ('@C:', 'Windows', 'system32'): 28,
#  ('Windows', 'system32', 'mblctr.exe,-1008\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{B94237E7-57AC-4347-9151-B08C6C32D1F7}'): 9,
#  ('FolderDescriptions',
#   '{B94237E7-57AC-4347-9151-B08C6C32D1F7}',
#   'PublishExpandedPath\n'): 1,
#  ('FolderDescriptions',
#   '{0762D272-C50A-4BB0-A382-697DCD729B80}',
#   'Description\n'): 1,
#  ('{CEBFF5CD-ACE2-4F4F-9178-9926F41749EA}',
#   'Count',
#   '{6Q809377-6NS0-444O-8957-N3773S02200R}'): 8,
#  ('Count', '{6Q809377-6NS0-444O-8957-N3773S02200R}', 'Jvaqbjf Wbheany'): 1,
#  ('{6Q809377-6NS0-444O-8957-N3773S02200R}',
#   'Jvaqbjf Wbheany',
#   'Wbheany.rkr\n'): 1,
#  ('CurrentVersion', 'Explorer', 'User Shell Folders'): 9,
#  ('Explorer', 'User Shell Folders', 'My Music\n'): 1,
#  ('Explorer', 'Advanced', 'IconsOnly\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{52528A6B-B9E3-4ADD-B60D-588C2DBA842D}'): 12,
#  ('FolderDescriptions',
#   '{52528A6B-B9E3-4ADD-B60D-588C2DBA842D}',
#   'LocalRedirectOnly\n'): 1,
#  ('FolderDescriptions', '{EE32E446-31CA-4ABA-814F-A5EBD2FD6D5E}', 'Icon\n'): 1,
#  ('FolderDescriptions',
#   '{724EF170-A42D-4FEF-9F26-B60E846FBA4F}',
#   'Security\n'): 1,
#  ('FolderDescriptions',
#   '{9E3995AB-1F9C-4F13-B827-48B24B6C7174}',
#   'Stream\n'): 1,
#  ('Control', 'Nls', 'Language Groups'): 10,
#  ('Nls', 'Language Groups', '4\n'): 1,
#  ('FolderDescriptions',
#   '{B7534046-3ECB-4C18-BE4E-64CD4CB7D6AC}',
#   'LocalRedirectOnly\n'): 1,
#  ('Nls', 'CustomLocale', 'ar\n'): 1,
#  ('FolderDescriptions',
#   '{7C5A40EF-A0FB-4BFC-874A-C0F2E0B9FA8E}',
#   'ParentFolder\n'): 1,
#  ('FolderDescriptions',
#   '{C870044B-F49E-4126-A9C3-B52A1FF411E8}',
#   'StreamResourceType\n'): 1,
#  ('{59031A47-3F72-44A7-89C5-5595FE6B30EE}',
#   'ShellFolder',
#   'QueryForInfoTip\n'): 1,
#  ('Nls', 'ExtendedLocale', 'sv-SE\n'): 1,
#  ('FolderDescriptions',
#   '{3EB685DB-65F9-4CF6-A03A-E3EF65729F3D}',
#   'FolderTypeID\n'): 1,
#  ('FolderDescriptions',
#   '{98EC0E18-2098-4D44-8644-66979315A281}',
#   'Stream\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{DE974D24-D9C6-4D3E-BF91-F4455120B917}'): 11,
#  ('FolderDescriptions',
#   '{DE974D24-D9C6-4D3E-BF91-F4455120B917}',
#   'Category\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{15CA69B3-30EE-49C1-ACE1-6B5EC372AFB5}'): 15,
#  ('FolderDescriptions',
#   '{15CA69B3-30EE-49C1-ACE1-6B5EC372AFB5}',
#   'InitFolderHandler\n'): 1,
#  ('Count', 'P:', 'Hfref'): 4,
#  ('P:', 'Hfref', 'arjg'): 3,
#  ('Hfref', 'arjg', 'Qbjaybnqf'): 2,
#  ('arjg',
#   'Qbjaybnqf',
#   'Frghc_100100507_3112578_68747470733n2s2s68616s2r3336302r636r2s3s7372633q6p6q266p733q6r30353635323035383963.rkr\n'): 1,
#  ('FolderDescriptions',
#   '{7C5A40EF-A0FB-4BFC-874A-C0F2E0B9FA8E}',
#   'LocalRedirectOnly\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{1B3EA5DC-B587-4786-B4EF-BD1DC332AEAE}'): 12,
#  ('FolderDescriptions', '{1B3EA5DC-B587-4786-B4EF-BD1DC332AEAE}', 'Name\n'): 1,
#  ('Control', 'Nls', 'Locale'): 52,
#  ('Nls', 'Locale', '0000043F\n'): 1,
#  ('Nls', 'CustomLocale', 'si\n'): 1,
#  ('FolderDescriptions',
#   '{B4BFCC3A-DB2C-424C-B029-7FE99A87C641}',
#   'LocalRedirectOnly\n'): 1,
#  ('FolderDescriptions',
#   '{98EC0E18-2098-4D44-8644-66979315A281}',
#   'LocalizedName\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{5CD7AEE2-2219-4A67-B85D-6C9CE15660CB}'): 7,
#  ('FolderDescriptions',
#   '{5CD7AEE2-2219-4A67-B85D-6C9CE15660CB}',
#   'ParentFolder\n'): 1,
#  ('FolderDescriptions',
#   '{8983036C-27C0-404B-8F08-102D10DCFD74}',
#   'FolderTypeID\n'): 1,
#  ('FolderDescriptions',
#   '{18989B1D-99B5-455B-841C-AB7C74E4DDFC}',
#   'Stream\n'): 1,
#  ('Nls', 'ExtendedLocale', 'yo\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{2112AB0A-C86A-4FFE-A368-0DE96E47012E}'): 12,
#  ('FolderDescriptions',
#   '{2112AB0A-C86A-4FFE-A368-0DE96E47012E}',
#   'StreamResourceType\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{10C07CD0-EF91-4567-B850-448B77CB37F9}'): 11,
#  ('FolderDescriptions',
#   '{10C07CD0-EF91-4567-B850-448B77CB37F9}',
#   'LocalizedName\n'): 1,
#  ('FolderDescriptions',
#   '{A63293E8-664E-48DB-A079-DF759E0509F7}',
#   'StreamResourceType\n'): 1,
#  ('FolderDescriptions',
#   '{B97D20BB-F46A-4C97-BA10-5E3608430854}',
#   'LocalRedirectOnly\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{5E6C858F-0E22-4760-9AFE-EA3317B67173}'): 8,
#  ('FolderDescriptions',
#   '{5E6C858F-0E22-4760-9AFE-EA3317B67173}',
#   'LocalRedirectOnly\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{9274BD8D-CFD1-41C3-B35E-B13F55A758F4}'): 12,
#  ('FolderDescriptions',
#   '{9274BD8D-CFD1-41C3-B35E-B13F55A758F4}',
#   'ParsingName\n'): 1,
#  ('FolderDescriptions',
#   '{69D2CF90-FC33-4FB7-9A0C-EBB0F0FCB43C}',
#   'ParentFolder\n'): 1,
#  ('Nls', 'CustomLocale', 'syr-SY\n'): 1,
#  ('FolderDescriptions',
#   '{3EB685DB-65F9-4CF6-A03A-E3EF65729F3D}',
#   'Category\n'): 1,
#  ('FolderDescriptions',
#   '{A75D362E-50FC-4FB7-AC2C-A8BEAA314493}',
#   'StreamResource\n'): 1,
#  ('CurrentVersion', 'explorer', 'User Shell Folders'): 4,
#  ('explorer', 'User Shell Folders', 'Common Startup\n'): 1,
#  ('Wow6432Node', 'CLSID', '{ED228FDF-9EA8-4870-83B1-96B02CFE0D52}'): 9,
#  ('CLSID', '{ED228FDF-9EA8-4870-83B1-96B02CFE0D52}', 'ShellFolder'): 7,
#  ('{ED228FDF-9EA8-4870-83B1-96B02CFE0D52}',
#   'ShellFolder',
#   'HideFolderVerbs\n'): 1,
#  ('Nls', 'ExtendedLocale', 'te-IN\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{7D1D3A04-DEBB-4115-95CF-2F29DA2920DA}'): 13,
#  ('FolderDescriptions',
#   '{7D1D3A04-DEBB-4115-95CF-2F29DA2920DA}',
#   'PreCreate\n'): 1,
#  ('CurrentVersion', 'Explorer', 'Taskband'): 1,
#  ('Explorer', 'Taskband', 'FavoritesChanges\n'): 1,
#  ('Nls', 'ExtendedLocale', 'rw-RW\n'): 1,
#  ('FolderDescriptions',
#   '{D0384E7D-BAC3-4797-8F14-CBA229B392B5}',
#   'ParsingName\n'): 1,
#  ('regkey_read_HKEY_CURRENT_USER', 'Keyboard Layout', 'Preload'): 1,
#  ('Keyboard Layout', 'Preload', '1\n'): 1,
#  ('FolderDescriptions',
#   '{98EC0E18-2098-4D44-8644-66979315A281}',
#   'FolderTypeID\n'): 1,
#  ('Nls', 'ExtendedLocale', 'km-KH\n'): 1,
#  ('FolderDescriptions',
#   '{9E3995AB-1F9C-4F13-B827-48B24B6C7174}',
#   'RelativePath\n'): 1,
#  ('FolderDescriptions', '{C5ABBF53-E17F-4121-8900-86626FC2C973}', 'Name\n'): 1,
#  ('FolderDescriptions',
#   '{2112AB0A-C86A-4FFE-A368-0DE96E47012E}',
#   'ParsingName\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{2B0F765D-C0E9-4171-908E-08A611B84FF6}'): 10,
#  ('FolderDescriptions',
#   '{2B0F765D-C0E9-4171-908E-08A611B84FF6}',
#   'Attributes\n'): 1,
#  ('FolderDescriptions', '{F38BF404-1D43-42F2-9305-67DE0B28FC23}', 'Name\n'): 1,
#  ('Count', '{0139Q44R-6NSR-49S2-8690-3QNSPNR6SSO8}', 'Npprffbevrf'): 12,
#  ('{0139Q44R-6NSR-49S2-8690-3QNSPNR6SSO8}', 'Npprffbevrf', 'Flfgrz Gbbyf'): 5,
#  ('Npprffbevrf', 'Flfgrz Gbbyf', 'Jvaqbjf Rnfl Genafsre Ercbegf.yax\n'): 1,
#  ('Wow6432Node', 'CLSID', '{DFFACDC5-679F-4156-8947-C5C76BC0B67F}'): 12,
#  ('CLSID', '{DFFACDC5-679F-4156-8947-C5C76BC0B67F}', 'ShellFolder'): 10,
#  ('{DFFACDC5-679F-4156-8947-C5C76BC0B67F}',
#   'ShellFolder',
#   'WantsFORPARSING\n'): 1,
#  ('FolderDescriptions',
#   '{491E922F-5643-4AF4-A7EB-4E7A138D8174}',
#   'ParentFolder\n'): 1,
#  ('FolderDescriptions',
#   '{D65231B0-B2F1-4857-A4CE-A8E7C6EA7D27}',
#   'Attributes\n'): 1,
#  ('Wow6432Node', 'CLSID', '{20D04FE0-3AEA-1069-A2D8-08002B30309D}'): 11,
#  ('CLSID', '{20D04FE0-3AEA-1069-A2D8-08002B30309D}', 'ShellFolder'): 10,
#  ('{20D04FE0-3AEA-1069-A2D8-08002B30309D}',
#   'ShellFolder',
#   'WantsUniversalDelegate\n'): 1,
#  ('Nls', 'ExtendedLocale', 'lo-LA\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{2A00375E-224C-49DE-B8D1-440DF7EF3DDC}'): 8,
#  ('FolderDescriptions', '{2A00375E-224C-49DE-B8D1-440DF7EF3DDC}', 'Name\n'): 1,
#  ('FolderDescriptions',
#   '{2112AB0A-C86A-4FFE-A368-0DE96E47012E}',
#   'FolderTypeID\n'): 1,
#  ('Windows', 'system32', 'SnippingTool.exe,-15051\n'): 1,
#  ('Nls', 'ExtendedLocale', 'sq\n'): 1,
#  ('FolderDescriptions',
#   '{98EC0E18-2098-4D44-8644-66979315A281}',
#   'Roamable\n'): 1,
#  ('CURRENTVERSION', 'FontSubstitutes', 'Arabic Transparent,0\n'): 1,
#  ('FolderDescriptions',
#   '{18989B1D-99B5-455B-841C-AB7C74E4DDFC}',
#   'LocalizedName\n'): 1,
#  ('FolderDescriptions',
#   '{A302545D-DEFF-464B-ABE8-61C8648D939B}',
#   'LocalizedName\n'): 1,
#  ('{59031A47-3F72-44A7-89C5-5595FE6B30EE}',
#   'ShellFolder',
#   'WantsFORDISPLAY\n'): 1,
#  ('SystemFileAssociations', '.exe', 'AlwaysShowExt\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{0F214138-B1D3-4A90-BBA9-27CBC0C5389A}'): 10,
#  ('FolderDescriptions',
#   '{0F214138-B1D3-4A90-BBA9-27CBC0C5389A}',
#   'StreamResourceType\n'): 1,
#  ('FolderDescriptions',
#   '{FD228CB7-AE11-4AE3-864C-16F3910AB8FE}',
#   'Description\n'): 1,
#  ('FolderDescriptions',
#   '{054FAE61-4DD8-4787-80B6-090220C4B700}',
#   'InfoTip\n'): 1,
#  ('Nls', 'ExtendedLocale', 'bo-CN\n'): 1,
#  ('regkey_read_HKEY_LOCAL_MACHINE', 'SOFTWARE', 'Policies'): 14,
#  ('SOFTWARE', 'Policies', 'Microsoft'): 7,
#  ('Microsoft', 'Windows', 'System'): 2,
#  ('Windows', 'System', 'CopyFileOverlappedCount\n'): 1,
#  ('Explorer', 'Advanced', 'AccListViewV6\n'): 1,
#  ('Nls', 'ExtendedLocale', 'ky-KG\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{56784854-C6CB-462B-8169-88E350ACB882}'): 11,
#  ('FolderDescriptions',
#   '{56784854-C6CB-462B-8169-88E350ACB882}',
#   'InitFolderHandler\n'): 1,
#  ('Nls', 'CustomLocale', 'ar-SA\n'): 1,
#  ('FolderDescriptions',
#   '{2A00375E-224C-49DE-B8D1-440DF7EF3DDC}',
#   'Security\n'): 1,
#  ('Providers', 'Trust', 'CertCheck'): 2,
#  ('Trust', 'CertCheck', '{00AAC56B-CD44-11D0-8CC2-00C04FC295EE}'): 2,
#  ('CertCheck', '{00AAC56B-CD44-11D0-8CC2-00C04FC295EE}', '$Function\n'): 1,
#  ('explorer',
#   'FolderDescriptions',
#   '{915221FB-9EFE-4BDA-8FD7-F78DCA774F87}'): 11,
#  ('FolderDescriptions',
#   '{915221FB-9EFE-4BDA-8FD7-F78DCA774F87}',
#   'LocalizedName\n'): 1,
#  ('FolderDescriptions',
#   '{D20BEEC4-5CA8-4905-AE3B-BF251EA09B53}',
#   'ParsingName\n'): 1,
#  ('FolderDescriptions',
#   '{B97D20BB-F46A-4C97-BA10-5E3608430854}',
#   'LocalizedName\n'): 1,
#  ('CURRENTVERSION', 'FontSubstitutes', 'David Transparent\n'): 1,
#  ('Acrobat Reader', '11.0', 'FeatureLockDown'): 7,
#  ('11.0', 'FeatureLockDown', 'bEnableSameObjectCheck\n'): 1,
#  ...}

# %% [markdown]
# ### 3. Visualized Analysis for Three ngrams data

# %%
fd_nor = pd.DataFrame(thr_ngrams_freqdist_nor.keys())
fd_nor['frequency'] = thr_ngrams_freqdist_nor.values()
cols = [0,1,2]
fd_nor['features'] = fd_nor[cols].apply(lambda row: ','.join(row.values.astype(str)), axis=1)
fd_nor = fd_nor.sort_values(by=['frequency'], ascending=False)
fd_nor = fd_nor[['features','frequency']]
fd_nor.reset_index()
fd_nor
# Out:
#                                                features  frequency
# 2957                  Program Files,XMind ZEN,resources       2310
# 2958              XMind ZEN,resources,app.asar.unpacked       2308
# 2959           resources,app.asar.unpacked,node_modules       2300
# 2956            file_created_C:,Program Files,XMind ZEN       1926
# 3                      Microsoft,Windows,CurrentVersion       1368
# ...                                                 ...        ...
# 2312                            Nls,Language Groups,b\n          1
# 2311  FolderDescriptions,{D0384E7D-BAC3-4797-8F14-CB...          1
# 2310          SystemFileAssociations,system,DocObject\n          1
# 2309  regkey_read_HKEY_CURRENT_USER,manifest_auto_fi...          1
# 6411                               crypto,bn,bn_mod.c\n          1
#
# [6412 rows x 2 columns]

# %%
fd_ran = pd.DataFrame(thr_ngrams_freqdist_ran.keys())
fd_ran['frequency'] = thr_ngrams_freqdist_ran.values()
cols = [0,1,2]
fd_ran['features'] = fd_ran[cols].apply(lambda row: ','.join(row.values.astype(str)), axis=1)
fd_ran = fd_ran.sort_values(by=['frequency'], ascending=False)
fd_ran.reset_index()
fd_ran = fd_ran[['features','frequency']]
fd_ran
# Out:
#                                                features  frequency
# 10                     Microsoft,Windows,CurrentVersion       1639
# 8                        SOFTWARE,Wow6432Node,Microsoft       1504
# 1425  regkey_read_HKEY_LOCAL_MACHINE,SOFTWARE,Wow643...       1259
# 9                         Wow6432Node,Microsoft,Windows       1247
# 4226                                 Users,newt,AppData       1225
# ...                                                 ...        ...
# 3006  {CEBFF5CD-ACE2-4F4F-9178-9926F41749EA},Count,Z...          1
# 3005                            runas,command,command\n          1
# 3004       Applications,NTVDM.exe,NoStaticDefaultVerb\n          1
# 3003  GACChangeNotification,Default,Microsoft.Visual...          1
# 7373                                strings_,]K",]OwC\n          1
#
# [7374 rows x 2 columns]

# %% [markdown]
# add rank for the ransomware behavior dataframe

# %%
ransom_rank = range(1,len(fd_ran)+1)
fd_ran['rank'] = ransom_rank
fd_ran
# Out:
#                                                features  frequency  rank
# 10                     Microsoft,Windows,CurrentVersion       1639     1
# 8                        SOFTWARE,Wow6432Node,Microsoft       1504     2
# 1425  regkey_read_HKEY_LOCAL_MACHINE,SOFTWARE,Wow643...       1259     3
# 9                         Wow6432Node,Microsoft,Windows       1247     4
# 4226                                 Users,newt,AppData       1225     5
# ...                                                 ...        ...   ...
# 3006  {CEBFF5CD-ACE2-4F4F-9178-9926F41749EA},Count,Z...          1  7370
# 3005                            runas,command,command\n          1  7371
# 3004       Applications,NTVDM.exe,NoStaticDefaultVerb\n          1  7372
# 3003  GACChangeNotification,Default,Microsoft.Visual...          1  7373
# 7373                                strings_,]K",]OwC\n          1  7374
#
# [7374 rows x 3 columns]

# %% [markdown]
# add rank for the normal behavior dataframe

# %%
normal_rank = range(1,len(fd_nor)+1)
fd_nor['rank'] = normal_rank
fd_nor
# Out:
#                                                features  frequency  rank
# 2957                  Program Files,XMind ZEN,resources       2310     1
# 2958              XMind ZEN,resources,app.asar.unpacked       2308     2
# 2959           resources,app.asar.unpacked,node_modules       2300     3
# 2956            file_created_C:,Program Files,XMind ZEN       1926     4
# 3                      Microsoft,Windows,CurrentVersion       1368     5
# ...                                                 ...        ...   ...
# 2312                            Nls,Language Groups,b\n          1  6408
# 2311  FolderDescriptions,{D0384E7D-BAC3-4797-8F14-CB...          1  6409
# 2310          SystemFileAssociations,system,DocObject\n          1  6410
# 2309  regkey_read_HKEY_CURRENT_USER,manifest_auto_fi...          1  6411
# 6411                               crypto,bn,bn_mod.c\n          1  6412
#
# [6412 rows x 3 columns]

# %% [markdown]
# find the unique features in ransome behavior while not in normal behavior

# %%
fd_ran[~fd_ran.features.isin(fd_nor['features'])].reset_index()
# Out:
#       index                                           features  frequency  \
# 0      4231                                Python27,tcl,tcl8.5        366
# 1      4232                                    tcl,tcl8.5,msgs        342
# 2      4242                          Users,All Users,Microsoft        275
# 3      6465                       file_deleted_C:,Python27,tcl        220
# 4      6458                       file_deleted_C:,Python27,Lib        202
# ...     ...                                                ...        ...
# 5752   3007  FolderDescriptions,{2B0F765D-C0E9-4171-908E-08...          1
# 5753   3006  {CEBFF5CD-ACE2-4F4F-9178-9926F41749EA},Count,Z...          1
# 5754   3005                            runas,command,command\n          1
# 5755   3003  GACChangeNotification,Default,Microsoft.Visual...          1
# 5756   7373                                strings_,]K",]OwC\n          1
#
#       rank
# 0       11
# 1       13
# 2       17
# 3       21
# 4       24
# ...    ...
# 5752  7369
# 5753  7370
# 5754  7371
# 5755  7373
# 5756  7374
#
# [5757 rows x 4 columns]

# %% [markdown]
# compare the ranks for the some features in two datasets

# %%
thr_feature_ranks = fd_ran[['features','rank']].merge(fd_nor[['features','rank']], on=['features'])
thr_feature_ranks.iloc[:194,:]
# Out:
#                                               features  rank_x  rank_y
# 0                     Microsoft,Windows,CurrentVersion       1       5
# 1                       SOFTWARE,Wow6432Node,Microsoft       2       6
# 2    regkey_read_HKEY_LOCAL_MACHINE,SOFTWARE,Wow643...       3      10
# 3                        Wow6432Node,Microsoft,Windows       4       7
# 4                                   Users,newt,AppData       5      26
# ..                                                 ...     ...     ...
# 189  explorer,FolderDescriptions,{1777F761-68AD-4D8...     330     212
# 190  explorer,FolderDescriptions,{A75D362E-50FC-4FB...     331     181
# 191  EncodingType 0,CertDllCreateCertificateChainEn...     332     331
# 192  Wow6432Node,CLSID,{1F3427C8-5C10-4210-AA03-2EE...     333     391
# 193         CurrentVersion,Explorer,User Shell Folders     334     296
#
# [194 rows x 3 columns]

# %% [markdown]
# compare the frequencies for the some features in two datasets

# %%
thr_feature_freqs = fd_ran[['features','frequency']].merge(fd_nor[['features','frequency']], on=['features'])
thr_feature_freqs
# Out:
#                                                features  frequency_x  \
# 0                      Microsoft,Windows,CurrentVersion         1639
# 1                        SOFTWARE,Wow6432Node,Microsoft         1504
# 2     regkey_read_HKEY_LOCAL_MACHINE,SOFTWARE,Wow643...         1259
# 3                         Wow6432Node,Microsoft,Windows         1247
# 4                                    Users,newt,AppData         1225
# ...                                                 ...          ...
# 1612  FolderDescriptions,{4BD8D571-6D19-48D3-BE97-42...            1
# 1613                  Lsa,FipsAlgorithmPolicy,Enabled\n            1
# 1614                    Control,Lsa,FipsAlgorithmPolicy            1
# 1615  FolderDescriptions,{054FAE61-4DD8-4787-80B6-09...            1
# 1616       Applications,NTVDM.exe,NoStaticDefaultVerb\n            1
#
#       frequency_y
# 0            1368
# 1            1237
# 2            1091
# 3            1173
# 4             161
# ...           ...
# 1612            1
# 1613            1
# 1614            1
# 1615            1
# 1616            1
#
# [1617 rows x 3 columns]

# %%
thr_feature_freqs[thr_feature_freqs['frequency_x']>191]
# Out:
#                                              features  frequency_x  \
# 0                    Microsoft,Windows,CurrentVersion         1639
# 1                      SOFTWARE,Wow6432Node,Microsoft         1504
# 2   regkey_read_HKEY_LOCAL_MACHINE,SOFTWARE,Wow643...         1259
# 3                       Wow6432Node,Microsoft,Windows         1247
# 4                                  Users,newt,AppData         1225
# 5                     Windows,CurrentVersion,explorer         1190
# 6          CurrentVersion,explorer,FolderDescriptions         1174
# 7                                  newt,AppData,Local          929
# 8                          file_created_C:,Users,newt          490
# 9                                  AppData,Local,Temp          418
# 10                         Software,Microsoft,Windows          359
# 11                            AppData,Local,Microsoft          340
# 12   regkey_read_HKEY_CURRENT_USER,Software,Microsoft          335
# 13                         file_deleted_C:,Users,newt          289
# 14                          file_opened_C:,Users,newt          260
# 15  regkey_opened_HKEY_LOCAL_MACHINE,SOFTWARE,Wow6...          239
# 16    regkey_read_HKEY_LOCAL_MACHINE,SOFTWARE,Classes          233
# 17                            Local,Microsoft,Windows          215
# 18                               newt,AppData,Roaming          209
# 19                    Windows,CurrentVersion,Explorer          192
#
#     frequency_y
# 0          1368
# 1          1237
# 2          1091
# 3          1173
# 4           161
# 5          1163
# 6          1151
# 7           121
# 8            31
# 9           108
# 10          183
# 11            4
# 12          118
# 13           11
# 14           65
# 15          143
# 16          182
# 17            4
# 18           18
# 19          148

# %% [markdown]
# ### 4. Visualized Analysis for Four ngrams data

# %%
# get the fre of four ngrams for two sets of features
four_ngrams_freqdist_nor = ngram_fre_analysis(4, normal_features_list)
four_ngrams_freqdist_ran = ngram_fre_analysis(4, ransom_features_list)

# %%
four_ngrams_freqdist_nor
# Out:
# FreqDist({('Program Files', 'XMind ZEN', 'resources', 'app.asar.unpacked'): 2308, ('XMind ZEN', 'resources', 'app.asar.unpacked', 'node_modules'): 2300, ('file_created_C:', 'Program Files', 'XMind ZEN', 'resources'): 1888, ('SOFTWARE', 'Wow6432Node', 'Microsoft', 'Windows'): 1173, ('Wow6432Node', 'Microsoft', 'Windows', 'CurrentVersion'): 1173, ('Microsoft', 'Windows', 'CurrentVersion', 'explorer'): 1163, ('Windows', 'CurrentVersion', 'explorer', 'FolderDescriptions'): 1151, ('regkey_read_HKEY_LOCAL_MACHINE', 'SOFTWARE', 'Wow6432Node', 'Microsoft'): 1090, ('resources', 'app.asar.unpacked', 'node_modules', 'core-js'): 784, ('app.asar.unpacked', 'node_modules', 'core-js', 'library'): 378, ...})

# %%
four_ngrams_freqdist_ran
# Out:
# FreqDist({('regkey_read_HKEY_LOCAL_MACHINE', 'SOFTWARE', 'Wow6432Node', 'Microsoft'): 1255, ('SOFTWARE', 'Wow6432Node', 'Microsoft', 'Windows'): 1247, ('Wow6432Node', 'Microsoft', 'Windows', 'CurrentVersion'): 1244, ('Microsoft', 'Windows', 'CurrentVersion', 'explorer'): 1190, ('Windows', 'CurrentVersion', 'explorer', 'FolderDescriptions'): 1174, ('Users', 'newt', 'AppData', 'Local'): 929, ('file_created_C:', 'Users', 'newt', 'AppData'): 474, ('newt', 'AppData', 'Local', 'Temp'): 418, ('Software', 'Microsoft', 'Windows', 'CurrentVersion'): 344, ('Python27', 'tcl', 'tcl8.5', 'msgs'): 342, ...})

# %% [markdown]
# ### 5. Visualized analysis for four ngrams data

# %%
fd_nor_four = pd.DataFrame(four_ngrams_freqdist_nor.keys())
fd_nor_four['frequency'] = four_ngrams_freqdist_nor.values()
cols = [0,1,2,3]
fd_nor_four['features'] = fd_nor_four[cols].apply(lambda row: ','.join(row.values.astype(str)), axis=1)
fd_nor_four = fd_nor_four.sort_values(by=['frequency'], ascending=False)
fd_nor_four = fd_nor_four[['features','frequency']]
fd_nor_four.reset_index()
fd_nor_four
# Out:
#                                                features  frequency
# 2890  Program Files,XMind ZEN,resources,app.asar.unp...       2308
# 2891  XMind ZEN,resources,app.asar.unpacked,node_mod...       2300
# 2889  file_created_C:,Program Files,XMind ZEN,resources       1888
# 2          Wow6432Node,Microsoft,Windows,CurrentVersion       1173
# 1                SOFTWARE,Wow6432Node,Microsoft,Windows       1173
# ...                                                 ...        ...
# 2234  explorer,FolderDescriptions,{DE974D24-D9C6-4D3...          1
# 2233           @C:,Windows,system32,recdisc.exe,-2000\n          1
# 2232  CLSID,{DFFACDC5-679F-4156-8947-C5C76BC0B67F},S...          1
# 2231  explorer,FolderDescriptions,{B6EBFB86-6907-413...          1
# 6119                     strings_.,crypto,bn,bn_mod.c\n          1
#
# [6120 rows x 2 columns]

# %% [markdown]
# create the feature dataframe for ransom behavior

# %%
fd_ran_four = pd.DataFrame(four_ngrams_freqdist_ran.keys())
fd_ran_four['frequency'] = four_ngrams_freqdist_ran.values()
cols = [0,1,2,3]
fd_ran_four['features'] = fd_ran_four[cols].apply(lambda row: ','.join(row.values.astype(str)), axis=1)
fd_ran_four = fd_ran_four.sort_values(by=['frequency'], ascending=False)
fd_ran_four.reset_index()
fd_ran_four = fd_ran_four[['features','frequency']]
fd_ran_four
# Out:
#                                                features  frequency
# 1451  regkey_read_HKEY_LOCAL_MACHINE,SOFTWARE,Wow643...       1255
# 7                SOFTWARE,Wow6432Node,Microsoft,Windows       1247
# 8          Wow6432Node,Microsoft,Windows,CurrentVersion       1244
# 15            Microsoft,Windows,CurrentVersion,explorer       1190
# 16    Windows,CurrentVersion,explorer,FolderDescript...       1174
# ...                                                 ...        ...
# 2958  explorer,FolderDescriptions,{054FAE61-4DD8-478...          1
# 2957  explorer,FolderDescriptions,{9E3995AB-1F9C-4F1...          1
# 2956  explorer,FolderDescriptions,{B88F4DAA-E7BD-49A...          1
# 2955  explorer,FolderDescriptions,{D9DC8A3B-B784-432...          1
# 7315                     crts,crtw32,convert,mbtowc.c\n          1
#
# [7316 rows x 2 columns]

# %% [markdown]
# create the frequency dataframe for normal features

# %%
fd_nor_four = pd.DataFrame(four_ngrams_freqdist_nor.keys())
fd_nor_four['frequency'] = four_ngrams_freqdist_nor.values()
cols = [0,1,2,3]
fd_nor_four['features'] = fd_nor_four[cols].apply(lambda row: ','.join(row.values.astype(str)), axis=1)
fd_nor_four = fd_nor_four.sort_values(by=['frequency'], ascending=False)
fd_nor_four.reset_index()
fd_nor_four = fd_nor_four[['features','frequency']]
fd_nor_four
# Out:
#                                                features  frequency
# 2890  Program Files,XMind ZEN,resources,app.asar.unp...       2308
# 2891  XMind ZEN,resources,app.asar.unpacked,node_mod...       2300
# 2889  file_created_C:,Program Files,XMind ZEN,resources       1888
# 2          Wow6432Node,Microsoft,Windows,CurrentVersion       1173
# 1                SOFTWARE,Wow6432Node,Microsoft,Windows       1173
# ...                                                 ...        ...
# 2234  explorer,FolderDescriptions,{DE974D24-D9C6-4D3...          1
# 2233           @C:,Windows,system32,recdisc.exe,-2000\n          1
# 2232  CLSID,{DFFACDC5-679F-4156-8947-C5C76BC0B67F},S...          1
# 2231  explorer,FolderDescriptions,{B6EBFB86-6907-413...          1
# 6119                     strings_.,crypto,bn,bn_mod.c\n          1
#
# [6120 rows x 2 columns]

# %% [markdown]
# create the rank for two dataframe

# %%
normal_rank = range(1,len(fd_nor_four)+1)
fd_nor_four['rank'] = normal_rank
fd_nor_four

ransom_rank = range(1,len(fd_ran_four)+1)
fd_ran_four['rank'] = ransom_rank
fd_ran_four
# Out:
#                                                features  frequency  rank
# 1451  regkey_read_HKEY_LOCAL_MACHINE,SOFTWARE,Wow643...       1255     1
# 7                SOFTWARE,Wow6432Node,Microsoft,Windows       1247     2
# 8          Wow6432Node,Microsoft,Windows,CurrentVersion       1244     3
# 15            Microsoft,Windows,CurrentVersion,explorer       1190     4
# 16    Windows,CurrentVersion,explorer,FolderDescript...       1174     5
# ...                                                 ...        ...   ...
# 2958  explorer,FolderDescriptions,{054FAE61-4DD8-478...          1  7312
# 2957  explorer,FolderDescriptions,{9E3995AB-1F9C-4F1...          1  7313
# 2956  explorer,FolderDescriptions,{B88F4DAA-E7BD-49A...          1  7314
# 2955  explorer,FolderDescriptions,{D9DC8A3B-B784-432...          1  7315
# 7315                     crts,crtw32,convert,mbtowc.c\n          1  7316
#
# [7316 rows x 3 columns]

# %%
four_feature_ranks = fd_ran_four[['features','rank']].merge(fd_nor_four[['features','rank']], on=['features'])
four_feature_ranks.iloc[:194,:]
# Out:
#                                               features  rank_x  rank_y
# 0    regkey_read_HKEY_LOCAL_MACHINE,SOFTWARE,Wow643...       1       8
# 1               SOFTWARE,Wow6432Node,Microsoft,Windows       2       5
# 2         Wow6432Node,Microsoft,Windows,CurrentVersion       3       4
# 3            Microsoft,Windows,CurrentVersion,explorer       4       6
# 4    Windows,CurrentVersion,explorer,FolderDescript...       5       7
# ..                                                 ...     ...     ...
# 189  OID,EncodingType 0,CertDllCreateCertificateCha...     334     326
# 190  CurrentVersion,explorer,FolderDescriptions,{3E...     335     124
# 191  CurrentVersion,explorer,FolderDescriptions,{17...     337     189
# 192  CurrentVersion,explorer,FolderDescriptions,{7B...     339     272
# 193  CurrentVersion,explorer,FolderDescriptions,{2C...     341     344
#
# [194 rows x 3 columns]

# %% [markdown]
# ### Find the unique strings in ransomware activities

# %% [markdown]
# #### Four-Gram analysis

# %%
unique_fd_ran_four = fd_ran_four[~fd_ran_four.features.isin(fd_nor_four['features'])].reset_index()
unique_fd_ran_four
# Out:
#       index                                           features  frequency  \
# 0      4293                           Python27,tcl,tcl8.5,msgs        342
# 1      4325   Local,Microsoft,Windows,Temporary Internet Files        168
# 2      4326  Microsoft,Windows,Temporary Internet Files,Con...        167
# 3      6518                file_deleted_C:,Python27,tcl,tcl8.5        150
# 4        29                         SOFTWARE,MICROSOFT,CTF,TIP        147
# ...     ...                                                ...        ...
# 5758   2964           Internet Settings,Zones,1,CurrentLevel\n          1
# 5759   2963  Trust,Initialization,{573E31F8-AABA-11D0-8CCB-...          1
# 5760   2962  Providers,Trust,Initialization,{573E31F8-AABA-...          1
# 5761   2959  explorer,FolderDescriptions,{054FAE61-4DD8-478...          1
# 5762   7315                     crts,crtw32,convert,mbtowc.c\n          1
#
#       rank
# 0       10
# 1       19
# 2       20
# 3       22
# 4       23
# ...    ...
# 5758  7307
# 5759  7308
# 5760  7309
# 5761  7311
# 5762  7316
#
# [5763 rows x 4 columns]

# %%
# save the result for three-ngram
unique_fd_ran_four.to_pickle('../dataset/N-Gram/unique_fd_four.pkl')

# %%
fd_ran_four[~fd_ran_four.features.isin(fd_nor_four['features'])][fd_ran_four['frequency']==1].reset_index()
# Out:
# <ipython-input-29-2df9c441eef4>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   fd_ran_four[~fd_ran_four.features.isin(fd_nor_four['features'])][fd_ran_four['frequency']==1].reset_index()
#       index                                           features  frequency  \
# 0      7018               email,guest,data,msg_17.txt.WNCRYT\n          1
# 1      7010                     tcl,tk8.5,msgs,ru.msg.WNCRYT\n          1
# 2      7009       Python27,Lib,guest,exception_hierarchy.txt\n          1
# 3      4882             file_created_C:,Python27,Tools,Scripts          1
# 4      4890                        Python27,tcl,tcl8.5,http1.0          1
# ...     ...                                                ...        ...
# 4171   2964           Internet Settings,Zones,1,CurrentLevel\n          1
# 4172   2963  Trust,Initialization,{573E31F8-AABA-11D0-8CCB-...          1
# 4173   2962  Providers,Trust,Initialization,{573E31F8-AABA-...          1
# 4174   2959  explorer,FolderDescriptions,{054FAE61-4DD8-478...          1
# 4175   7315                     crts,crtw32,convert,mbtowc.c\n          1
#
#       rank
# 0     2055
# 1     2056
# 2     2057
# 3     2058
# 4     2059
# ...    ...
# 4171  7307
# 4172  7308
# 4173  7309
# 4174  7311
# 4175  7316
#
# [4176 rows x 4 columns]

# %%
fd_ran_four[~fd_ran_four.features.isin(fd_nor_four['features'])][fd_ran_four['frequency']<=191].reset_index()
# Out:
# <ipython-input-30-9f08b1495f5d>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   fd_ran_four[~fd_ran_four.features.isin(fd_nor_four['features'])][fd_ran_four['frequency']<=191].reset_index()
#       index                                           features  frequency  \
# 0      4325   Local,Microsoft,Windows,Temporary Internet Files        168
# 1      4326  Microsoft,Windows,Temporary Internet Files,Con...        167
# 2      6518                file_deleted_C:,Python27,tcl,tcl8.5        150
# 3        29                         SOFTWARE,MICROSOFT,CTF,TIP        147
# 4      6504          file_deleted_C:,Users,All Users,Microsoft        122
# ...     ...                                                ...        ...
# 5757   2964           Internet Settings,Zones,1,CurrentLevel\n          1
# 5758   2963  Trust,Initialization,{573E31F8-AABA-11D0-8CCB-...          1
# 5759   2962  Providers,Trust,Initialization,{573E31F8-AABA-...          1
# 5760   2959  explorer,FolderDescriptions,{054FAE61-4DD8-478...          1
# 5761   7315                     crts,crtw32,convert,mbtowc.c\n          1
#
#       rank
# 0       19
# 1       20
# 2       22
# 3       23
# 4       25
# ...    ...
# 5757  7307
# 5758  7308
# 5759  7309
# 5760  7311
# 5761  7316
#
# [5762 rows x 4 columns]

# %% [markdown]
# #### Three-Gram analysis

# %%
unique_fd_ran_three = fd_ran[~fd_ran.features.isin(fd_nor['features'])].reset_index()
unique_fd_ran_three
# Out:
#       index                                           features  frequency  \
# 0      4231                                Python27,tcl,tcl8.5        366
# 1      4232                                    tcl,tcl8.5,msgs        342
# 2      4242                          Users,All Users,Microsoft        275
# 3      6465                       file_deleted_C:,Python27,tcl        220
# 4      6458                       file_deleted_C:,Python27,Lib        202
# ...     ...                                                ...        ...
# 5752   3007  FolderDescriptions,{2B0F765D-C0E9-4171-908E-08...          1
# 5753   3006  {CEBFF5CD-ACE2-4F4F-9178-9926F41749EA},Count,Z...          1
# 5754   3005                            runas,command,command\n          1
# 5755   3003  GACChangeNotification,Default,Microsoft.Visual...          1
# 5756   7373                                strings_,]K",]OwC\n          1
#
#       rank
# 0       11
# 1       13
# 2       17
# 3       21
# 4       24
# ...    ...
# 5752  7369
# 5753  7370
# 5754  7371
# 5755  7373
# 5756  7374
#
# [5757 rows x 4 columns]

# %%
# save the result for three-ngram
unique_fd_ran_three.to_pickle('../dataset/N-Gram/unique_fd_three.pkl')

# %%
fd_ran[~fd_ran.features.isin(fd_nor['features'])][fd_ran['frequency']<=191].reset_index()
# Out:
# <ipython-input-33-7f1cb17efd37>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   fd_ran[~fd_ran.features.isin(fd_nor['features'])][fd_ran['frequency']<=191].reset_index()
#       index                                           features  frequency  \
# 0      4272                                 Python27,Lib,guest        175
# 1      4266         Microsoft,Windows,Temporary Internet Files        168
# 2      4267       Windows,Temporary Internet Files,Content.IE5        167
# 3        32                             SOFTWARE,MICROSOFT,CTF        147
# 4        33                                  MICROSOFT,CTF,TIP        147
# ...     ...                                                ...        ...
# 5747   3007  FolderDescriptions,{2B0F765D-C0E9-4171-908E-08...          1
# 5748   3006  {CEBFF5CD-ACE2-4F4F-9178-9926F41749EA},Count,Z...          1
# 5749   3005                            runas,command,command\n          1
# 5750   3003  GACChangeNotification,Default,Microsoft.Visual...          1
# 5751   7373                                strings_,]K",]OwC\n          1
#
#       rank
# 0       27
# 1       28
# 2       29
# 3       33
# 4       34
# ...    ...
# 5747  7369
# 5748  7370
# 5749  7371
# 5750  7373
# 5751  7374
#
# [5752 rows x 4 columns]

# %%
fd_ran[~fd_ran.features.isin(fd_nor['features'])][fd_ran['frequency']==1].reset_index()
# Out:
# <ipython-input-34-38f9251836ab>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   fd_ran[~fd_ran.features.isin(fd_nor['features'])][fd_ran['frequency']==1].reset_index()
#       index                                           features  frequency  \
# 0      5040               User Data,OriginTrials,~SDB3B4.tmp\n          1
# 1      7208        svlhbcnth,RMS^hlRFOUVbZLKUWW_YI>Sdeb,VV]s\n          1
# 2      7207  strings_}ttqkpz}}wkht}pcdehbgae[U^da[XQ,svlhbc...          1
# 3      5038              Content.IE5,LXGDWYKT,BBACPiN[1].png\n          1
# 4      5035              Content.IE5,3DL0D11W,BBLLeL3[1].jpg\n          1
# ...     ...                                                ...        ...
# 4045   3007  FolderDescriptions,{2B0F765D-C0E9-4171-908E-08...          1
# 4046   3006  {CEBFF5CD-ACE2-4F4F-9178-9926F41749EA},Count,Z...          1
# 4047   3005                            runas,command,command\n          1
# 4048   3003  GACChangeNotification,Default,Microsoft.Visual...          1
# 4049   7373                                strings_,]K",]OwC\n          1
#
#       rank
# 0     2208
# 1     2209
# 2     2210
# 3     2211
# 4     2212
# ...    ...
# 4045  7369
# 4046  7370
# 4047  7371
# 4048  7373
# 4049  7374
#
# [4050 rows x 4 columns]
