# %%
import pickle
import sys

# %%
# process the normal registry data
normal_file_path = './dataset/normal_registry_total.pkl'
with open(normal_file_path, 'rb') as fr:
    normal_data = pickle.load(fr, encoding="bytes")

# process the ransom registry data
ransom_file_path = './dataset/ransom_registry_total.pkl'
with open(ransom_file_path, 'rb') as fr:
    ransom_data = pickle.load(fr, encoding="bytes")

# %%
# Preprocessing for lowercase
import numpy as np

# lowercase all the data
normal_data = np.char.lower(normal_data)
ransom_data = np.char.lower(ransom_data)

# %%
# calculate the weights
from collections import Counter

def string_frequency(strings):
    total_len = len(strings)
    weights_dict = {}
    strings_dict = Counter(strings)
    print(len(strings_dict.keys()))
    for key, value in strings_dict.items():
        weights_dict[key] = round(value/total_len, 6)
    return weights_dict

# %%
normal_weights_dict = string_frequency(normal_data)
ransom_weights_dict = string_frequency(ransom_data)
# Out:
# 4685
# 6452

# %%
# sort the dict according to the weights
normal_query_weights = sorted(normal_weights_dict.items(), key=lambda x: x[1], reverse=True)
ransom_query_weights = sorted(ransom_weights_dict.items(), key=lambda x: x[1], reverse=True)

# %%
normal_query_weights[:50]
# Out:
# [('hkey_local_machine\\software\\classes\\allfilesystemobjects\\docobject',
#   0.000953),
#  ('hkey_local_machine\\software\\classes\\directory\\browseinplace', 0.000953),
#  ('hkey_local_machine\\software\\classes\\directory\\docobject', 0.000953),
#  ('hkey_local_machine\\software\\classes\\allfilesystemobjects\\browseinplace',
#   0.000953),
#  ('hkey_local_machine\\software\\classes\\folder\\docobject', 0.000953),
#  ('hkey_local_machine\\software\\classes\\folder\\browseinplace', 0.000953),
#  ('hkey_local_machine\\software\\classes\\unknown\\browseinplace', 0.000901),
#  ('hkey_local_machine\\software\\classes\\unknown\\docobject', 0.000901),
#  ('hkey_current_user\\local settings\\software\\microsoft\\windows\\shell\\muicache\\c:\\program files (x86)\\adobe\\reader 11.0\\reader\\acrord32.exe',
#   0.000901),
#  ('hkey_local_machine\\software\\classes\\.bin\\docobject', 0.000857),
#  ('hkey_local_machine\\software\\classes\\.bin\\browseinplace', 0.000857),
#  ('hkey_current_user\\software\\microsoft\\windows\\currentversion\\explorer\\advanced',
#   0.000715),
#  ('hkey_classes_root\\applications\\acrord32.exe', 0.000683),
#  ('hkey_current_user\\software\\microsoft\\windows\\currentversion\\explorer\\fileexts\\.bin\\openwithlist\\mrulist',
#   0.000648),
#  ('hkey_local_machine\\system\\controlset001\\control\\nls\\extendedlocale\\en-us',
#   0.000487),
#  ('hkey_local_machine\\system\\controlset001\\control\\nls\\customlocale\\en-us',
#   0.000487),
#  ('hkey_local_machine\\software\\microsoft\\sqmclient\\windows\\ceipenable',
#   0.000485),
#  ('hkey_local_machine\\software\\microsoft\\windows nt\\currentversion\\fontsubstitutes',
#   0.000484),
#  ('hkey_current_user\\software\\microsoft\\windows\\currentversion\\policies\\nonenum',
#   0.000482),
#  ('hkey_current_user\\software\\microsoft\\windows\\currentversion\\explorer\\user shell folders',
#   0.000482),
#  ('hkey_local_machine\\software\\microsoft\\windows\\currentversion\\policies\\explorer',
#   0.000482),
#  ('hkey_current_user\\software\\microsoft\\windows\\currentversion\\policies\\explorer',
#   0.000482),
#  ('hkey_local_machine\\software\\policies\\microsoft\\windows\\explorer',
#   0.000482),
#  ('hkey_local_machine\\software\\microsoft\\windows\\currentversion\\explorer\\clsid\\{20d04fe0-3aea-1069-a2d8-08002b30309d}\\shellfolder',
#   0.000482),
#  ('hkey_local_machine\\software\\microsoft\\windows\\currentversion\\policies\\nonenum',
#   0.000482),
#  ('hkey_local_machine\\software\\microsoft\\windows nt\\currentversion\\profilelist\\s-1-5-21-1608274813-2371932595-3444937299-1001',
#   0.000482),
#  ('hkey_classes_root\\drive\\shellex\\folderextensions', 0.000482),
#  ('hkey_classes_root\\drive\\shellex\\folderextensions\\{fbeb8a05-beee-4442-804e-409d6c4515e9}',
#   0.000482),
#  ('hkey_current_user\\software\\microsoft\\windows\\currentversion\\explorer\\clsid\\{20d04fe0-3aea-1069-a2d8-08002b30309d}\\shellfolder',
#   0.000482),
#  ('hkey_classes_root\\clsid\\{20d04fe0-3aea-1069-a2d8-08002b30309d}\\shellfolder',
#   0.000482),
#  ('hkey_current_user\\software\\microsoft\\windows\\currentversion\\explorer',
#   0.000482),
#  ('hkey_current_user\\software\\policies\\microsoft\\windows\\explorer',
#   0.000482),
#  ('hkey_local_machine\\software\\microsoft\\windows nt\\currentversion\\profilelist\\s-1-5-21-1608274813-2371932595-3444937299-1001\\profileimagepath',
#   0.000482),
#  ('hkey_local_machine\\software\\microsoft\\windows\\currentversion\\policies\\explorer\\nocontrolpanel',
#   0.000482),
#  ('hkey_local_machine\\software\\classes\\wow6432node\\clsid\\{20d04fe0-3aea-1069-a2d8-08002b30309d}\\shellfolder\\wantsfordisplay',
#   0.000482),
#  ('hkey_local_machine\\software\\microsoft\\windows\\currentversion\\policies\\explorer\\nocommongroups',
#   0.000482),
#  ('hkey_local_machine\\software\\classes\\wow6432node\\clsid\\{20d04fe0-3aea-1069-a2d8-08002b30309d}\\shellfolder\\restrictedattributes',
#   0.000482),
#  ('hkey_local_machine\\software\\classes\\wow6432node\\clsid\\{20d04fe0-3aea-1069-a2d8-08002b30309d}\\shellfolder\\wantsuniversaldelegate',
#   0.000482),
#  ('hkey_local_machine\\software\\classes\\wow6432node\\clsid\\{20d04fe0-3aea-1069-a2d8-08002b30309d}\\shellfolder\\usedrophandler',
#   0.000482),
#  ('hkey_local_machine\\software\\classes\\wow6432node\\clsid\\{20d04fe0-3aea-1069-a2d8-08002b30309d}\\shellfolder\\attributes',
#   0.000482),
#  ('hkey_local_machine\\software\\classes\\wow6432node\\clsid\\{20d04fe0-3aea-1069-a2d8-08002b30309d}\\shellfolder\\mapnetdriveverbs',
#   0.000482),
#  ('hkey_local_machine\\software\\classes\\wow6432node\\clsid\\{20d04fe0-3aea-1069-a2d8-08002b30309d}\\shellfolder\\queryforinfotip',
#   0.000482),
#  ('hkey_local_machine\\software\\classes\\wow6432node\\clsid\\{20d04fe0-3aea-1069-a2d8-08002b30309d}\\shellfolder\\nofilefolderjunction',
#   0.000482),
#  ('hkey_local_machine\\software\\classes\\wow6432node\\clsid\\{20d04fe0-3aea-1069-a2d8-08002b30309d}\\shellfolder\\wantsparsedisplayname',
#   0.000482),
#  ('hkey_local_machine\\software\\classes\\wow6432node\\clsid\\{20d04fe0-3aea-1069-a2d8-08002b30309d}\\shellfolder\\wantsaliasednotifications',
#   0.000482),
#  ('hkey_local_machine\\software\\classes\\wow6432node\\clsid\\{20d04fe0-3aea-1069-a2d8-08002b30309d}\\shellfolder\\pintonamespacetree',
#   0.000482),
#  ('hkey_local_machine\\software\\microsoft\\windows\\currentversion\\policies\\explorer\\nopropertiesrecyclebin',
#   0.000482),
#  ('hkey_local_machine\\software\\microsoft\\windows\\currentversion\\policies\\explorer\\nopropertiesmycomputer',
#   0.000482),
#  ('hkey_local_machine\\software\\classes\\wow6432node\\clsid\\{20d04fe0-3aea-1069-a2d8-08002b30309d}\\shellfolder\\wantsforparsing',
#   0.000482),
#  ('hkey_local_machine\\software\\classes\\wow6432node\\clsid\\{20d04fe0-3aea-1069-a2d8-08002b30309d}\\shellfolder\\queryforoverlay',
#   0.000482)]

# %%
ransom_query_weights[:50]
# Out:
# [('hkey_local_machine\\software\\microsoft\\windows nt\\currentversion\\gre_initialize\\disablemetafiles',
#   0.001185),
#  ('hkey_local_machine\\software\\classes\\allfilesystemobjects\\browseinplace',
#   0.000853),
#  ('hkey_local_machine\\software\\classes\\allfilesystemobjects\\docobject',
#   0.000853),
#  ('hkey_local_machine\\software\\classes\\directory\\browseinplace', 0.000853),
#  ('hkey_local_machine\\software\\classes\\folder\\docobject', 0.000853),
#  ('hkey_local_machine\\software\\classes\\directory\\docobject', 0.000853),
#  ('hkey_local_machine\\software\\classes\\folder\\browseinplace', 0.000853),
#  ('hkey_local_machine\\software\\microsoft\\windows nt\\currentversion\\profilelist\\s-1-5-21-1608274813-2371932595-3444937299-1001',
#   0.000735),
#  ('hkey_local_machine\\software\\microsoft\\windows\\currentversion\\explorer\\folderdescriptions',
#   0.000711),
#  ('hkey_local_machine\\software\\wow6432node\\microsoft\\windows\\currentversion\\explorer\\folderdescriptions\\{5e6c858f-0e22-4760-9afe-ea3317b67173}\\propertybag',
#   0.000711),
#  ('hkey_current_user\\software\\microsoft\\windows\\currentversion\\explorer\\sessioninfo\\1',
#   0.000711),
#  ('hkey_current_user\\software\\microsoft\\windows\\currentversion\\explorer\\sessioninfo\\1\\knownfolders',
#   0.000711),
#  ('hkey_current_user\\software\\microsoft\\windows\\currentversion\\explorer\\user shell folders',
#   0.000711),
#  ('hkey_local_machine\\software\\wow6432node\\microsoft\\windows\\currentversion\\explorer\\folderdescriptions\\{5e6c858f-0e22-4760-9afe-ea3317b67173}',
#   0.000711),
#  ('hkey_local_machine\\software\\wow6432node\\microsoft\\windows\\currentversion\\explorer\\folderdescriptions\\{5e6c858f-0e22-4760-9afe-ea3317b67173}\\parsingname',
#   0.000711),
#  ('hkey_local_machine\\software\\wow6432node\\microsoft\\windows\\currentversion\\explorer\\folderdescriptions\\{5e6c858f-0e22-4760-9afe-ea3317b67173}\\infotip',
#   0.000711),
#  ('hkey_local_machine\\software\\wow6432node\\microsoft\\windows\\currentversion\\explorer\\folderdescriptions\\{5e6c858f-0e22-4760-9afe-ea3317b67173}\\security',
#   0.000711),
#  ('hkey_local_machine\\software\\wow6432node\\microsoft\\windows\\currentversion\\explorer\\folderdescriptions\\{5e6c858f-0e22-4760-9afe-ea3317b67173}\\precreate',
#   0.000711),
#  ('hkey_local_machine\\software\\wow6432node\\microsoft\\windows\\currentversion\\explorer\\folderdescriptions\\{5e6c858f-0e22-4760-9afe-ea3317b67173}\\relativepath',
#   0.000711),
#  ('hkey_local_machine\\software\\wow6432node\\microsoft\\windows\\currentversion\\explorer\\folderdescriptions\\{5e6c858f-0e22-4760-9afe-ea3317b67173}\\category',
#   0.000711),
#  ('hkey_local_machine\\software\\wow6432node\\microsoft\\windows\\currentversion\\explorer\\folderdescriptions\\{5e6c858f-0e22-4760-9afe-ea3317b67173}\\publishexpandedpath',
#   0.000711),
#  ('hkey_local_machine\\software\\wow6432node\\microsoft\\windows\\currentversion\\explorer\\folderdescriptions\\{5e6c858f-0e22-4760-9afe-ea3317b67173}\\foldertypeid',
#   0.000711),
#  ('hkey_local_machine\\software\\wow6432node\\microsoft\\windows\\currentversion\\explorer\\folderdescriptions\\{5e6c858f-0e22-4760-9afe-ea3317b67173}\\stream',
#   0.000711),
#  ('hkey_local_machine\\software\\wow6432node\\microsoft\\windows\\currentversion\\explorer\\folderdescriptions\\{5e6c858f-0e22-4760-9afe-ea3317b67173}\\icon',
#   0.000711),
#  ('hkey_local_machine\\software\\microsoft\\windows nt\\currentversion\\profilelist\\s-1-5-21-1608274813-2371932595-3444937299-1001\\profileimagepath',
#   0.000711),
#  ('hkey_local_machine\\software\\wow6432node\\microsoft\\windows\\currentversion\\explorer\\folderdescriptions\\{5e6c858f-0e22-4760-9afe-ea3317b67173}\\localredirectonly',
#   0.000711),
#  ('hkey_local_machine\\software\\wow6432node\\microsoft\\windows\\currentversion\\explorer\\folderdescriptions\\{5e6c858f-0e22-4760-9afe-ea3317b67173}\\streamresource',
#   0.000711),
#  ('hkey_local_machine\\software\\wow6432node\\microsoft\\windows\\currentversion\\explorer\\folderdescriptions\\{5e6c858f-0e22-4760-9afe-ea3317b67173}\\localizedname',
#   0.000711),
#  ('hkey_local_machine\\software\\wow6432node\\microsoft\\windows\\currentversion\\explorer\\folderdescriptions\\{5e6c858f-0e22-4760-9afe-ea3317b67173}\\parentfolder',
#   0.000711),
#  ('hkey_local_machine\\software\\wow6432node\\microsoft\\windows\\currentversion\\explorer\\folderdescriptions\\{5e6c858f-0e22-4760-9afe-ea3317b67173}\\name',
#   0.000711),
#  ('hkey_local_machine\\software\\wow6432node\\microsoft\\windows\\currentversion\\explorer\\folderdescriptions\\{5e6c858f-0e22-4760-9afe-ea3317b67173}\\attributes',
#   0.000711),
#  ('hkey_local_machine\\software\\wow6432node\\microsoft\\windows\\currentversion\\explorer\\folderdescriptions\\{5e6c858f-0e22-4760-9afe-ea3317b67173}\\roamable',
#   0.000711),
#  ('hkey_local_machine\\software\\wow6432node\\microsoft\\windows\\currentversion\\explorer\\folderdescriptions\\{5e6c858f-0e22-4760-9afe-ea3317b67173}\\description',
#   0.000711),
#  ('hkey_local_machine\\software\\wow6432node\\microsoft\\windows\\currentversion\\explorer\\folderdescriptions\\{5e6c858f-0e22-4760-9afe-ea3317b67173}\\streamresourcetype',
#   0.000711),
#  ('hkey_local_machine\\software\\wow6432node\\microsoft\\windows\\currentversion\\explorer\\folderdescriptions\\{5e6c858f-0e22-4760-9afe-ea3317b67173}\\initfolderhandler',
#   0.000711),
#  ('hkey_local_machine\\software\\wow6432node\\microsoft\\tracing\\rasmancs\\enableconsoletracing',
#   0.00064),
#  ('hkey_local_machine\\software\\wow6432node\\microsoft\\tracing\\rasmancs\\enablefiletracing',
#   0.00064),
#  ('hkey_local_machine\\software\\wow6432node\\microsoft\\tracing\\rasmancs\\maxfilesize',
#   0.00064),
#  ('hkey_local_machine\\software\\wow6432node\\microsoft\\tracing\\rasmancs\\filetracingmask',
#   0.00064),
#  ('hkey_local_machine\\software\\wow6432node\\microsoft\\tracing\\rasmancs\\consoletracingmask',
#   0.00064),
#  ('hkey_local_machine\\software\\wow6432node\\microsoft\\tracing\\rasmancs\\filedirectory',
#   0.00064),
#  ('hkey_local_machine\\system\\controlset001\\control\\nls\\extendedlocale\\en-us',
#   0.00064),
#  ('hkey_local_machine\\software\\microsoft\\sqmclient\\windows\\ceipenable',
#   0.00064),
#  ('hkey_local_machine\\system\\setup\\systemsetupinprogress', 0.00064),
#  ('hkey_local_machine\\system\\controlset001\\control\\nls\\customlocale\\en-us',
#   0.00064),
#  ('hkey_local_machine\\software\\wow6432node\\microsoft\\windows\\currentversion\\explorer\\folderdescriptions\\{56784854-c6cb-462b-8169-88e350acb882}',
#   0.000616),
#  ('hkey_current_user\\software\\policies\\microsoft\\windows\\explorer',
#   0.000616),
#  ('hkey_local_machine\\software\\policies\\microsoft\\windows\\explorer',
#   0.000616),
#  ('hkey_local_machine\\software\\wow6432node\\microsoft\\windows\\currentversion\\explorer\\folderdescriptions\\{56784854-c6cb-462b-8169-88e350acb882}\\propertybag',
#   0.000616),
#  ('hkey_local_machine\\software\\wow6432node\\microsoft\\windows\\currentversion\\explorer\\folderdescriptions\\{56784854-c6cb-462b-8169-88e350acb882}\\parsingname',
#   0.000616)]

# %%
import pandas as pd
# write to dataframe
normal_df = pd.DataFrame(normal_query_weights, columns=['features', 'weights'])
normal_rank = range(1,len(normal_weights_dict)+1)
normal_df['rank']=normal_rank

# %%
# write to dataframe
ransom_df = pd.DataFrame(ransom_query_weights, columns=['features', 'weights'])
ransom_rank = range(1,len(ransom_weights_dict)+1)
ransom_df['rank'] = ransom_rank

# %%
ransom_df
# Out:
#                                                features   weights  rank
# 0     hkey_local_machine\software\microsoft\windows ...  0.001185     1
# 1     hkey_local_machine\software\classes\allfilesys...  0.000853     2
# 2     hkey_local_machine\software\classes\allfilesys...  0.000853     3
# 3     hkey_local_machine\software\classes\directory\...  0.000853     4
# 4     hkey_local_machine\software\classes\folder\doc...  0.000853     5
# ...                                                 ...       ...   ...
# 6447          hkey_current_user\software\sistemanet\lk4  0.000024  6448
# 6448  hkey_current_user\software\microsoft\windows\c...  0.000024  6449
# 6449  hkey_current_user\software\microsoft\windows\c...  0.000024  6450
# 6450  hkey_current_user\software\microsoft\windows\c...  0.000024  6451
# 6451  hkey_current_user\software\microsoft\windows\c...  0.000024  6452
#
# [6452 rows x 3 columns]

# %%
ransom_df[ransom_df['weights']>0.0006]
# Out:
#                                              features   weights  rank
# 0   hkey_local_machine\software\microsoft\windows ...  0.001185     1
# 1   hkey_local_machine\software\classes\allfilesys...  0.000853     2
# 2   hkey_local_machine\software\classes\allfilesys...  0.000853     3
# 3   hkey_local_machine\software\classes\directory\...  0.000853     4
# 4   hkey_local_machine\software\classes\folder\doc...  0.000853     5
# ..                                                ...       ...   ...
# 65  hkey_local_machine\software\wow6432node\micros...  0.000616    66
# 66  hkey_local_machine\software\wow6432node\micros...  0.000616    67
# 67  hkey_current_user\software\microsoft\windows\c...  0.000616    68
# 68  hkey_local_machine\software\wow6432node\micros...  0.000616    69
# 69  hkey_local_machine\software\wow6432node\micros...  0.000616    70
#
# [70 rows x 3 columns]

# %%
df1 = ransom_df[ransom_df['weights']>0.0007]
df1
# Out:
#                                              features   weights  rank
# 0   hkey_local_machine\software\microsoft\windows ...  0.001185     1
# 1   hkey_local_machine\software\classes\allfilesys...  0.000853     2
# 2   hkey_local_machine\software\classes\allfilesys...  0.000853     3
# 3   hkey_local_machine\software\classes\directory\...  0.000853     4
# 4   hkey_local_machine\software\classes\folder\doc...  0.000853     5
# 5   hkey_local_machine\software\classes\directory\...  0.000853     6
# 6   hkey_local_machine\software\classes\folder\bro...  0.000853     7
# 7   hkey_local_machine\software\microsoft\windows ...  0.000735     8
# 8   hkey_local_machine\software\microsoft\windows\...  0.000711     9
# 9   hkey_local_machine\software\wow6432node\micros...  0.000711    10
# 10  hkey_current_user\software\microsoft\windows\c...  0.000711    11
# 11  hkey_current_user\software\microsoft\windows\c...  0.000711    12
# 12  hkey_current_user\software\microsoft\windows\c...  0.000711    13
# 13  hkey_local_machine\software\wow6432node\micros...  0.000711    14
# 14  hkey_local_machine\software\wow6432node\micros...  0.000711    15
# 15  hkey_local_machine\software\wow6432node\micros...  0.000711    16
# 16  hkey_local_machine\software\wow6432node\micros...  0.000711    17
# 17  hkey_local_machine\software\wow6432node\micros...  0.000711    18
# 18  hkey_local_machine\software\wow6432node\micros...  0.000711    19
# 19  hkey_local_machine\software\wow6432node\micros...  0.000711    20
# 20  hkey_local_machine\software\wow6432node\micros...  0.000711    21
# 21  hkey_local_machine\software\wow6432node\micros...  0.000711    22
# 22  hkey_local_machine\software\wow6432node\micros...  0.000711    23
# 23  hkey_local_machine\software\wow6432node\micros...  0.000711    24
# 24  hkey_local_machine\software\microsoft\windows ...  0.000711    25
# 25  hkey_local_machine\software\wow6432node\micros...  0.000711    26
# 26  hkey_local_machine\software\wow6432node\micros...  0.000711    27
# 27  hkey_local_machine\software\wow6432node\micros...  0.000711    28
# 28  hkey_local_machine\software\wow6432node\micros...  0.000711    29
# 29  hkey_local_machine\software\wow6432node\micros...  0.000711    30
# 30  hkey_local_machine\software\wow6432node\micros...  0.000711    31
# 31  hkey_local_machine\software\wow6432node\micros...  0.000711    32
# 32  hkey_local_machine\software\wow6432node\micros...  0.000711    33
# 33  hkey_local_machine\software\wow6432node\micros...  0.000711    34
# 34  hkey_local_machine\software\wow6432node\micros...  0.000711    35

# %%
pd.concat([df1, normal_df], axis=1, join='inner')
feature_ranks = df1.merge(normal_df, on=['features'])
feature_ranks_com = feature_ranks[['features','rank_x','rank_y']]
feature_ranks_com
# Out:
#                                              features  rank_x  rank_y
# 0   hkey_local_machine\software\microsoft\windows ...       1     606
# 1   hkey_local_machine\software\classes\allfilesys...       2       4
# 2   hkey_local_machine\software\classes\allfilesys...       3       1
# 3   hkey_local_machine\software\classes\directory\...       4       2
# 4   hkey_local_machine\software\classes\folder\doc...       5       5
# 5   hkey_local_machine\software\classes\directory\...       6       3
# 6   hkey_local_machine\software\classes\folder\bro...       7       6
# 7   hkey_local_machine\software\microsoft\windows ...       8      26
# 8   hkey_local_machine\software\microsoft\windows\...       9      61
# 9   hkey_local_machine\software\wow6432node\micros...      10      67
# 10  hkey_current_user\software\microsoft\windows\c...      11      68
# 11  hkey_current_user\software\microsoft\windows\c...      12      62
# 12  hkey_current_user\software\microsoft\windows\c...      13      20
# 13  hkey_local_machine\software\wow6432node\micros...      14      63
# 14  hkey_local_machine\software\wow6432node\micros...      15      75
# 15  hkey_local_machine\software\wow6432node\micros...      16      79
# 16  hkey_local_machine\software\wow6432node\micros...      17      86
# 17  hkey_local_machine\software\wow6432node\micros...      18      91
# 18  hkey_local_machine\software\wow6432node\micros...      19      71
# 19  hkey_local_machine\software\wow6432node\micros...      20      77
# 20  hkey_local_machine\software\wow6432node\micros...      21      80
# 21  hkey_local_machine\software\wow6432node\micros...      22      85
# 22  hkey_local_machine\software\wow6432node\micros...      23      88
# 23  hkey_local_machine\software\wow6432node\micros...      24      69
# 24  hkey_local_machine\software\microsoft\windows ...      25      33
# 25  hkey_local_machine\software\wow6432node\micros...      26      78
# 26  hkey_local_machine\software\wow6432node\micros...      27      84
# 27  hkey_local_machine\software\wow6432node\micros...      28      72
# 28  hkey_local_machine\software\wow6432node\micros...      29      81
# 29  hkey_local_machine\software\wow6432node\micros...      30      87
# 30  hkey_local_machine\software\wow6432node\micros...      31      92
# 31  hkey_local_machine\software\wow6432node\micros...      32      76
# 32  hkey_local_machine\software\wow6432node\micros...      33      89
# 33  hkey_local_machine\software\wow6432node\micros...      34      90
# 34  hkey_local_machine\software\wow6432node\micros...      35      83

# %%
feature_final = feature_ranks_com[feature_ranks_com['rank_y']>35]
feature_final
# Out:
#                                              features  rank_x  rank_y
# 0   hkey_local_machine\software\microsoft\windows ...       1     606
# 8   hkey_local_machine\software\microsoft\windows\...       9      61
# 9   hkey_local_machine\software\wow6432node\micros...      10      67
# 10  hkey_current_user\software\microsoft\windows\c...      11      68
# 11  hkey_current_user\software\microsoft\windows\c...      12      62
# 13  hkey_local_machine\software\wow6432node\micros...      14      63
# 14  hkey_local_machine\software\wow6432node\micros...      15      75
# 15  hkey_local_machine\software\wow6432node\micros...      16      79
# 16  hkey_local_machine\software\wow6432node\micros...      17      86
# 17  hkey_local_machine\software\wow6432node\micros...      18      91
# 18  hkey_local_machine\software\wow6432node\micros...      19      71
# 19  hkey_local_machine\software\wow6432node\micros...      20      77
# 20  hkey_local_machine\software\wow6432node\micros...      21      80
# 21  hkey_local_machine\software\wow6432node\micros...      22      85
# 22  hkey_local_machine\software\wow6432node\micros...      23      88
# 23  hkey_local_machine\software\wow6432node\micros...      24      69
# 25  hkey_local_machine\software\wow6432node\micros...      26      78
# 26  hkey_local_machine\software\wow6432node\micros...      27      84
# 27  hkey_local_machine\software\wow6432node\micros...      28      72
# 28  hkey_local_machine\software\wow6432node\micros...      29      81
# 29  hkey_local_machine\software\wow6432node\micros...      30      87
# 30  hkey_local_machine\software\wow6432node\micros...      31      92
# 31  hkey_local_machine\software\wow6432node\micros...      32      76
# 32  hkey_local_machine\software\wow6432node\micros...      33      89
# 33  hkey_local_machine\software\wow6432node\micros...      34      90
# 34  hkey_local_machine\software\wow6432node\micros...      35      83

# %%
feature_final.reset_index()
# Out:
#     index                                           features  rank_x  rank_y
# 0       0  hkey_local_machine\software\microsoft\windows ...       1     606
# 1       8  hkey_local_machine\software\microsoft\windows\...       9      61
# 2       9  hkey_local_machine\software\wow6432node\micros...      10      67
# 3      10  hkey_current_user\software\microsoft\windows\c...      11      68
# 4      11  hkey_current_user\software\microsoft\windows\c...      12      62
# 5      13  hkey_local_machine\software\wow6432node\micros...      14      63
# 6      14  hkey_local_machine\software\wow6432node\micros...      15      75
# 7      15  hkey_local_machine\software\wow6432node\micros...      16      79
# 8      16  hkey_local_machine\software\wow6432node\micros...      17      86
# 9      17  hkey_local_machine\software\wow6432node\micros...      18      91
# 10     18  hkey_local_machine\software\wow6432node\micros...      19      71
# 11     19  hkey_local_machine\software\wow6432node\micros...      20      77
# 12     20  hkey_local_machine\software\wow6432node\micros...      21      80
# 13     21  hkey_local_machine\software\wow6432node\micros...      22      85
# 14     22  hkey_local_machine\software\wow6432node\micros...      23      88
# 15     23  hkey_local_machine\software\wow6432node\micros...      24      69
# 16     25  hkey_local_machine\software\wow6432node\micros...      26      78
# 17     26  hkey_local_machine\software\wow6432node\micros...      27      84
# 18     27  hkey_local_machine\software\wow6432node\micros...      28      72
# 19     28  hkey_local_machine\software\wow6432node\micros...      29      81
# 20     29  hkey_local_machine\software\wow6432node\micros...      30      87
# 21     30  hkey_local_machine\software\wow6432node\micros...      31      92
# 22     31  hkey_local_machine\software\wow6432node\micros...      32      76
# 23     32  hkey_local_machine\software\wow6432node\micros...      33      89
# 24     33  hkey_local_machine\software\wow6432node\micros...      34      90
# 25     34  hkey_local_machine\software\wow6432node\micros...      35      83
