# %% [markdown]
# # The realization of TF-IDF for sentences
#
# **document will be composed of api callings and registry operations**

# %%
from nltk.corpus import stopwords
import pickle
import pandas as pd

# %%
# combine the title with the values
def splice_key_value(file):
    registry_values = []
    with open(file,'rb') as fr:
        registry_values_dict = pickle.load(fr, encoding="bytes")
    for key, values in registry_values_dict.items():
        for value in values:
            registry_values.append(key+'_'+str(value))
    return registry_values

# %%
registry_values_ransom_file = '../dataset/registry_values/registry_values_ransom.pkl'
registry_values_normal_file = '../dataset/registry_values/registry_values_normal.pkl'

registry_values_ransom_list = splice_key_value(registry_values_ransom_file)
registry_values_normal_list = splice_key_value(registry_values_normal_file)

# %%
len(registry_values_ransom_list)
# Out:
# 50515

# %%
len(set(registry_values_ransom_list))
# Out:
# 6657

# %%
registry_values_ransom_list[:5]
# Out:
# ['regkey_opened_HKEY_LOCAL_MACHINE\\System\\CurrentControlSet\\Services\\DnsCache\\Parameters',
#  'regkey_opened_HKEY_LOCAL_MACHINE\\Software\\Policies\\Microsoft\\Windows NT\\DnsClient',
#  'regkey_opened_HKEY_LOCAL_MACHINE\\Software\\Microsoft\\Tracing',
#  'regkey_opened_HKEY_LOCAL_MACHINE\\Software\\Policies\\Microsoft\\System\\DNSClient',
#  'regkey_opened_HKEY_LOCAL_MACHINE\\System\\CurrentControlSet\\Services\\Tcpip\\Parameters']

# %% [markdown]
# # Term Frequency

# %%
import numpy as np

# function to convert string to lower case and delete the stop words in document
def preprocess_string(document):
    stop_words = set(stopwords.words('english'))
    # convert to lowercase
    registry_values_list = np.char.lower(document)
    # split sentences into words
    registry_words = []
    for registry_value in registry_values_list:
        words = registry_value.split("\\")
        for word in words:
            registry_words.append(word)
    # delete stop words in them
    for stop_word in stop_words:
        try:
            registry_words.remove(stop_word)
        except:
            continue
        finally:
            return registry_words

# %%
# here, we count how many times a word appears in the words array
# we do not use n-grams,cuz there are single string not only word
from collections import Counter

def countWords(words):
    '''
        return: a dictionary of {WORD: COUNT} where count is how many times
        that word appears in "words"
    '''
    words_dict ={}
    word_dict = Counter(words)
    return word_dict

# %%
# calculate the frequency of term in a document
def termFrequency(document):
    word_freq = {}
    # get the words without stop words
    registry_words = preprocess_string(document)
    # get the count for terms
    word_dict = countWords(registry_words)
    for key, value in word_dict.items():
        word_freq[key] = word_dict[key]/len(registry_words)
    return word_freq

# %% [markdown]
# calculate the TF for two datasets

# %%
word_freq_ransom = termFrequency(registry_values_ransom_list)
word_freq_normal = termFrequency(registry_values_normal_list)

# %%
# calculate the sentence importance
def senFrequency(sentence, word_freq):
    # split the sentence into words
    words_list = sentence.split('\\')
    words_list = np.char.lower(words_list)
    # log the frequency of sentences
    sen_freq_total = 0
    # log the number of non stop words in each process
    num = 0
    for word, freq in word_freq.items():
        if word in words_list:
            sen_freq_total += word_freq[word]
            num += 1
    sen_freq = np.round(sen_freq_total/num ,3)
    return sen_freq

# %%
# # generate the sen_freq dict with indexes as the keys
# sen_freq_ran_dict = {}
# for i, sentence in enumerate(registry_values_ransom_list): 
#     # input the lowercased sentence
    
#     sen_freq = senFrequency(sentence, word_freq_ransom)
#     sen_freq_ran_dict[str(i)] = sen_freq

# %% [markdown]
# generate the sen_freq dict with strings as the keys

# %%
try:
    with open('../dataset/TF_IDF_Sen/sen_freq_ran_dict.pkl','rb') as fr:
        sen_freq_ran_dict = pickle.load(fr)
except:
    print('[-] The file does not exist! \n')
    print('Creating new file now!')
    sen_freq_ran_dict = {}

    for sentence in registry_values_ransom_list: 
        # input the lowercase sentence
        sen_freq = senFrequency(sentence, word_freq_ransom)
        sen_freq_ran_dict[sentence] = sen_freq
    # save the result
    with open('../dataset/TF_IDF_Sen/sen_freq_ran_dict.pkl','wb') as fw:
        data = pickle.dump(sen_freq_ran_dict, fw)

# %%
# sen_freq_ran_dict

# %%
try:
    with open('../dataset/TF_IDF_Sen/sen_freq_nor_dict.pkl','rb') as fr:
        sen_freq_nor_dict = pickle.load(fr)
except:
    print('[-] The file does not exist!')
    print('Creating new file now!')

    sen_freq_nor_dict = {}

    for sentence in registry_values_normal_list: 
        # input the lowercase sentence
        sen_freq = senFrequency(sentence, word_freq_normal)
        sen_freq_nor_dict[sentence] = sen_freq
    # save the result
    with open('../dataset/TF_IDF_Sen/sen_freq_nor_dict.pkl','wb') as fw:
        data = pickle.dump(sen_freq_nor_dict, fw)

# %%
# sen_freq_nor_dict

# %% [markdown]
# # Inverse document frequency

# %%
# IDF used over many documents, here, each sentence is its own document
# IDF = ln(number of docs/number docs the term appears in)
import math

def InverseDocumentFreq(document):
    # get all the unique words
    registry_words =  preprocess_string(document)
    # get the word dict with {word: occurences} in all documents
    word_dict = countWords(registry_words)
    # the number of document
    num_docs = len(document)
    # calculate the IDF for every words
    word_IDF = {}
    for word in registry_words:
        word_IDF[word] = np.round(math.log10(num_docs/word_dict[word]), 3)

    return word_IDF

# %% [markdown]
# calculate the IDF for two datasets

# %%
word_IDF_ran = InverseDocumentFreq(registry_values_ransom_list)
word_IDF_nor = InverseDocumentFreq(registry_values_normal_list)

# %%
# len(word_IDF_nor)

# %%
# word_IDF_ran

# %%
# calculate the IDF for single sentence
def SentenceIDF(word_IDF, sentence):
    # split the sentence into words
    words_list = sentence.split('\\')
    words_list = np.char.lower(words_list)
    # log the frequency of sentences
    sen_IDF_total = 0
    # log the number of non stop words in each process
    num = 0
    for word, IDF in word_IDF.items():
        if word in words_list:
            sen_IDF_total += word_IDF[word]
            num += 1
    sen_IDF = np.round(sen_IDF_total/num ,3)
    return sen_IDF

# %% [markdown]
# calculate the IDF for all sentences in ran dataset:

# %%
try:
    with open('../dataset/TF_IDF_Sen/sen_IDF_nor_dict.pkl','rb') as fr:
        sen_IDF_nor_dict = pickle.load(fr)
except:
    print('[-] The file does not exist! \n')
    print('Creating new file now!')
    sen_IDF_nor_dict = {}
    
    sen_IDF_nor_dict = {sentence: SentenceIDF(word_IDF_nor, sentence) for sentence in registry_values_normal_list}
    
#     for sentence in registry_values_normal_list:
#         sen_IDF = SentenceIDF(word_IDF_nor, sentence)
#         sen_IDF_nor_dict[sentence] = sen_IDF
    # save the result
    with open('../dataset/TF_IDF_Sen/sen_IDF_nor_dict.pkl','wb') as fw:
        data = pickle.dump(sen_IDF_nor_dict, fw)

# %%
try:
    with open('../dataset/TF_IDF_Sen/sen_IDF_ran_dict.pkl','rb') as fr:
        sen_IDF_ran_dict = pickle.load(fr)
except:
    print('[-] The file does not exist! \n')
    print('Creating new file now!')
    sen_IDF_ran_dict = {}

    for sentence in registry_values_ransom_list:
        sen_IDF = SentenceIDF(word_IDF_ran, sentence)
        sen_IDF_ran_dict[sentence] = sen_IDF
    # save the result
    with open('../dataset/TF_IDF_Sen/sen_IDF_ran_dict.pkl','wb') as fw:
        data = pickle.dump(sen_IDF_ran_dict, fw)

# %%
# calculate the TF_IDF for sentences
def TF_IDF(sen_TF_dict, sen_IDF_dict):
    # two dict should have the same keys
    sen_TF_IDF = {}
    for key in sen_TF_dict.keys():
        sen_TF_IDF[key] = sen_TF_dict[key] * sen_IDF_dict[key]
        
    return sen_TF_IDF

# %% [markdown]
# calculate the sentence importance for two datasets

# %%
sen_ran_TF_IDF = TF_IDF(sen_freq_ran_dict, sen_IDF_ran_dict)
sen_nor_TF_IDF = TF_IDF(sen_freq_nor_dict, sen_IDF_nor_dict)

# %%
sen_ran_TF_IDF
# Out:
# {'regkey_opened_HKEY_LOCAL_MACHINE\\System\\CurrentControlSet\\Services\\DnsCache\\Parameters': 0.008548,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\Software\\Policies\\Microsoft\\Windows NT\\DnsClient': 0.047323,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\Software\\Microsoft\\Tracing': 0.04202,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\Software\\Policies\\Microsoft\\System\\DNSClient': 0.046322,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\System\\CurrentControlSet\\Services\\Tcpip\\Parameters': 0.00816,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\Software\\Microsoft\\Tracing\\RASMANCS': 0.048355999999999996,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\SOFTWARE\\Wow6432Node\\Microsoft\\Windows\\CurrentVersion\\explorer\\FolderDescriptions\\{FDD39AD0-238F-46AF-ADB4-6C85480369C7}\\PropertyBag': 0.032086,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\SOFTWARE\\Wow6432Node\\Microsoft\\Windows\\CurrentVersion\\explorer\\FolderDescriptions\\{E555AB60-153B-4D17-9F04-A5FE99FC15EC}': 0.030485,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\Software\\Microsoft\\Windows\\CurrentVersion\\Explorer\\UsersFiles\\NameSpace': 0.04634200000000001,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\SOFTWARE\\Wow6432Node\\Microsoft\\Windows\\CurrentVersion\\explorer\\FolderDescriptions\\{6F0CD92B-2E97-45D1-88FF-B0D186B8DEDD}': 0.030485,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\SOFTWARE\\Wow6432Node\\Microsoft\\Windows\\CurrentVersion\\explorer\\FolderDescriptions\\{C4900540-2379-4C75-844B-64E6FAF8716B}\\PropertyBag': 0.034464999999999996,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\SOFTWARE\\Wow6432Node\\Microsoft\\Windows\\CurrentVersion\\explorer\\FolderDescriptions\\{A302545D-DEFF-464B-ABE8-61C8648D939B}\\PropertyBag': 0.034464999999999996,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\SOFTWARE\\Wow6432Node\\Microsoft\\Windows\\CurrentVersion\\explorer\\FolderDescriptions\\{B88F4DAA-E7BD-49A9-B74D-02885A5DC765}': 0.030485,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\Software\\Microsoft\\Windows\\CurrentVersion\\Explorer\\KnownFolderSettings': 0.044154000000000006,
#  'regkey_opened_HKEY_CLASSES_ROOT\\Directory': 0.002002,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\SOFTWARE\\Wow6432Node\\Microsoft\\Windows\\CurrentVersion\\explorer\\FolderDescriptions\\{724EF170-A42D-4FEF-9F26-B60E846FBA4F}': 0.030485,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\SOFTWARE\\Wow6432Node\\Microsoft\\Windows\\CurrentVersion\\explorer\\FolderDescriptions\\{A4115719-D62E-491D-AA7C-E74B8BE3B067}\\PropertyBag': 0.034464999999999996,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\Software\\Microsoft\\Windows\\CurrentVersion\\Explorer\\FolderDescriptions': 0.016425,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\SOFTWARE\\Wow6432Node\\Microsoft\\Windows\\CurrentVersion\\explorer\\FolderDescriptions\\{7C5A40EF-A0FB-4BFC-874A-C0F2E0B9FA8E}\\PropertyBag': 0.032208,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\SOFTWARE\\Wow6432Node\\Microsoft\\Windows\\CurrentVersion\\explorer\\FolderDescriptions\\{D0384E7D-BAC3-4797-8F14-CBA229B392B5}\\PropertyBag': 0.034464999999999996,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\SOFTWARE\\Wow6432Node\\Microsoft\\Windows\\CurrentVersion\\explorer\\FolderDescriptions\\{724EF170-A42D-4FEF-9F26-B60E846FBA4F}\\PropertyBag': 0.034464999999999996,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\SOFTWARE\\Wow6432Node\\Microsoft\\Windows\\CurrentVersion\\explorer\\FolderDescriptions\\{82A74AEB-AEB4-465C-A014-D097EE346D63}\\PropertyBag': 0.034464999999999996,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\SOFTWARE\\Wow6432Node\\Microsoft\\Windows\\CurrentVersion\\explorer\\FolderDescriptions\\{2A00375E-224C-49DE-B8D1-440DF7EF3DDC}': 0.030485,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\SOFTWARE\\Wow6432Node\\Microsoft\\Windows\\CurrentVersion\\explorer\\FolderDescriptions\\{1777F761-68AD-4D8A-87BD-30B759FA33DD}\\PropertyBag': 0.032086,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\Software\\Microsoft\\Windows\\CurrentVersion\\Explorer\\UsersFiles\\NameSpace\\DelegateFolders': 0.05145899999999999,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\Software\\Microsoft\\Windows\\CurrentVersion\\Explorer\\CLSID\\{59031A47-3F72-44A7-89C5-5595FE6B30EE}\\ShellFolder': 0.039155999999999996,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\SOFTWARE\\Wow6432Node\\Microsoft\\Windows\\CurrentVersion\\explorer\\FolderDescriptions\\{F1B32785-6FBA-4FCF-9D55-7B8E7F157091}': 0.030485,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\SOFTWARE\\Wow6432Node\\Microsoft\\Windows\\CurrentVersion\\explorer\\FolderDescriptions\\{9E52AB10-F80D-49DF-ACB8-4330F5687855}': 0.030485,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\SOFTWARE\\Wow6432Node\\Microsoft\\Windows\\CurrentVersion\\explorer\\FolderDescriptions\\{56784854-C6CB-462B-8169-88E350ACB882}': 0.026792000000000003,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\SOFTWARE\\Wow6432Node\\Microsoft\\Windows\\CurrentVersion\\explorer\\FolderDescriptions\\{8983036C-27C0-404B-8F08-102D10DCFD74}': 0.030485,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\SOFTWARE\\Wow6432Node\\Microsoft\\Windows\\CurrentVersion\\explorer\\FolderDescriptions\\{859EAD94-2E85-48AD-A71A-0969CB56A6CD}': 0.030485,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\SOFTWARE\\Wow6432Node\\Microsoft\\Windows\\CurrentVersion\\explorer\\FolderDescriptions\\{859EAD94-2E85-48AD-A71A-0969CB56A6CD}\\PropertyBag': 0.034464999999999996,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\SOFTWARE\\Microsoft\\Windows\\CurrentVersion\\ShellCompatibility\\Applications\\VirusShare_4dec330daa442782728720869ce6b11c.exe': 0.061544,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\SOFTWARE\\Wow6432Node\\Microsoft\\Windows\\CurrentVersion\\explorer\\FolderDescriptions\\{69D2CF90-FC33-4FB7-9A0C-EBB0F0FCB43C}': 0.030485,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\SOFTWARE\\Wow6432Node\\Microsoft\\Windows\\CurrentVersion\\explorer\\FolderDescriptions\\{F1B32785-6FBA-4FCF-9D55-7B8E7F157091}\\PropertyBag': 0.034464999999999996,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\SOFTWARE\\Wow6432Node\\Microsoft\\Windows\\CurrentVersion\\explorer\\FolderDescriptions\\{DEBF2536-E1A8-4C59-B6A2-414586476AEA}\\PropertyBag': 0.034464999999999996,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\SOFTWARE\\Wow6432Node\\Microsoft\\Windows\\CurrentVersion\\explorer\\FolderDescriptions\\{4BD8D571-6D19-48D3-BE97-422220080E43}\\PropertyBag': 0.032086,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\SOFTWARE\\Wow6432Node\\Microsoft\\Windows\\CurrentVersion\\explorer\\FolderDescriptions\\{3214FAB5-9757-4298-BB61-92A9DEAA44FF}\\PropertyBag': 0.032086,
#  'regkey_opened_HKEY_CLASSES_ROOT\\Folder': 0.002093,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\SOFTWARE\\Wow6432Node\\Microsoft\\Windows\\CurrentVersion\\explorer\\FolderDescriptions\\{374DE290-123F-4565-9164-39C4925E467B}\\PropertyBag': 0.031964,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\SOFTWARE\\Wow6432Node\\Microsoft\\Windows\\CurrentVersion\\explorer\\FolderDescriptions\\{C1BAE2D0-10DF-4334-BEDD-7AA20B227A9D}\\PropertyBag': 0.034464999999999996,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\SOFTWARE\\Classes\

#  'regkey_opened_HKEY_LOCAL_MACHINE\\SOFTWARE\\Wow6432Node\\Microsoft\\Cryptography\\OID\\EncodingType 1\\CryptDllEncodeObjectEx': 0.053579999999999996,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\SOFTWARE\\Wow6432Node\\Microsoft\\Internet Explorer\\MAIN\\FeatureControl\\FEATURE_BLOCK_LMZ_SCRIPT': 0.046094,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\SOFTWARE\\Wow6432Node\\Microsoft\\Cryptography\\OID\\EncodingType 0\\CryptDllFindOIDInfo\\1.3.6.1.4.1.311.64.1.1!7': 0.052371,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\SOFTWARE\\Microsoft\\CTF\\TIP\\{531FDEBF-9B4C-4A43-A2AA-960E8FCDC732}\\LanguageProfile\\0x00000404\\{0B883BA0-C1C7-11D4-87F9-0080C882687E}': 0.038194,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\SOFTWARE\\MICROSOFT\\CTF\\TIP\\{E429B25A-E5D3-4D1F-9BE3-0C608477E3A1}\\LanguageProfile\\0x0000045e': 0.03874400000000001,
#  'regkey_opened_HKEY_CURRENT_USER\\Software\\Microsoft\\Windows\\CurrentVersion\\Internet Settings\\Wpad\\0a-00-27-00-00-13_52-54-00-12-35-00': 0.055271999999999995,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\SOFTWARE\\Classes\\TypeLib\\{5E77EB03-937C-11D1-B047-00AA003B6061}\\1.1\\0': 0.035188000000000004,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\SOFTWARE\\Classes\\Wow6432Node\\CLSID\\{B196B286-BAB4-101A-B69C-00AA00341D07}\\Progid': 0.040951,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\SOFTWARE\\RegisteredApplications': 0.05412,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\Software\\Microsoft\\Cryptography\\Providers\\Trust\\Initialization\\{573E31F8-AABA-11D0-8CCB-00C04FC295EE}': 0.050932,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\SOFTWARE\\MICROSOFT\\CTF\\TIP\\{AE6BE008-07FB-400D-8BEB-337A64F7051F}\\Category\\Category\\{5130A009-5540-4FCF-97EB-AAD33FC0EE09}': 0.039701,
#  'regkey_opened_HKEY_CURRENT_USER\\SOFTWARE\\Microsoft\\CTF\\TIP\\{8613E14C-D0C0-4161-AC0F-1DD2563286BC}\\LanguageProfile\\0x00000804\\{B37D4237-8D1A-412E-9026-538FE16DF216}': 0.037559999999999996,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\Software\\Policies\\Microsoft\\SystemCertificates\\TrustedPublisher\\Safer': 0.053408000000000004,
#  'regkey_opened_HKEY_CURRENT_USER\\Software\\Microsoft\\Internet Explorer\\MenuExt\\%s': 0.0639,
#  'regkey_opened_HKEY_CURRENT_USER\\Interface\\{26656EAA-54EB-4E6F-8F85-4F0EF901A406}': 0.0046159999999999994,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\System\\CurrentControlSet\\Services\\LanmanWorkstation\\Parameters': 0.008484,
#  'regkey_opened_HKEY_CURRENT_USER\\Software\\Microsoft\\Windows\\CurrentVersion\\Explorer\\FileExts\\.url\\OpenWithProgids': 0.059,
#  'regkey_opened_HKEY_LOCAL_MACHINE\\SOFTWARE\\Classes\\Wow6432Node\\Interface\\{BCD1DE7E-2DB1-418B-B047-4A74E101F8C1}\\ProxyStubClsid32': 0.043019999999999996,
#  'regkey_opened_HKEY_CURRENT_USER\\SOFTWARE\\Microsoft\\CTF\\DirectSwitchHotkeys\\': 0.05468399999999999,
#  ...}

# %% [markdown]
# compare the importance ranking for two datasets

# %%
# create the rank dataframe for ransomware dataset
sen_ran_df = pd.Series(list(sen_ran_TF_IDF.keys())).reset_index()
sen_ran_df.columns = ['Index','Features']
sen_ran_df['importance'] = pd.Series(list(sen_ran_TF_IDF.values()))
sen_ran_df = sen_ran_df.sort_values(by=['importance'], ascending=False)
sen_ran_df['rank'] = range(1,len(sen_ran_df)+1)
sen_ran_df
# Out:
#       Index                                           Features  importance  \
# 6206   6206  regkey_read_HKEY_LOCAL_MACHINE\SOFTWARE\Wow643...    0.093184
# 448     448  regkey_opened_HKEY_LOCAL_MACHINE\SOFTWARE\Micr...    0.090552
# 4885   4885  regkey_read_HKEY_LOCAL_MACHINE\SOFTWARE\MICROS...    0.087808
# 4625   4625  regkey_read_HKEY_LOCAL_MACHINE\SOFTWARE\MICROS...    0.087808
# 6642   6642  regkey_written_HKEY_CURRENT_USER\Software\Micr...    0.086592
# ...     ...                                                ...         ...
# 5531   5531         regkey_read_\bEnableAlternateTempDirectory    0.000000
# 5552   5552         regkey_read_\bEnableGlobalAtomRestrictions    0.000000
# 5614   5614              regkey_read_\bEnforceReadRestrictions    0.000000
# 5631   5631                  regkey_read_\iMaxMRUCntToBeStored    0.000000
# 5655   5655         regkey_read_\bEnableAlternateLaunchDesktop    0.000000
#
#       rank
# 6206     1
# 448      2
# 4885     3
# 4625     4
# 6642     5
# ...    ...
# 5531  6653
# 5552  6654
# 5614  6655
# 5631  6656
# 5655  6657
#
# [6657 rows x 4 columns]

# %%
# create the rank dataframe for normal dataset
sen_nor_df = pd.Series(list(sen_nor_TF_IDF.keys())).reset_index()
sen_nor_df.columns = ['Index', 'Features']
sen_nor_df['importance'] = pd.Series(list(sen_nor_TF_IDF.values()))
sen_nor_df = sen_nor_df.sort_values(by=['importance'], ascending=False)
sen_nor_df['rank'] = range(1, len(sen_nor_df)+1)
sen_nor_df
# Out:
#       Index                                           Features  importance  \
# 6707   6707  regkey_read_HKEY_LOCAL_MACHINE\SOFTWARE\Wow643...    0.110596
# 6359   6359  regkey_read_HKEY_LOCAL_MACHINE\SOFTWARE\Wow643...    0.108940
# 4778   4778  regkey_read_HKEY_LOCAL_MACHINE\SOFTWARE\MICROS...    0.101304
# 5038   5038  regkey_read_HKEY_LOCAL_MACHINE\SOFTWARE\MICROS...    0.101304
# 6656   6656  regkey_read_HKEY_LOCAL_MACHINE\SOFTWARE\MICROS...    0.099748
# ...     ...                                                ...         ...
# 5684   5684         regkey_read_\bEnableAlternateTempDirectory    0.000000
# 5901   5901       regkey_read_\bEnableBinaryPlantingProtection    0.000000
# 5705   5705         regkey_read_\bEnableGlobalAtomRestrictions    0.000000
# 5808   5808         regkey_read_\bEnableAlternateLaunchDesktop    0.000000
# 5582   5582           regkey_read_\bPreventCreatingExecutables    0.000000
#
#       rank
# 6707     1
# 6359     2
# 4778     3
# 5038     4
# 6656     5
# ...    ...
# 5684  7516
# 5901  7517
# 5705  7518
# 5808  7519
# 5582  7520
#
# [7520 rows x 4 columns]

# %% [markdown]
# Merge two dataframe and compare the feature ranks

# %%
feature_ranks = sen_ran_df[sen_ran_df['importance']>0].merge(sen_nor_df, on=['Features'])
feature_ranks_com = feature_ranks[['Features','rank_x','rank_y']]
feature_ranks_com
# Out:
#                                                Features  rank_x  rank_y
# 0     regkey_read_HKEY_LOCAL_MACHINE\SOFTWARE\Wow643...       1       2
# 1     regkey_opened_HKEY_LOCAL_MACHINE\SOFTWARE\Micr...       2      15
# 2     regkey_read_HKEY_LOCAL_MACHINE\SOFTWARE\MICROS...       3       4
# 3     regkey_read_HKEY_LOCAL_MACHINE\SOFTWARE\MICROS...       4       3
# 4     regkey_written_HKEY_CURRENT_USER\Software\Micr...       5      49
# ...                                                 ...     ...     ...
# 6640             regkey_opened_HKEY_CLASSES_ROOT\Folder    6641    7314
# 6641  regkey_opened_HKEY_CLASSES_ROOT\AllFilesystemO...    6642    7317
# 6642  regkey_opened_HKEY_CLASSES_ROOT\Applications\A...    6643    7072
# 6643  regkey_opened_HKEY_CLASSES_ROOT\Applications\A...    6644    7073
# 6644          regkey_opened_HKEY_CLASSES_ROOT\Directory    6645    7331
#
# [6645 rows x 3 columns]

# %%
feature_ranks_com['minux'] = abs(feature_ranks_com['rank_x']-feature_ranks_com['rank_y'])
feature_ranks_com
# Out:
# <ipython-input-30-c9847533b609>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_ranks_com['minux'] = abs(feature_ranks_com['rank_x']-feature_ranks_com['rank_y'])
#                                                Features  rank_x  rank_y  minux
# 0     regkey_read_HKEY_LOCAL_MACHINE\SOFTWARE\Wow643...       1       2      1
# 1     regkey_opened_HKEY_LOCAL_MACHINE\SOFTWARE\Micr...       2      15     13
# 2     regkey_read_HKEY_LOCAL_MACHINE\SOFTWARE\MICROS...       3       4      1
# 3     regkey_read_HKEY_LOCAL_MACHINE\SOFTWARE\MICROS...       4       3      1
# 4     regkey_written_HKEY_CURRENT_USER\Software\Micr...       5      49     44
# ...                                                 ...     ...     ...    ...
# 6640             regkey_opened_HKEY_CLASSES_ROOT\Folder    6641    7314    673
# 6641  regkey_opened_HKEY_CLASSES_ROOT\AllFilesystemO...    6642    7317    675
# 6642  regkey_opened_HKEY_CLASSES_ROOT\Applications\A...    6643    7072    429
# 6643  regkey_opened_HKEY_CLASSES_ROOT\Applications\A...    6644    7073    429
# 6644          regkey_opened_HKEY_CLASSES_ROOT\Directory    6645    7331    686
#
# [6645 rows x 4 columns]

# %%
# feature_ranks_com[feature_ranks_com['minux']>191]['minux'].sort_values().plot.bar()

# %%
# compute the median value and mean of minux
print('The mean value of minux column is: ',feature_ranks_com['minux'].mean())
print('The median value of minux column is: ',feature_ranks_com['minux'].median())
# Out:
# The mean value of minux column is:  468.51407072987206
# The median value of minux column is:  312.0

# %%
feature_ranks_com[feature_ranks_com['minux']>312]['minux'].sort_values().hist(bins=200)

# %%
feature_ranks_com[feature_ranks_com['minux']>191]['minux'].sort_values().hist(bins=200)

# %% [markdown]
# [Optioanl] Analyse the Minus of Ranks by Counter

# %%
from collections import Counter

minus_values = Counter(abs(feature_ranks_com['rank_x']-feature_ranks_com['rank_y']))

# %%
# minus_values.keys()
# minus_values.values()

# %%
minus_df = pd.Series(list(minus_values.keys())).reset_index()
minus_df
# Out:
#       index    0
# 0         0    1
# 1         1   13
# 2         2   44
# 3         3   47
# 4         4   45
# ...     ...  ...
# 1394   1394  885
# 1395   1395  818
# 1396   1396  431
# 1397   1397  646
# 1398   1398  675
#
# [1399 rows x 2 columns]

# %%
minus_df.columns = ['Index', 'Minux']

# %%
minus_df['Occurences'] = pd.Series(list(minus_values.values()))

# %%
minus_df = minus_df.sort_values(by=['Minux'], ascending=True)
minus_df = minus_df[['Minux', 'Occurences']]
minus_df
# Out:
#       Minux  Occurences
# 1199      0           4
# 0         1          14
# 32        2           8
# 11        3          16
# 83        4          10
# ...     ...         ...
# 1078   2769           1
# 1038   2869           1
# 1014   2876           1
# 1031   2886           1
# 1089   3126           1
#
# [1399 rows x 2 columns]

# %%
minus_df[minus_df['Minux']>191]
# Out:
#       Minux  Occurences
# 393     192           6
# 280     193          15
# 282     194           7
# 392     195          12
# 281     196          10
# ...     ...         ...
# 1078   2769           1
# 1038   2869           1
# 1014   2876           1
# 1031   2886           1
# 1089   3126           1
#
# [1207 rows x 2 columns]

# %%
import matplotlib.pyplot as plt


fig = plt.plot(minus_df['Minux'],minus_df['Occurences'],'g--',label='type1')

plt.title('Minux_Occurences_Chart')
plt.xlabel('row')
plt.ylabel('column')
plt.axvline(x=191, color='blue')
plt.legend()
plt.show()

# %% [markdown]
# # Reference：
# **Automated Behavioral Analysis of Malware A Case Study of WannaCry Ransomware**
