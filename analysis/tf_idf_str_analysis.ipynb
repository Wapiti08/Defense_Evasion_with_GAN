# %%
import pandas as pd
import numpy as np
from nltk.corpus import stopwords
import math
from nltk.tokenize import word_tokenize

ori_df = pd.read_pickle("../dataset/features/raw_features.pickle")

# %%
strs_df = ori_df[['Label', 'strings']].compute()

# %% [markdown]
# ### 1. TF_IDF Analysis on Tokens

# %%
from nltk import FreqDist

cache_stopwords = stopwords.words("english")

def tokens_gen(sen):
    if ' ' not in sen:
        return sen
    else:
        return word_tokenize(sen)

def remove_stopwords(sen):
    return ' '.join([word for word in sen.split() if word not in cache_stopwords])

def TF_Words(docs):
    '''
    :param docs: the total lists of strings
    '''
    tf_word_dict = {}
    total_tokens_num = 0
    for doc in docs:
        for sen in doc:
            # tokenize sentence
            tokens = tokens_gen(sen)
            freddist = FreqDist(tokens)
            tokens = list(freddist.keys())
            total_tokens_num += len(tokens)
    
            for token, freq in freddist.items():
                if token in tf_word_dict.keys():
                    tf_word_dict[token] += freq
                else:
                    tf_word_dict[token] = freq

    for key, value in tf_word_dict.items():
        tf_word_dict[key] = np.round(value/total_tokens_num,5)
    
    return tf_word_dict


def IDF_Words(tf_word_dict, docs):
    # calculate the IDF for every words
    num_docs = len(docs)
    idf_word_dict = {}

    for word in tf_word_dict.keys():
        doc_num = 0
        for doc in docs:
            if any(word in sen for sen in doc):
                doc_num += 1
                
        idf_word_dict[word] = np.round(math.log10(num_docs/doc_num), 5)

    return idf_word_dict

def TF_IDF_Words(tf_word_dict, idf_word_dict):
    tf_idf_dict = {}
    for word, value in tf_word_dict.items():
        tf_idf_dict[word] = np.round(value * idf_word_dict[word], 5)

    return tf_idf_dict

# %%
# test on tf_idf_word
docs = strs_df['strings'].tolist()
tf_word_dict = TF_Words(docs)

# %%
idf_word_dict = IDF_Words(tf_word_dict, docs)
tf_idf_dict = TF_IDF_Words(tf_word_dict, idf_word_dict)

# %%
word_df = pd.DataFrame(tf_idf_dict.items(), columns=['word','value'])

# %%
print(word_df[word_df['value']>0].sort_values('value',ascending=False))

# %%
# word_df

# %%
strs_df['doc'] = strs_df['strings'].apply(lambda x: ' '.join(x))

# %%
strs_df.head()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
corpus = strs_df['doc'].tolist()
vectorizer_model = vectorizer.fit(corpus)
X_word = vectorizer_model.transform(corpus)

# %%
# type(X_word)
# X_word.toarray()

# %%
np.savetxt('../dataset/matrix/X_tf_idf_token.csv', X_word.toarray())

# %%
vectorizer_model.get_feature_names()[-10:]

# %%
np.loadtxt('../dataset/matrix/X_tf_idf_token.csv').shape
# Out:
# (321, 125326)

# %% [markdown]
# ### 2. TF_IDF Analysis on Sentences

# %%
def TF_Sen(docs):
    ''' calculate the frequencies of sentences in corpus
    :param docs: the lists of lists of strings
    '''
    tf_sen_dict = {}
    total_sens_num = 0
    # calculate the TF for sentences
    for doc in docs:
        for sen in doc:
            total_sens_num += 1
            if sen in tf_sen_dict.keys():
                tf_sen_dict[sen] += 1
            else:
                tf_sen_dict[sen] = 1
    for key, value in tf_sen_dict.items():
        tf_sen_dict[key] = np.round(value/total_sens_num ,7)
    
    return tf_sen_dict


def IDF_Sen(tf_sen_dict, docs):
    # calculate the IDF for single sentence
    num_docs = len(docs)
    idf_sen_dict = {}

    for sen_key in tf_sen_dict.keys():
        doc_num = 0
        for doc in docs:
            if sen_key in doc:
                doc_num += 1   

        idf_sen_dict[sen_key] = np.round(math.log10(num_docs/doc_num), 7)

    return idf_sen_dict


# calculate the TF_IDF for sentences
def TF_IDF_Sen(tf_sen_dict, idf_sen_dict):
    # two dict should have the same keys
    tf_idf_dict = {}
    for sen, value in tf_sen_dict.items():
        tf_idf_dict[sen] =np.round(value * idf_sen_dict[sen], 7)
        
    return tf_idf_dict

# %%
# test on tf_idf_word
docs = strs_df['strings'].tolist()
tf_sen_dict = TF_Sen(docs)

# %%
# tf_sen_dict

# %%
idf_sen_dict = IDF_Sen(tf_sen_dict, docs)

# %%
# idf_sen_dict

# %%
tf_idf_sen_dict = TF_IDF_Sen(tf_sen_dict, idf_sen_dict)

# print(tf_idf_sen_dict)

# %%
sen_df = pd.DataFrame(tf_idf_sen_dict.items(), columns = ['sen', 'value'])

# %%
sen_df['value'].sort_values(ascending=False)
# Out:
# 9798      0.025733
# 8449      0.016294
# 76867     0.003556
# 134088    0.001872
# 134093    0.001707
#             ...
# 132938    0.000008
# 132937    0.000008
# 132936    0.000008
# 132935    0.000008
# 100989    0.000008
# Name: value, Length: 201980, dtype: float64

# %%
# sen_df[sen_df['value']>0.00003]

# %%
# sen_df[sen_df['value']>0.00001]

# %%
# filter_sen_df = sen_df[sen_df['value']>0.00002]

# %%
# filter_sen_df

# %%
# sen_df

# %%
def match_value(sen_list, tf_idf_dict):
    array = []
    for sen in sen_list:
        if sen in tf_idf_dict.keys():
            array.append(tf_idf_dict[sen])
    return array

# %%
strs_df['vector'] = strs_df['strings'].apply(lambda x: match_value(x, tf_idf_sen_dict))

# %%
strs_df.head()['strings'][0]
# Out:
# ['!This program cannot be run in DOS mode.',
#  '.rdata',
#  '`@.bss',
#  '.edata',
#  '0@.idata',
#  '.reloc',
#  '0B.gnu_deb',
#  '\x1f<dVmT',
#  '};\x1fTBT2pq',
#  'P<)M,M',
#  'PO@MA$6',
#  'FOZM[$',
#  "'W`ScS",
#  'WgSVSc',
#  'WtSCSt',
#  '.M"OM/Z',
#  'P7QJVu',
#  'O*OIJBJ',
#  '?"*~, ',
#  '@QGizdL',
#  'FLOTI}',
#  'xAThFF',
#  'c?(!".',
#  "/'A(.9",
#  '1ig8.QBE',
#  '#+"p? ',
#  'Vt9@ZpY',
#  'cQri6lF]',
#  'CwB8bq',
#  'NiD:ht',
#  '/@FHG4M',
#  '__1NJK',
#  '4sP\\.In',
#  'pG9<dku',
#  'X9JqN0',
#  'krr&7>8>vZI9G',
#  '\x1fAklw_E',
#  'G$hG,F.',
#  'X>\x1fJl\x1fwG',
#  'K`\x1f+v/!m',
#  '@A{C@K',
#  '9Atc_fR',
#  'GB;`!_\\',
#  'VL8q\\O\x1f',
#  'i6yvsxi',
#  'pH9\x1f`\\',
#  '_$>9Am',
#  '`~^L>V',
#  'G".,!y',
#  'Bt&P":&y',
#  "!!\\O^'>u",
#  '&AY"!=',
#  '"*KtR8',
#  ')`"Kc2@u',
#  ',($j"8(U',
#  '<>9F:;5',
#  '4aL):O',
#  "aCD^')K",
#  'Yyn~$q',
#  'OABo."',
#  ':AH?A_i',
#  "v2Vn'K",
#  'f?{J@oa',
#  'L0O6Qh',
#  'Q\x1fQ(Q*Q$[>Q',
#  '@lT"?$',
#  ',H4Gj8',
#  'Kq2w9gw',
#  '~R^AHe',
#  "'Hbk\\_",
#  'NR9K+9$B',
#  ')\\\x1f(+`=',
#  'FLH79!=',
#  'IhL,[AL',
#  'Bj(OdV',
#  'KGCN,Ze',
#  'LL?I9o',
#  "*\\G9C'*.8",
#  '7:?G+1',
#  '&L?JQ9[',
#  'FL$(+?, ',
#  '<;4[/ 5',
#  '\\HYvj;',
#  ';W8&Ta{@',
#  ';Qzh+w',
#  "D*'.<8",
#  'LD/ *<49',
#  'Pf`jHA',
#  '3/,AfY',
#  'YA nbU',
#  'i8oy)Q',
#  "|CG.'=",
#  ')<4!+>[;,/',
#  '/$YA[Rl',
#  '+h9T_C',
#  'jz9HG}',
#  'B#>!C<$5',
#  'WOyo8@',
#  "C>'9L $?5",
#  '/wg__\\',
#  '|CFJ)9&*(j.',
#  'l_DF" @',
#  "F|id\x1f'4",
#  'NofbsU',
#  '8>j(?#?',
#  '?+"7<5',
#  ',O+;/.(&',
#  'sQ~+GU',
#  ')K\\a\x1fE',
#  ':<,z/+A',
#  '/~lYa)m',
#  'G 7Q!*"',
#  'P(\\jo|+',
#  't)?Tsm',
#  '$C.*7:',
#  'kD$)[Dn',
#  '<_3ky<',
#  ' $iY!\x1f',
#  'A`NX9~',
#  'CXAKd]',
#  "a8>9`'i",
#  'GllI(_9',
#  ':|$#I(9b',
#  'iCth.Tjw',
#  ';4?Bl&',
#  'ZK?3Hi',
#  '&7?I8!9>5',
#  'BhI"Qof',
#  '8?F! "#',
#  'jHI9Y,',
#  'pqrH>E',
#  '#) &8?_<:',
#  "QGc+'R",
#  'l|ch9T',
#  '1_t01n',
#  '!2F1iE',
#  'z@Qb.Pm',
#  '~Oyx{zu',
#  '<&4*):F1',
#  'X9i_l1',
#  "LG'?&:,5",
#  'C(C?F>CU',
#  '$7GONY[',
#  'XxlK@:',
#  'cyoOdm',
#  '6IL8Ab',
#  '\x1f8#J9$ (m',
#  ',/.)(+M',
#  "$'&! #M",
#  '<?>98;D:5',
#  'Lz\x1fXL1',
#  "4L<'klfp",
#  '~y"Iv-',
#  '*Lbq M',
#  'KBT\\?)',
#  'bOZLTJ',
#  'BhSf@U',
#  'f1qbFM',
#  'B6!;9-',
#  'CXo"qm',
#  '3Ia{N\x1fM',
#  'vjoB{2/',
#  'J!"7Cs',
#  '6B8s~K',
#  '!>C3hM',
#  'Q[*c9\x1f',
#  'gJ|t)s',
#  'LyRz(Y',
#  'QsA)Nfh',
#  '6jhy)Y',
#  's*L<Cp',
#  'NwLK79',
#  '@zxTjg',
#  '4Ay4^F9f}',
#  ' kTkdL',
#  "dK.3':",
#  'ir\\iO*',
#  'KtyCw[vSqkpcs{rsr',
#  'r+r#r;r3r',
#  '3+2#3;333',
#  '3+3#3;333',
#  '_ttWw}',
#  'IqwAv]',
#  'Aw?g9s;',
#  'FtqQwivdqcp~su',
#  '\\tzRww*',
#  'tGwYvSqkzc',
#  'ct.w>h',
#  'Ftryh6',
#  "qr'r:r",
#  'JAr$h0',
#  'GyBaOt',
#  'ItzGiYO',
#  'aOithG',
#  'r.r*r&r"r>r:r6r2r',
#  'aJNqRb',
#  'oJOtDiQ',
#  'jB,k)gF',
#  'r9aSv1b',
#  'libgcj_s.dll',
#  '_Jv_RegisterClasses',
#  'Copyright (C) the VideoLAN VLC media player developers',
#  'Licensed under the terms of the GNU General Public License, version 2 or later.',
#  'MP4 stream demuxer',
#  'elst old=%d new=%d',
#  'freeing all memory',
#  'invalid SampleEntry index (track[Id 0x%x])',
#  'cannot find SampleEntry (track[Id 0x%x])',
#  'sinf/frma',
#  'Original Format Box: %4.4s',
#  'Invalid sample per packet value for qt_version 1',
#  'i_timescale (%llu) != i_sampleratehi (%u), making both equal (report any problem).',
#  'wave/enda',
#  'wave/esds',
#  'unknown objectTypeIndication(0x%x) (Track[ID 0x%x])',
#  'missing avcC',
#  'recreate ES for track[Id 0x%x]',
#  'cannot create es for track[Id 0x%x]',
#  'elst (%d) gives %lldms (movie)-> %lldms (track)',
#  'track[Id 0x%x] will be disabled (seeking too far) chunk=%d sample=%d',
#  'track[Id 0x%x] using Sync Sample Box (stss)',
#  'stts gives %d --> %d (sample number)',
#  'track[Id 0x%x] does not provide Sync Sample Box (stss)',
#  'cannot select track[Id 0x%x]',
#  'DEMUX_GET_FPS unimplemented !!',
#  '/moov/udta/meta/ilst',
#  '/moov/udta',
#  'control query %u unimplemented',
#  '>lmP?lm',
#  '=lmpAlm',
#  '=lmtrack[Id 0x%x] already unselected',
#  'MP4 plugin discarded (unseekable)',
#  'MP4 plugin discarded (not a valid file)',
#  'ISO Media file (isom) version %d.',
#  'unrecognized major file specification (%4.4s).',
#  'file type box missing (assuming ISO Media file)',
#  'MP4 plugin discarded (no moov box)',
#  '/moov/rmra',
#  'detected playlist mov file (%d ref)',
#  'rmda[%d]/rdrf',
#  "new ref=`%s' type=%4.4s",
#  'qt5gateQT',
#  "ignoring pseudo ref =`%s'",
#  'http://',
#  'rtsp://',
#  '%s://%s%s',
#  "adding ref = `%s'",
#  'unknown ref type=%4.4s FIXME (send a bug report)',
#  '/moov/mvhd',
#  'cannot find /moov/mvhd',
#  'cannot find /moov/mvhd (pure ref file)',
#  'bad timescale',
#  '/moov/trak',
#  'cannot find any /moov/trak',
#  'found %d track%c',
#  '/moov/trak[%d]',
#  'tref/chap',
#  'mdia/mdhd',
#  'mdia/hdlr',
#  'mdia/minf/smhd',
#  'mdia/minf/vmhd',
#  'edts/elst',
#  'elst box found',
#  '   - [%d] duration=%lldms media time=%lldms) rate=%d.%d',
#  'mdia/minf/stbl',
#  'mdia/minf/stbl/stsd',
#  'sinf/skcr',
#  'no chunk defined',
#  'cannot read chunk table or table empty',
#  'corrupted chunk table',
#  'track[Id 0x%x] read %d chunk',
#  'cannot find STSZ box',
#  'cannot find STTS box',
#  'CTTS table',
#  'track[Id 0x%x] read %d samples length:%llds',
#  'Enabling track[Id 0x%x] (buggy file without enabled track)',
#  'unknown',
#  'disable',
#  'enable',
#  'adding track[Id 0x%x] %s (%s) language %s',
#  'using track[Id 0x%x] for chapter language %s',
#  'ignoring track[Id 0x%x]',
#  '/moov/udta/chpl',
#  'no track selected, exiting...',
#  'track[0x%x] will be disabled (eof?)',
#  'track[0x%x] will be disabled (cannot restart decoder)',
#  'subtitle',
#  'cannot free box %4.4s, type unknown',
#  'cannot free box c%3.3s, type unknown',
#  'dumping root Box "%4.4s"',
#  'dumping root Box "c%3.3s"',
#  '+ %4.4s size %d',
#  '+ c%3.3s size %d',
#  'Not enough data',
#  'read box: "c%3.3s" text=`%s\'',
#  'read box: "skcr" i_init:%d i_encr:%d i_decr:%d',
#  'read box: "frma" i_type:%4.4s',
#  'read box: "rmvc" gestaltType:%4.4s val1:0x%x val2:0x%x checkType:0x%x',
#  'read box: "rmqu" quality:%d',
#  'read box: "rmdr" rate:%d',
#  'read box: "rdrf" type:%4.4s ref %s',
#  'read box: "chap" %d references',
#  'read box: "dac3" fscod=0x%x bsid=0x%x bsmod=0x%x acmod=0x%x lfeon=0x%x bitrate_code=0x%x',
#  'read box: "avcC" version=%d profile=0x%x level=0x%x length size=%d sps=%d pps=%d',
#  '         - sps[%d] length=%d',
#  '         - pps[%d] length=%d',
#  'read box: "cmvd" compressed data size %d',
#  'read box: "dcom" compression algorithm : %4.4s',
#  'found esds MPEG4ESDescr (%dBytes)',
#  'found esds MP4DecConfigDescr (%dBytes)',
#  'found esds MP4DecSpecificDescr (%dBytes)',
#  'read box: "stdp" entry-count %lld',
#  'read box: "stsh" entry-count %d',
#  'read box: "stss" entry-count %d',
#  'read box: "stsc" entry-count %d',
#  'read box: "stsz" sample-size %d sample-count %d',
#  'read box: "ctts" entry-count %d',
#  'read box: "stts" entry-count %d',
#  'read box: "hmhd" maxPDU-size %d avgPDU-size %d max-bitrate %d avg-bitrate %d',
#  'read box: "smhd" balance %f',
#  'read box: "vmhd" graphics-mode %d opcolor (%d, %d, %d)',
#  'read box: "hdlr" handler type %4.4s name %s',
#  'unknown error',
#  'drms_init(%4.4s) failed (%s)',
#  'drms_init(c%3.3s) failed (%s)',
#  'found Box: %4.4s size %lld',
#  'found Box: c%3.3s size %lld',
#  'cannot read one box',
#  'found an empty box (null size)',
#  'out of bound child',
#  'moov/cmov',
#  'foov/cmov',
#  'read box: "soun" qt3+ sample/packet=%d bytes/packet=%d bytes/frame=%d bytes/sample=%d',
#  'read box: %f Hz',
#  'read box: "soun" V2',
#  'read box: "soun" mp4 or qt1/2 (rest=%lld)',
#  'drms_alloc() failed',
#  'read box: "soun" in stsd channel %d sample size %d sample rate %f',
#  'read box: "stsd" entry-count %d',
#  'read box: "dref" entry-count %d',
#  'read box: "vide" in stsd %dx%d depth %d',
#  '../../../..',
#  'read box: "text" in stsd text',
#  'read box: "tx3g" in stsd text',
#  'unknown handler type in stsd (incompletely loaded)',
#  'unknown box type %4.4s (incompletely loaded)',
#  'unknown box type c%3.3s (incompletely loaded)',
#  'detected moov hidden in a free box ...',
#  'skip box: "%4.4s"',
#  'skip box: "c%3.3s"',
#  'read box: "cprt" language %c%c%c notice %s',
#  'read box: "urn" name %s location %s',
#  'read box: "url" url: %s',
#  '%dd-%2.2dh:%2.2dm:%2.2ds',
#  'read box: "mdhd" creation %s modification %s time scale %d duration %s language %c%c%c',
#  'read box: "tkhd" creation %s modification %s duration %s track ID %d layer %d volume %f width %f height %f',
#  'read box: "mvhd" creation %s modification %s time scale %d duration %s rate %f volume %f next track id %d',
#  'Read box: "cmov" box alone',
#  'read box: "cmov" incomplete',
#  'read box: "cmov" compression algorithm : %4.4s not supported',
#  'read box: "cmov" error while uncompressing',
#  'read box: "cmov" uncompressing data size mismatch',
#  'read box: "cmov" error while uncompressing data (ignored)',
#  'read box: "cmov" box succesfully uncompressed',
#  'read box: "cmov" compressed movie header completed',
#  'read box: "co64" entry-count %d',
#  'read box: "chpl" %d chapters',
#  'read box: "elst" entry-count %lu',
#  'lmtrak',
#  'lmmdia',
#  'lmmoof',
#  'lmminf',
#  'lmstbl',
#  'lmdinf',
#  'lmedts',
#  'lmudta',
#  'lmnmhd',
#  'lmhnti',
#  'lmrmra',
#  'lmrmda',
#  'lmtref',
#  'lmgmhd',
#  'lmwave',
#  'lmilst',
#  'lmftyp0',
#  'lmcmov',
#  'lmmvhd`Smm',
#  'lmtkhd',
#  'lmmdhd',
#  'lmhdlrp',
#  'lmvmhdP',
#  'lmsmhd',
#  'lmhmhd',
#  'lmurl 0;mm',
#  'lmurn `6mmP',
#  'lmdref@',
#  'lmstts',
#  'lmctts',
#  'lmstsdp',
#  'lmstsz',
#  'lmstsc0',
#  'lmstco0dmm ',
#  'lmco640dmm ',
#  'lmstssp',
#  'lmstshp',
#  'lmstdp',
#  'lmpadb`',
#  'lmelst',
#  'lmcprtp2mmp',
#  'lmesds`',
#  'lmdcom',
#  'lmcmvd',
#  'lmavcC`',
#  'lmdac3',
#  'lmmdat 1mm',
#  'lmskip 1mm',
#  'lmfree 1mm',
#  'lmwide 1mm',
#  'lmsoun0',
#  'mm.mp30',
#  'mmmp4a0',
#  'mmtwos0',
#  'mmsowt0',
#  'mmQDMC0',
#  'mmQDM20',
#  'mmima40',
#  'mmIMA40',
#  'mmdvi 0',
#  'mmalaw0',
#  'mmulaw0',
#  'mmraw 0',
#  'mmMAC30',
#  'mmMAC60',
#  'mmQclp0',
#  'mmsamr0',
#  'mmsawb0',
#  'mmOggS0',
#  'mmalac0',
#  'mmdrmi',
#  'mmvide',
#  'mmmp4v',
#  'mmSVQ1',
#  'mmSVQ3',
#  'mmZyGo',
#  'mmDIVX',
#  'mmXVID',
#  'mmh263',
#  'mms263',
#  'mmcvid',
#  'mm3IV1',
#  'mm3iv1',
#  'mm3IV2',
#  'mm3iv2',
#  'mm3IVD',
#  'mm3ivd',
#  'mm3VID',
#  'mm3vid',
#  'mmmjpa',
#  'mmmjqt',
#  'mmqdrw',
#  'mmmp2v',
#  'mmhdv2',
#  'mmmjht',
#  'mmdvp ',
#  'mmdv5n',
#  'mmdv5p',
#  'mmVP31',
#  'mmvp31',
#  'mmh264',
#  'mmjpeg',
#  'mmavc1',
#  'mmyv12',
#  'mmyuv2',
#  'mmmp4s',
#  'lmhint',
#  'lmdpnd',
#  'lmrtp ',
#  'lmrmdr',
#  'lmrmqu',
#  'lmrmvcP',
#  'lmdrms0',
#  'mmsinf',
#  'lmschi',
#  'lmuser@',
#  'lmkey @',
#  'lmiviv@',
#  'lmname@',
#  'lmpriv@',
#  'lmfrmap',
#  'lmskcr',
#  'lmchpl',
#  'lmmeta ',
#  'invalid user key',
#  'no user key found in SCI data',
#  'could not get SCI data',
#  'could not get system key',
#  'invalid argument',
#  'unimplemented',
#  'mm%s/drms/%08X.%03d',
#  'cache-control',
#  'Ethernet',
#  'SHFolder.dll',
#  'IPODID',
#  'iSCInfo',
#  'SHGetFolderPathW',
#  '%s/iPod_Control/iTunes/iSCInfo2',
#  '%s/drms',
#  'tr1-th3n.y00_by3',
#  'mUfnpognadfgf873',
#  'zPif98gaYuaFlafuHARDWARE\\DESCRIPTION\\System',
#  'SystemBiosVersion',
#  'HARDWARE\\DESCRIPTION\\System\\CentralProcessor\\0',
#  'ProcessorNameString',
#  'SOFTWARE\\Microsoft\\Windows\\CurrentVersion',
#  'ProductId',
#  '____v8rhvsaAvOKM____FfUH%798=[;.____f8677680a634____ba87fnOIf)(*',
#  'PQAeS~',
#  '~4[C)v',
#  'pbclevtug (p) Nccyr Pbzchgre, Vap.  Nyy Evtugf Erfreirq.',
#  'uRJ%WRm',
#  'TRJ7Trk',
#  'incorrect header check',
#  'unknown compression method',
#  'invalid window size',
#  'unknown header flags set',
#  'header crc mismatch',
#  'invalid block type',
#  'invalid stored block lengths',
#  'too many length or distance symbols',
#  'invalid code lengths set',
#  'invalid bit length repeat',
#  'invalid literal/lengths set',
#  'invalid distances set',
#  'invalid literal/length code',
#  'invalid distance code',
#  'invalid distance too far back',
#  'incorrect data check',
#  'incorrect length check',
#  'invalid distance too far back',
#  'invalid distance code',
#  'invalid literal/length code',
#  ' inflate 1.2.3 Copyright 1995-2005 Mark Adler ',
#  'Qkkbal',
#  "[-&LMb#{'",
#  'w+OQvr',
#  'IN\x1fSKyu',
#  ')\\ZEo^m/',
#  'H*0"ZOW',
#  'mj>zjZ',
#  'IiGM>nw',
#  'ewh/?y',
#  'OZw3(?',
#  'V_:X1:',
#  'need dictionary',
#  'stream end',
#  'file error',
#  'stream error',
#  'data error',
#  'insufficient memory',
#  'buffer error',
#  'incompatible version',
#  'Mingw runtime failure:',
#  '  VirtualQuery failed for %d bytes at address %p',
#  '  Unknown pseudo relocation protocol version %d.',
#  '  Unknown pseudo relocation bit size %d.',
#  'PRINTF_EXPONENT_DIGITS',
#  '(null)',
#  '@+nm\x1f$nm\x1f$nm +nm\x1f$nm',
#  '+nm\x1f$nm\x1f$nm\x1f$nm\x1f$nm',
#  '*nm\x1f$nm',
#  '*nmv*nm\x1f$nmX*nm\x1f$nm\x1f$nm\x1f$nm\x1f$nm\x1f$nm\x1f$nm\x1f$nm\x1f$nm\x1f$nm\x1f$nm\x1f$nm\x1f$nm\x1f$nm\x1f$nm\x1f$nm\x1f$nm',
#  ')nm\x1f$nmF)nm\x1f$nm )nm',
#  '(nm\x1f$nm',
#  '(nm\x1f$nm\x1f$nm',
#  '$nm\x1f$nm\x1f$nm\x1f$nm\x1f$nm\x1f$nm\x1f$nm',
#  "+nm\x1f$nm\x1f$nm\x1f$nm\x1f$nm@(nm\x1f$nm\x1f$nm\x1f$nm\x1f$nm\x1f$nm\x1f$nm\x1f$nm\x1f$nmw'nm\x1f$nm",
#  '&nmP&nm',
#  '%nm\x1f$nm',
#  '$nm\x1f$nm',
#  '%nm@(nmW%nm\x1f$nm\x1f$nm"%nm',
#  '$nm@(nm\x1f$nm\x1f$nm@(nm\x1f$nm',
#  '$nmInfinity',
#  '5nmP4nmP4nm',
#  '5nmU5nm',
#  'libmp4_plugin.dll',
#  'vlc_entry__1_0_0e',
#  'vlc_entry_copyright__1_0_0e',
#  'vlc_entry_license__1_0_0e',
#  'AddMD5',
#  'EndMD5',
#  'EnsureUTF8',
#  'InitMD5',
#  '__input_item_NewExt',
#  '__msg_Generic',
#  '__stream_MemoryNew',
#  '__vlc_object_find',
#  '__vlc_object_release',
#  'config_GetHomeDir',
#  'es_format_Clean',
#  'es_format_Init',
#  'input_GetItem',
#  'input_item_AddSubItem',
#  'input_item_CopyOptions',
#  'stream_Block',
#  'stream_Control',
#  'stream_Delete',
#  'stream_Peek',
#  'stream_Read',
#  'utf8_fopen',
#  'vlc_plugin_set',
#  'vlc_release',
#  'RegCloseKey',
#  'RegOpenKeyExA',
#  'RegQueryValueExA',
#  'DeleteCriticalSection',
#  'EnterCriticalSection',
#  'FreeLibrary',
#  'GetModuleHandleA',
#  'GetProcAddress',
#  'GetVolumeInformationA',
#  'InitializeCriticalSection',
#  'InterlockedExchange',
#  'IsDBCSLeadByteEx',
#  'LeaveCriticalSection',
#  'LoadLibraryA',
#  'MultiByteToWideChar',
#  'VirtualProtect',
#  'VirtualQuery',
#  'WideCharToMultiByte',
#  '_mkdir',
#  '_strdup',
#  '__dllonexit',
#  '__lc_codepage',
#  '__mb_cur_max',
#  '_errno',
#  '_fstati64',
#  '_isctype',
#  '_pctype',
#  'calloc',
#  'fclose',
#  'fflush',
#  'fwrite',
#  'getenv',
#  'gmtime',
#  'localeconv',
#  'localtime',
#  'malloc',
#  'memchr',
#  'memcpy',
#  'memmove',
#  'realloc',
#  'strchr',
#  'strcpy',
#  'strlen',
#  'strncpy',
#  'strpbrk',
#  'strrchr',
#  'strstr',
#  'strtol',
#  'toupper',
#  'vfprintf',
#  'wcscat',
#  'wcslen',
#  'libvlccore.dll',
#  'ADVAPI32.DLL',
#  'KERNEL32.dll',
#  'msvcrt.dll',
#  'msvcrt.dll',
#  'libmp4_plugin.dll.dbg',
#  '\\Apple Computer\\iTunes\\SC Info\\SC Info.sidb',
#  '\x1f#+3;CScs',
#  '(null)']

# %%
num_array = []
max_len = max([len(value_list) for value_list in strs_df['vector']])

for value_list in strs_df['vector'].tolist():
    if len(value_list) != max_len:
        value_list.extend([0]* (max_len - len(value_list)))
    
    num_array.append(np.array(value_list))

# %%
num_array
# Out:
# [array([2.457e-04, 9.310e-05, 1.430e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([5.710e-05, 5.710e-05, 2.457e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 4.550e-05, 4.170e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([0.0002457, 0.0002859, 0.000282 , ..., 0.       , 0.       ,
#         0.       ]),
#  array([2.457e-04, 4.550e-05, 4.170e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([5.25e-05, 5.25e-05, 5.25e-05, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([2.457e-04, 4.900e-05, 4.900e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 8.300e-06, 2.859e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 1.990e-05, 1.990e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 1.127e-04, 1.430e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 1.990e-05, 1.430e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 4.900e-05, 4.900e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 1.430e-05, 2.859e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 1.762e-04, 1.430e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 2.859e-04, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([0.0002457, 0.0001127, 0.0001762, ..., 0.       , 0.       ,
#         0.       ]),
#  array([2.457e-04, 1.127e-04, 1.990e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([0.0002457, 0.0002859, 0.000282 , ..., 0.       , 0.       ,
#         0.       ]),
#  array([5.710e-05, 5.710e-05, 2.457e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 4.900e-05, 4.900e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 1.127e-04, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 8.300e-06, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([0.0002457, 0.0002859, 0.000282 , ..., 0.       , 0.       ,
#         0.       ]),
#  array([2.457e-04, 1.990e-05, 1.990e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([5.25e-05, 5.25e-05, 5.25e-05, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([2.457e-04, 1.990e-05, 1.127e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 1.430e-05, 2.480e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([0.0002457, 0.0001127, 0.0001208, ..., 0.       , 0.       ,
#         0.       ]),
#  array([0.0002457, 0.0002859, 0.000282 , ..., 0.       , 0.       ,
#         0.       ]),
#  array([2.457e-04, 1.127e-04, 4.550e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([0.0002457, 0.0002859, 0.000282 , ..., 0.       , 0.       ,
#         0.       ]),
#  array([1.63e-05, 9.01e-05, 1.99e-05, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([2.457e-04, 4.550e-05, 4.170e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 1.990e-05, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([5.71e-05, 5.71e-05, 1.43e-05, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([2.457e-04, 1.127e-04, 1.990e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 8.300e-06, 2.859e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 1.430e-05, 1.990e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([8.32e-05, 9.01e-05, 8.30e-06, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([0.0002457, 0.0002859, 0.000282 , ..., 0.       , 0.       ,
#         0.       ]),
#  array([9.01e-05, 1.63e-05, 1.63e-05, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([8.32e-05, 7.32e-05, 8.30e-06, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([9.010e-05, 1.059e-04, 1.430e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([8.320e-05, 1.059e-04, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([9.010e-05, 1.059e-04, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([8.32e-05, 9.01e-05, 8.30e-06, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([9.01e-05, 8.30e-06, 8.30e-06, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([8.32e-05, 9.01e-05, 1.43e-05, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([8.320e-05, 1.059e-04, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([8.32e-05, 9.01e-05, 8.30e-06, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([1.059e-04, 8.300e-06, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([8.320e-05, 8.300e-06, 1.059e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([7.32e-05, 8.30e-06, 8.30e-06, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([8.320e-05, 9.010e-05, 1.059e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([8.300e-06, 9.010e-05, 1.059e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 4.900e-05, 4.900e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([8.320e-05, 9.010e-05, 1.059e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([9.010e-05, 1.059e-04, 1.430e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([9.01e-05, 8.30e-06, 8.30e-06, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([8.32e-05, 9.01e-05, 1.43e-05, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([1.43e-05, 3.71e-05, 1.99e-05, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([9.01e-05, 1.63e-05, 1.43e-05, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([9.01e-05, 8.30e-06, 8.30e-06, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([1.43e-05, 8.30e-06, 8.30e-06, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([9.01e-05, 8.30e-06, 1.43e-05, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([8.32e-05, 9.01e-05, 7.32e-05, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([9.0100e-05, 8.3000e-06, 1.3739e-03, ..., 0.0000e+00, 0.0000e+00,
#         0.0000e+00]),
#  array([8.320e-05, 1.059e-04, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([8.32e-05, 9.01e-05, 2.64e-05, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([0.0002457, 0.0002859, 0.000282 , ..., 0.       , 0.       ,
#         0.       ]),
#  array([0.0002457, 0.0002859, 0.000282 , ..., 0.       , 0.       ,
#         0.       ]),
#  array([2.457e-04, 3.370e-05, 2.859e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 5.570e-05, 2.859e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 5.570e-05, 2.859e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 3.370e-05, 2.859e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 5.570e-05, 2.859e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 4.550e-05, 4.170e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 5.570e-05, 2.859e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 5.570e-05, 2.859e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 3.370e-05, 2.859e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 2.480e-05, 2.859e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 3.370e-05, 2.859e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 5.570e-05, 2.859e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 2.480e-05, 2.859e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 3.370e-05, 2.859e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.43e-05, 8.30e-06, 3.71e-05, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([2.457e-04, 2.480e-05, 2.859e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([5.25e-05, 5.25e-05, 5.25e-05, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([2.457e-04, 5.570e-05, 2.859e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 5.570e-05, 2.859e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 5.570e-05, 2.859e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 5.570e-05, 2.859e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([0.0002457, 0.0002859, 0.000282 , ..., 0.       , 0.       ,
#         0.       ]),
#  array([0.0002457, 0.0002859, 0.000282 , ..., 0.       , 0.       ,
#         0.       ]),
#  array([0.0002457, 0.0002859, 0.000282 , ..., 0.       , 0.       ,
#         0.       ]),
#  array([2.457e-04, 5.570e-05, 2.859e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 5.570e-05, 2.859e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 3.370e-05, 2.859e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([0.0002457, 0.0001127, 0.0001208, ..., 0.       , 0.       ,
#         0.       ]),
#  array([2.457e-04, 2.480e-05, 2.859e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.455e-04, 8.300e-06, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 4.550e-05, 4.170e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([5.710e-05, 5.710e-05, 2.457e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([5.25e-05, 5.25e-05, 5.25e-05, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([0.0002457, 0.0002859, 0.000282 , ..., 0.       , 0.       ,
#         0.       ]),
#  array([2.480e-05, 1.127e-04, 9.310e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 1.127e-04, 4.300e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([5.25e-05, 5.25e-05, 5.25e-05, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([2.457e-04, 1.430e-05, 2.859e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([5.25e-05, 5.25e-05, 5.25e-05, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([2.457e-04, 4.900e-05, 4.900e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 6.490e-05, 6.490e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([5.25e-05, 5.25e-05, 5.25e-05, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([2.457e-04, 1.430e-05, 1.127e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([5.710e-05, 5.710e-05, 2.457e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([0.0002457, 0.0002859, 0.000282 , ..., 0.       , 0.       ,
#         0.       ]),
#  array([0.0002457, 0.0002859, 0.000282 , ..., 0.       , 0.       ,
#         0.       ]),
#  array([0.0002457, 0.0002859, 0.000282 , ..., 0.       , 0.       ,
#         0.       ]),
#  array([2.457e-04, 1.127e-04, 1.430e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 2.480e-05, 2.859e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 4.900e-05, 4.900e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 8.300e-06, 1.127e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 1.990e-05, 1.990e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([8.300e-06, 8.300e-06, 2.442e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([0.0002859, 0.000282 , 0.0001762, ..., 0.       , 0.       ,
#         0.       ]),
#  array([0.0002457, 0.0001127, 0.0001208, ..., 0.       , 0.       ,
#         0.       ]),
#  array([0.0002457, 0.0002859, 0.000282 , ..., 0.       , 0.       ,
#         0.       ]),
#  array([2.457e-04, 4.550e-05, 4.170e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 1.990e-05, 1.990e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([0.0002457, 0.0002859, 0.000282 , ..., 0.       , 0.       ,
#         0.       ]),
#  array([5.710e-05, 5.710e-05, 2.457e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([0.0002859, 0.000282 , 0.0001762, ..., 0.       , 0.       ,
#         0.       ]),
#  array([2.457e-04, 1.127e-04, 1.990e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.480e-05, 1.430e-05, 1.127e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([0.0002457, 0.0002859, 0.000282 , ..., 0.       , 0.       ,
#         0.       ]),
#  array([5.710e-05, 5.710e-05, 2.457e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 4.900e-05, 4.900e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([0.0002457, 0.0002859, 0.000282 , ..., 0.       , 0.       ,
#         0.       ]),
#  array([2.457e-04, 4.900e-05, 4.900e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 4.550e-05, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([0.0002457, 0.0002859, 0.000282 , ..., 0.       , 0.       ,
#         0.       ]),
#  array([2.457e-04, 2.480e-05, 2.859e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 1.430e-05, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([0.0002457, 0.0002859, 0.000282 , ..., 0.       , 0.       ,
#         0.       ]),
#  array([0.0002457, 0.0002859, 0.000282 , ..., 0.       , 0.       ,
#         0.       ]),
#  array([2.457e-04, 8.300e-06, 1.762e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([0.0002457, 0.0002859, 0.000282 , ..., 0.       , 0.       ,
#         0.       ]),
#  array([2.457e-04, 1.990e-05, 1.990e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([0.0002457, 0.0002859, 0.000282 , ..., 0.       , 0.       ,
#         0.       ]),
#  array([0.0002457, 0.0002859, 0.000282 , ..., 0.       , 0.       ,
#         0.       ]),
#  array([2.457e-04, 4.900e-05, 4.900e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 8.300e-06, 1.127e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 1.430e-05, 2.859e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([0.0002457, 0.0002859, 0.000282 , ..., 0.       , 0.       ,
#         0.       ]),
#  array([2.457e-04, 4.550e-05, 4.170e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 4.900e-05, 4.900e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 1.430e-05, 2.859e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 8.300e-06, 1.430e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 1.990e-05, 1.127e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([5.710e-05, 5.710e-05, 2.457e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([5.25e-05, 5.25e-05, 5.25e-05, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([2.48e-05, 8.30e-06, 8.30e-06, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([0.0002457, 0.0002859, 0.0002859, ..., 0.       , 0.       ,
#         0.       ]),
#  array([3.71e-05, 8.30e-06, 8.30e-06, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([1.430e-05, 1.430e-05, 1.127e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 1.430e-05, 2.859e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 4.550e-05, 4.170e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([5.25e-05, 5.25e-05, 5.25e-05, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([5.25e-05, 5.25e-05, 5.25e-05, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([2.457e-04, 8.300e-06, 2.859e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.990e-05, 2.457e-04, 9.310e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([2.457e-04, 8.300e-06, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([5.25e-05, 5.25e-05, 5.25e-05, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([5.710e-05, 5.710e-05, 2.457e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([8.320e-05, 1.455e-04, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([0.0002457, 0.0002859, 0.000282 , ..., 0.       , 0.       ,
#         0.       ]),
#  array([5.710e-05, 5.710e-05, 2.457e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.63e-05, 8.30e-06, 8.30e-06, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([2.480e-05, 1.430e-05, 1.127e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([0.0002457, 0.0002859, 0.000282 , ..., 0.       , 0.       ,
#         0.       ]),
#  array([1.455e-04, 2.211e-04, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.455e-04, 8.300e-06, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.455e-04, 5.250e-05, 7.840e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.455e-04, 5.250e-05, 7.840e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.455e-04, 5.250e-05, 7.840e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.455e-04, 5.250e-05, 7.840e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.455e-04, 5.250e-05, 7.840e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.455e-04, 5.250e-05, 7.840e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.95e-05, 5.25e-05, 7.84e-05, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([2.95e-05, 5.25e-05, 7.84e-05, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([8.300e-06, 2.859e-04, 2.820e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.455e-04, 2.211e-04, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.95e-05, 5.25e-05, 7.84e-05, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([2.95e-05, 5.25e-05, 7.84e-05, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([2.95e-05, 5.25e-05, 7.84e-05, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([1.455e-04, 4.550e-05, 7.840e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.455e-04, 4.550e-05, 7.840e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([4.55e-05, 7.84e-05, 4.55e-05, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([1.455e-04, 4.550e-05, 7.840e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.455e-04, 4.550e-05, 7.840e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([4.55e-05, 7.84e-05, 4.55e-05, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([1.455e-04, 4.550e-05, 7.840e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.211e-04, 8.300e-06, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([0.0002457, 0.0002859, 0.000282 , ..., 0.       , 0.       ,
#         0.       ]),
#  array([1.455e-04, 4.550e-05, 7.840e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.455e-04, 4.550e-05, 7.840e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([9.010e-05, 1.455e-04, 2.870e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([8.300e-06, 2.870e-05, 1.817e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([8.3e-06, 8.3e-06, 8.3e-06, ..., 0.0e+00, 0.0e+00, 0.0e+00]),
#  array([8.3e-06, 8.3e-06, 8.3e-06, ..., 0.0e+00, 0.0e+00, 0.0e+00]),
#  array([1.43e-05, 3.71e-05, 1.43e-05, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([2.211e-04, 8.300e-06, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.211e-04, 8.300e-06, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.455e-04, 2.211e-04, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 9.310e-05, 1.005e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.455e-04, 2.211e-04, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.211e-04, 8.300e-06, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.211e-04, 8.300e-06, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.455e-04, 2.211e-04, 5.710e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.455e-04, 2.211e-04, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.455e-04, 2.211e-04, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.211e-04, 8.300e-06, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.455e-04, 2.211e-04, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.211e-04, 8.300e-06, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([8.320e-05, 1.455e-04, 2.211e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.455e-04, 2.211e-04, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.455e-04, 2.211e-04, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([8.3e-06, 8.3e-06, 8.3e-06, ..., 0.0e+00, 0.0e+00, 0.0e+00]),
#  array([5.71e-05, 5.71e-05, 1.43e-05, ..., 8.30e-06, 8.30e-06, 8.30e-06]),
#  array([0.0002457, 0.0002859, 0.000282 , ..., 0.       , 0.       ,
#         0.       ]),
#  array([8.3e-06, 8.3e-06, 8.3e-06, ..., 0.0e+00, 0.0e+00, 0.0e+00]),
#  array([8.320e-05, 2.211e-04, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([0.0002457, 0.0002859, 0.000282 , ..., 0.       , 0.       ,
#         0.       ]),
#  array([0.0002457, 0.0002859, 0.000282 , ..., 0.       , 0.       ,
#         0.       ]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([1.455e-04, 2.211e-04, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.430e-05, 2.859e-04, 2.820e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([2.457e-04, 8.300e-06, 2.859e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([0.0002457, 0.0002859, 0.000282 , ..., 0.       , 0.       ,
#         0.       ]),
#  array([2.457e-04, 1.430e-05, 9.310e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 1.127e-04, 4.900e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.211e-04, 8.300e-06, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([0.0002457, 0.0002859, 0.000282 , ..., 0.       , 0.       ,
#         0.       ]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0.0002457, 0.0002859, 0.000282 , ..., 0.       , 0.       ,
#         0.       ]),
#  array([0.0002457, 0.0002859, 0.000282 , ..., 0.       , 0.       ,
#         0.       ]),
#  array([2.211e-04, 8.300e-06, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([0.0002457, 0.0002859, 0.000282 , ..., 0.       , 0.       ,
#         0.       ]),
#  array([2.457e-04, 1.430e-05, 9.310e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.430e-05, 8.300e-06, 2.457e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([0.0002457, 0.0002859, 0.000282 , ..., 0.       , 0.       ,
#         0.       ]),
#  array([1.430e-05, 2.457e-04, 2.859e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.211e-04, 8.300e-06, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.430e-05, 2.457e-04, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.430e-05, 2.457e-04, 2.859e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([0.0002457, 0.0002859, 0.000282 , ..., 0.       , 0.       ,
#         0.       ]),
#  array([9.010e-05, 1.455e-04, 2.211e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 1.127e-04, 4.900e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([0, 0, 0, ..., 0, 0, 0]),
#  array([2.211e-04, 8.300e-06, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.211e-04, 8.300e-06, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.211e-04, 8.300e-06, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.455e-04, 2.211e-04, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.3739e-03, 8.3000e-06, 8.3000e-06, ..., 0.0000e+00, 0.0000e+00,
#         0.0000e+00]),
#  array([2.211e-04, 8.300e-06, 8.430e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 8.300e-06, 2.859e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.211e-04, 8.300e-06, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([8.320e-05, 2.211e-04, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.455e-04, 2.211e-04, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.211e-04, 8.300e-06, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.455e-04, 2.211e-04, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([8.3e-06, 8.3e-06, 8.3e-06, ..., 0.0e+00, 0.0e+00, 0.0e+00]),
#  array([8.3e-06, 8.3e-06, 8.3e-06, ..., 0.0e+00, 0.0e+00, 0.0e+00]),
#  array([8.320e-05, 2.211e-04, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.455e-04, 2.211e-04, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.455e-04, 2.211e-04, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.455e-04, 2.211e-04, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.455e-04, 2.211e-04, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.455e-04, 2.211e-04, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 8.300e-06, 9.310e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.211e-04, 8.300e-06, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.211e-04, 8.300e-06, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.211e-04, 8.300e-06, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.211e-04, 8.300e-06, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.455e-04, 2.211e-04, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.211e-04, 8.300e-06, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.211e-04, 8.300e-06, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.455e-04, 2.211e-04, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.455e-04, 2.211e-04, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([9.010e-05, 2.211e-04, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.211e-04, 8.300e-06, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.430e-05, 2.859e-04, 2.820e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([8.320e-05, 1.455e-04, 2.211e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.211e-04, 8.300e-06, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.211e-04, 7.170e-05, 3.260e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.211e-04, 8.300e-06, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.455e-04, 2.211e-04, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.211e-04, 8.300e-06, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.211e-04, 8.300e-06, 6.520e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.455e-04, 2.211e-04, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.211e-04, 8.300e-06, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.455e-04, 2.211e-04, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([8.3e-06, 8.3e-06, 8.3e-06, ..., 0.0e+00, 0.0e+00, 0.0e+00]),
#  array([2.457e-04, 1.127e-04, 4.900e-05, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.455e-04, 1.430e-05, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([8.3e-06, 8.3e-06, 8.3e-06, ..., 0.0e+00, 0.0e+00, 0.0e+00]),
#  array([2.211e-04, 8.300e-06, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.455e-04, 8.300e-06, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([1.63e-05, 1.63e-05, 8.30e-06, ..., 0.00e+00, 0.00e+00, 0.00e+00]),
#  array([0.0001455, 0.       , 0.       , ..., 0.       , 0.       ,
#         0.       ]),
#  array([0.0001455, 0.       , 0.       , ..., 0.       , 0.       ,
#         0.       ]),
#  array([0.0001455, 0.       , 0.       , ..., 0.       , 0.       ,
#         0.       ]),
#  array([0.0001455, 0.       , 0.       , ..., 0.       , 0.       ,
#         0.       ]),
#  array([8.3e-06, 8.3e-06, 8.3e-06, ..., 0.0e+00, 0.0e+00, 0.0e+00]),
#  array([1.455e-04, 8.300e-06, 8.300e-06, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([2.457e-04, 8.300e-06, 2.859e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00]),
#  array([8.320e-05, 8.300e-06, 1.455e-04, ..., 0.000e+00, 0.000e+00,
#         0.000e+00])]

# %%
np.savetxt('../dataset/matrix/X_tf_idf_sen.csv', np.array(num_array))

# %%
import numpy as np

np.loadtxt('../dataset/matrix/X_tf_idf_sen.csv').shape
# Out:
# (321, 2068)
